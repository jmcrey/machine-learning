# %%
from nltk.corpus import reuters
from nltk import bigrams, trigrams
from collections import Counter, defaultdict

# Create a placeholder for model
model = defaultdict(lambda: defaultdict(lambda: 0))

# Count frequency of co-occurance  
for sentence in reuters.sents():
    for w1, w2, w3 in trigrams(sentence, pad_right=True, pad_left=True):
        model[(w1, w2)][w3] += 1

model
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {(None,
#               None): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ASIAN': 4,
#                           'They': 446,
#                           'But': 1054,
#                           'The': 8839,
#                           'Unofficial': 1,
#                           '"': 3589,
#                           'In': 1380,
#                           'Threat': 2,
#                           'Taiwan': 38,
#                           'Retaliation': 3,
#                           'A': 764,
#                           'Last': 202,
#                           'Much': 8,
#                           'He': 1586,
#                           'Meanwhile': 41,
#                           'Japan': 111,
#                           'Deputy': 8,
#                           'CHINA': 50,
#                           'It': 1768,
#                           'JAPAN': 164,
#                           'MITI': 12,
#                           'Nuclear': 1,
#                           'THAI': 19,
#                           'Thailand': 13,
#                           'Export': 12,
#                           'Products': 4,
#                           'INDONESIA': 21,
#                           'Prices': 43,
#                           'Harahap': 2,
#                           'Indonesia': 34,
#                           'Indonesian': 9,
#                           'AUSTRALIAN': 37,
#                           'Cargo': 1,
#                           'INDONESIAN': 12,
#                           'Trading': 24,
#                           'Physical': 2,
#                           'Rubber': 3,
#                           'Robusta': 2,
#                           'No': 92,
#                           'Trade': 52,
#                           'Nainggolan': 1,
#                           'Officials': 58,
#                           'Transactions': 2,
#                           'Total': 111,
#                           'SRI': 9,
#                           'WESTERN': 8,
#                           'Bundey': 1,
#                           'Annual': 5,
#                           'SUMITOMO': 4,
#                           'Osaka': 1,
#                           'Some': 177,
#                           'Others': 11,
#                           'Now': 21,
#                           'Among': 57,
#                           'Regulations': 1,
#                           'We': 73,
#                           'Komatsu': 1,
#                           'Article': 2,
#                           'That': 104,
#                           'Until': 15,
#                           'Like': 6,
#                           'SUBROTO': 3,
#                           'Asked': 127,
#                           'BUNDESBANK': 24,
#                           'Banks': 34,
#                           'Dealers': 114,
#                           'Two': 25,
#                           'BOND': 6,
#                           'Atlas': 3,
#                           'Wilson': 13,
#                           'Its': 88,
#                           'Industrial': 17,
#                           'Demands': 3,
#                           'Agriculture': 21,
#                           'Insists': 2,
#                           'Australia': 16,
#                           'End': 7,
#                           'U': 866,
#                           'Suppliers': 4,
#                           'Beef': 2,
#                           'Other': 111,
#                           'Imports': 50,
#                           'An': 140,
#                           'Position': 8,
#                           'Agricultural': 6,
#                           'To': 67,
#                           'AMATIL': 1,
#                           'Shareholders': 13,
#                           'Amatil': 1,
#                           'Industries': 5,
#                           'BOWATER': 2,
#                           'Partly': 14,
#                           'SOUTH': 36,
#                           'South': 28,
#                           'Wants': 3,
#                           'Kim': 9,
#                           'FINNS': 1,
#                           'Most': 76,
#                           'Canadian': 29,
#                           'Finland': 1,
#                           'CRA': 10,
#                           'Whim': 1,
#                           'As': 200,
#                           'GERMAN': 55,
#                           'New': 43,
#                           'Bowater': 1,
#                           'Analysts': 205,
#                           'Profit': 7,
#                           'CITIBANK': 7,
#                           'Citibank': 8,
#                           'Foreign': 55,
#                           'Earlier': 156,
#                           'VIEILLE': 2,
#                           'Vieille': 1,
#                           'EC': 134,
#                           'STAND': 1,
#                           'Spain': 7,
#                           'Michael': 7,
#                           'Armacost': 2,
#                           'This': 448,
#                           'NORTH': 19,
#                           'ANHEUSER': 1,
#                           'Ramon': 2,
#                           'Diaz': 4,
#                           'Anheuser': 1,
#                           'ECONOMIC': 20,
#                           'High': 11,
#                           'Fund': 1,
#                           'Official': 18,
#                           'While': 104,
#                           'If': 174,
#                           'Offshore': 4,
#                           'Reserve': 7,
#                           'Apart': 6,
#                           'Crucial': 1,
#                           'Bankers': 40,
#                           'Factors': 1,
#                           'There': 170,
#                           'Kuwait': 15,
#                           'Oil': 55,
#                           'External': 2,
#                           'Cabinet': 4,
#                           'MALAYSIA': 17,
#                           'Output': 28,
#                           'Palm': 4,
#                           'Soybean': 47,
#                           'JARDINE': 6,
#                           'MONIER': 1,
#                           'Redland': 2,
#                           'Locke': 1,
#                           'Monier': 5,
#                           'ISUZU': 2,
#                           'JAPANESE': 16,
#                           'Kuroda': 3,
#                           'BELL': 6,
#                           'Bell': 5,
#                           'NIPPON': 13,
#                           'Jardine': 9,
#                           'Keswick': 2,
#                           'However': 394,
#                           'BANK': 110,
#                           'SAN': 9,
#                           'Cojuangco': 3,
#                           'His': 30,
#                           'De': 37,
#                           'On': 202,
#                           'SMC': 2,
#                           'Soriano': 2,
#                           'San': 3,
#                           'RAIN': 1,
#                           'Mills': 5,
#                           'Although': 95,
#                           'Elsewhere': 4,
#                           'Initial': 5,
#                           'FRENCH': 56,
#                           'ITALY': 17,
#                           'Consolidated': 13,
#                           'Iniziativa': 1,
#                           'NICKEL': 1,
#                           'Shearson': 14,
#                           'HIGHER': 3,
#                           'POEHL': 7,
#                           'Poehl': 26,
#                           'All': 61,
#                           'CINCINNATI': 1,
#                           'CALIFORNIA': 6,
#                           'For': 210,
#                           'PALL': 1,
#                           'UNILEVER': 7,
#                           'Chesebrough': 2,
#                           'Immediately': 3,
#                           'Nine': 11,
#                           'Unilever': 8,
#                           'CONRAC': 10,
#                           'Mark': 7,
#                           'Conrac': 7,
#                           'COMPUTER': 20,
#                           'RUBBERMAID': 4,
#                           'INDEPENDENT': 3,
#                           'Lammers': 1,
#                           'ELECTRO': 7,
#                           'WTC': 6,
#                           'MEAD': 2,
#                           'Today': 54,
#                           'CAYUGA': 1,
#                           'JOHNSTOWN': 2,
#                           'Net': 133,
#                           'HOME': 13,
#                           'GEODYNAMICS': 1,
#                           'SWEDISH': 10,
#                           'COMPAQ': 1,
#                           'Rod': 2,
#                           'Compaq': 1,
#                           'I': 61,
#                           'INTERNATIONAL': 30,
#                           'International': 20,
#                           'Terms': 136,
#                           'Hawaiian': 2,
#                           'CXR': 2,
#                           'PROXMIRE': 1,
#                           'Speaking': 43,
#                           'Proxmire': 4,
#                           'Rather': 4,
#                           'HELEN': 1,
#                           'BANKERS': 10,
#                           'Brazil': 36,
#                           'Assuming': 6,
#                           '&': 313,
#                           'UK': 36,
#                           'STOLTENBERG': 9,
#                           'Stoltenberg': 38,
#                           'And': 59,
#                           'INTERVENTION': 8,
#                           'Intervention': 12,
#                           'Out': 9,
#                           'Received': 3,
#                           'Paris': 3,
#                           'Cumulative': 11,
#                           'Mead': 2,
#                           'AMERTEK': 2,
#                           'ALEX': 3,
#                           'TOWN': 2,
#                           'PAXAR': 1,
#                           'CANADIAN': 41,
#                           'Ownership': 2,
#                           'ENTOURAGE': 1,
#                           'Entourage': 1,
#                           'F': 10,
#                           'WOOLWORTH': 12,
#                           'DUTCH': 32,
#                           'Conditions': 4,
#                           'Only': 32,
#                           'J': 28,
#                           'VOLKSWAGEN': 2,
#                           'VW': 9,
#                           'When': 40,
#                           'Share': 22,
#                           'Company': 53,
#                           'Parent': 25,
#                           'CITYTRUST': 1,
#                           'SOUTHMARK': 7,
#                           'loan': 2,
#                           'FIRSTBANC': 1,
#                           'MAYFAIR': 4,
#                           'HANOVER': 2,
#                           'NATIONAL': 55,
#                           'Security': 8,
#                           'UNIVERSAL': 9,
#                           'ZAMBIA': 8,
#                           'WEDGESTONE': 1,
#                           'SUN': 16,
#                           'FURTHER': 3,
#                           'Rains': 3,
#                           'Producers': 31,
#                           'Deterioration': 1,
#                           'Area': 2,
#                           'Maize': 10,
#                           'Production': 52,
#                           'Sorghum': 14,
#                           'Harvest': 3,
#                           'Preparation': 1,
#                           '8': 1,
#                           'TOP': 5,
#                           'Also': 47,
#                           'Monetary': 12,
#                           'Italian': 4,
#                           'At': 192,
#                           'FED': 156,
#                           'Economists': 59,
#                           'READER': 1,
#                           'WEIS': 2,
#                           'CONTINENTAL': 12,
#                           'Continental': 20,
#                           'ATLAS': 3,
#                           'Translated': 1,
#                           'SCI': 2,
#                           'Bristol': 1,
#                           'Sci': 1,
#                           'FIDELCOR': 3,
#                           'DATA': 10,
#                           'ENERGY': 12,
#                           'PETROCHEMICAL': 1,
#                           'Demand': 7,
#                           'Oreffice': 2,
#                           'GAF': 29,
#                           'Dosher': 1,
#                           'Finally': 8,
#                           'Another': 78,
#                           'Specialty': 2,
#                           'Houston': 7,
#                           'Chairman': 15,
#                           'Garo': 1,
#                           'Armen': 1,
#                           'FIDATA': 1,
#                           'Quarter': 5,
#                           'MARBLE': 1,
#                           'DOMINION': 5,
#                           'RAYTHEON': 5,
#                           'FLEET': 7,
#                           'DIEBOLD': 1,
#                           'WALTHAM': 2,
#                           'Payable': 2,
#                           'Earnings': 25,
#                           'Dufour': 2,
#                           'Dominion': 5,
#                           'Burlington': 13,
#                           'Revenues': 28,
#                           'GENERAL': 42,
#                           '1986': 152,
#                           'COCOA': 21,
#                           'Major': 12,
#                           'HONDURAS': 5,
#                           '2': 7,
#                           'HRW': 1,
#                           'Offers': 7,
#                           'Morgan': 18,
#                           'After': 82,
#                           'Excluding': 11,
#                           'Non': 24,
#                           'BRAZIL': 38,
#                           'Ministry': 9,
#                           'Brito': 1,
#                           'Murray': 3,
#                           'ROWE': 2,
#                           'REUTERS': 3,
#                           'Hogg': 1,
#                           'Reuters': 3,
#                           'CCL': 3,
#                           'PARIS': 4,
#                           'RHODES': 2,
#                           'MADEIRA': 1,
#                           'CELLTRONICS': 1,
#                           'MONTEDISON': 4,
#                           'Agrimont': 2,
#                           'Montedison': 3,
#                           'Ferruzzi': 7,
#                           'DATRON': 3,
#                           'According': 57,
#                           'Datron': 2,
#                           'Upon': 9,
#                           'TRUMP': 4,
#                           'SOUND': 1,
#                           'Trump': 8,
#                           'TELECRAFTER': 1,
#                           'TUNISIA': 3,
#                           'France': 8,
#                           'Of': 39,
#                           'COLT': 2,
#                           'Prior': 56,
#                           'YANKEE': 2,
#                           'Further': 17,
#                           'UNITED': 36,
#                           'CANADA': 91,
#                           'Saunders': 3,
#                           'Harcourt': 17,
#                           'TALKING': 18,
#                           'Edelman': 7,
#                           'Wall': 11,
#                           'Arbitragers': 8,
#                           'She': 64,
#                           'Masland': 1,
#                           'Edward': 2,
#                           'West': 34,
#                           'STERIVET': 4,
#                           'Makoto': 1,
#                           'Both': 69,
#                           'President': 48,
#                           'Congressional': 10,
#                           'About': 45,
#                           'Reagan': 36,
#                           'HOECHST': 5,
#                           'Hoechst': 7,
#                           'MELLON': 8,
#                           'Stock': 2,
#                           'PRESTON': 2,
#                           'WHITE': 11,
#                           'DOW': 11,
#                           'WALGREEN': 4,
#                           'JUDY': 1,
#                           'ORANGE': 3,
#                           'Current': 53,
#                           'LORD': 5,
#                           'HEINEKEN': 2,
#                           'Heineken': 5,
#                           'Turnover': 24,
#                           'Vice': 6,
#                           'Africa': 3,
#                           'COLOMBIA': 17,
#                           'Samuel': 1,
#                           'TURKEY': 8,
#                           'Greece': 6,
#                           'Turkey': 8,
#                           'FRONTIER': 3,
#                           'GATT': 17,
#                           'Aart': 1,
#                           'Committee': 1,
#                           'House': 10,
#                           'Later': 9,
#                           'Tomorrow': 7,
#                           'SOUTHINGTON': 1,
#                           'CATERPILLAR': 3,
#                           'CORRECTED': 22,
#                           '(': 45,
#                           'Preston': 1,
#                           'MEDTRONIC': 3,
#                           'Winston': 1,
#                           'Wallin': 5,
#                           'Regulators': 1,
#                           'Glen': 1,
#                           'Siemens': 6,
#                           'SPIE': 1,
#                           'Spie': 2,
#                           'TALKS': 3,
#                           'Delegates': 27,
#                           'PAKISTAN': 17,
#                           'Baluch': 1,
#                           'TRANZONIC': 2,
#                           'SECURITY': 10,
#                           'Presidential': 2,
#                           'Fitzwater': 5,
#                           'SHOWBOAT': 2,
#                           'Showboat': 2,
#                           'Houssels': 1,
#                           'Despite': 47,
#                           'Ecuador': 38,
#                           'IRAQI': 2,
#                           'Iraq': 16,
#                           'Iraqi': 4,
#                           'GOLDEN': 7,
#                           'GROUP': 28,
#                           'USDA': 135,
#                           'Donald': 4,
#                           'UNION': 26,
#                           'Union': 22,
#                           'UAL': 15,
#                           'Takeover': 2,
#                           'Traders': 73,
#                           'Market': 27,
#                           'the': 11,
#                           'HARTMARX': 3,
#                           'Meinert': 2,
#                           'GHANA': 7,
#                           'IRNA': 4,
#                           'Heller': 8,
#                           'Widespread': 2,
#                           'Energy': 15,
#                           'Full': 28,
#                           'INDUSTRIAL': 6,
#                           'French': 28,
#                           'Finance': 42,
#                           'Japanese': 44,
#                           'European': 19,
#                           'Kenneth': 6,
#                           'Morrison': 3,
#                           'FSIS': 1,
#                           'Salmonella': 1,
#                           'Blaylock': 1,
#                           'Subcommittee': 3,
#                           'said': 12,
#                           'CHRYSLER': 18,
#                           'Chrysler': 15,
#                           'Under': 251,
#                           'Said': 2,
#                           'RITE': 3,
#                           'AIRSENSORS': 1,
#                           'General': 53,
#                           'GE': 6,
#                           'Aerospace': 1,
#                           'TECK': 2,
#                           'COPPER': 5,
#                           'Teck': 5,
#                           'Cominco': 7,
#                           'Townson': 1,
#                           'BANPONCE': 1,
#                           'XEBEC': 1,
#                           'Xebec': 3,
#                           'IBM': 6,
#                           'CCC': 34,
#                           'EGYPT': 10,
#                           'BROKER': 2,
#                           'KIENA': 2,
#                           'Record': 6,
#                           'DAY': 1,
#                           'Day': 7,
#                           'During': 43,
#                           'Ite': 1,
#                           'MEXICAN': 4,
#                           'VULCAN': 3,
#                           'Miller': 8,
#                           'Vulcan': 2,
#                           'STRATA': 2,
#                           'Strata': 1,
#                           'DAYTON': 7,
#                           'NAT': 5,
#                           'Comments': 3,
#                           'CASCADE': 1,
#                           'Cascade': 1,
#                           'ARMEL': 1,
#                           'Proceeds': 18,
#                           'National': 38,
#                           'MANAGEMENT': 3,
#                           'WOJNILOWER': 1,
#                           'Wojnilower': 1,
#                           'RAYTECH': 2,
#                           'Raybestos': 1,
#                           'INTERCARE': 3,
#                           'Intercare': 2,
#                           'Executives': 2,
#                           'Carney': 9,
#                           'Short': 7,
#                           'IAE': 1,
#                           'STEWART': 6,
#                           'WESTAMERICA': 2,
#                           'SOUTHEAST': 4,
#                           'Based': 23,
#                           'WILLIAMS': 9,
#                           'Williams': 9,
#                           'Companywide': 1,
#                           'SUPER': 3,
#                           'PARKER': 4,
#                           'COFFEE': 15,
#                           'HBO': 1,
#                           'ON': 3,
#                           'Andover': 1,
#                           'UAP': 1,
#                           'EIA': 13,
#                           'HAWKEYE': 1,
#                           '"...': 3,
#                           'Hawkeye': 2,
#                           'DOME': 13,
#                           'Dome': 43,
#                           'RECENT': 6,
#                           'Gasoline': 15,
#                           'So': 22,
#                           'Year': 46,
#                           'DEFICIT': 1,
#                           'Similarly': 5,
#                           'Federal': 30,
#                           'Such': 37,
#                           'Volcker': 14,
#                           'Kemper': 1,
#                           'Collander': 1,
#                           'Shr': 34,
#                           'Nobody': 1,
#                           'Without': 15,
#                           'GATEWAY': 5,
#                           'MORE': 17,
#                           'American': 63,
#                           'Their': 18,
#                           'cash': 1,
#                           'REUTER': 40,
#                           'Koehler': 3,
#                           'Speculative': 3,
#                           'Given': 12,
#                           'Unadjusted': 19,
#                           'CSR': 22,
#                           'Nihon': 2,
#                           'SHOWA': 1,
#                           'Showa': 2,
#                           'MPT': 2,
#                           'Washington': 25,
#                           'Close': 2,
#                           'Recognized': 1,
#                           'Many': 41,
#                           'Diplomatic': 8,
#                           'Critics': 3,
#                           'Providing': 1,
#                           'G': 14,
#                           '1': 9,
#                           '3': 12,
#                           'Money': 36,
#                           'RIO': 9,
#                           'Burmah': 3,
#                           'Bundesbank': 29,
#                           'Separately': 14,
#                           'Currency': 15,
#                           'Though': 11,
#                           'SOVIET': 23,
#                           'Statistics': 5,
#                           'Moscow': 7,
#                           'Western': 27,
#                           'BURMAH': 2,
#                           'Final': 15,
#                           'Pre': 12,
#                           'Minorities': 3,
#                           'Extraordinary': 9,
#                           'NOTE': 44,
#                           'RTZ': 2,
#                           'Consumption': 5,
#                           'Pretax': 5,
#                           'Metals': 2,
#                           'BRIDGESTONE': 1,
#                           'Operators': 7,
#                           'GEBRUEDER': 1,
#                           'Dividend': 17,
#                           'Note': 36,
#                           'Eishiro': 5,
#                           'Takashi': 3,
#                           'Saito': 5,
#                           'PERGAMON': 1,
#                           'NATIONALE': 1,
#                           'SHANGHAI': 1,
#                           'Part': 5,
#                           'SAUDI': 29,
#                           'Several': 31,
#                           'Spot': 16,
#                           'Three': 13,
#                           'Commercial': 10,
#                           'BELGIUM': 8,
#                           'PHILIPPINE': 14,
#                           'Lazo': 2,
#                           'PLDT': 3,
#                           'CARGILL': 9,
#                           'Price': 14,
#                           'India': 11,
#                           'OECF': 1,
#                           'CCF': 1,
#                           'planned': 1,
#                           'Previously': 26,
#                           'JOHNSON': 7,
#                           'Previous': 5,
#                           'PLATINUM': 2,
#                           'LEX': 1,
#                           'Lex': 5,
#                           'These': 80,
#                           'MAJOR': 14,
#                           'Malaysia': 17,
#                           'MEPC': 1,
#                           'GEORGE': 2,
#                           'Operating': 19,
#                           'AEGON': 8,
#                           'Interim': 2,
#                           'February': 29,
#                           'Just': 3,
#                           'One': 145,
#                           'MIYAZAWA': 17,
#                           'NATNED': 1,
#                           'Claim': 1,
#                           'Assets': 9,
#                           '9': 3,
#                           'EUROPEAN': 8,
#                           'Merchandise': 3,
#                           'Theodor': 2,
#                           'London': 18,
#                           'Concern': 7,
#                           'Dave': 3,
#                           'Chase': 13,
#                           'Alois': 1,
#                           'he': 6,
#                           'Bank': 86,
#                           'Any': 25,
#                           'Call': 14,
#                           'Holdings': 3,
#                           'THAILAND': 6,
#                           'Tokyo': 13,
#                           'SWISS': 20,
#                           'Subscriptions': 4,
#                           'Frankfurt': 1,
#                           'FINANCE': 1,
#                           'Shortly': 5,
#                           'Revenue': 7,
#                           'Health': 1,
#                           'Damage': 2,
#                           'Annuities': 1,
#                           'Large': 4,
#                           'Monumental': 1,
#                           'Miyazawa': 34,
#                           'YEN': 4,
#                           'Marc': 2,
#                           'Will': 1,
#                           'UNIFIRST': 1,
#                           'WEST': 15,
#                           'STEP': 1,
#                           'COAST': 1,
#                           'Central': 26,
#                           'Coast': 1,
#                           'BRAMALL': 1,
#                           'Bramall': 2,
#                           'Payment': 15,
#                           'Each': 31,
#                           'FAO': 6,
#                           'World': 29,
#                           'CB': 4,
#                           'XICOR': 1,
#                           'Wimpey': 1,
#                           'C': 17,
#                           'DATATRAK': 1,
#                           'TODD': 4,
#                           'Todd': 4,
#                           'CLEVITE': 5,
#                           'SUNTRUST': 2,
#                           'Results': 37,
#                           'PHILIP': 5,
#                           'COLONIAL': 7,
#                           'RPT': 4,
#                           'Sunflowerseed': 5,
#                           'Clevite': 2,
#                           'ARGENTINE': 21,
#                           'MAXIMUN': 1,
#                           'PHYSIO': 1,
#                           'Physio': 2,
#                           'WASHINGTON': 9,
#                           'Crude': 25,
#                           'Product': 1,
#                           'May': 15,
#                           'PONCE': 2,
#                           'LEBANESE': 1,
#                           'BROWN': 15,
#                           'LONDON': 21,
#                           'Moderately': 1,
#                           'Grain': 20,
#                           'Soviet': 17,
#                           'HOG': 9,
#                           'Cattle': 11,
#                           'WHIRLPOOL': 3,
#                           'BRAZILIAN': 15,
#                           'Schlesinger': 9,
#                           'German': 38,
#                           'Aside': 3,
#                           'Responding': 3,
#                           'SAO': 4,
#                           'MINAS': 3,
#                           'E': 22,
#                           'WORLD': 18,
#                           'GEMINA': 1,
#                           'Group': 12,
#                           'Kiichi': 1,
#                           'Bonn': 5,
#                           'Sharp': 11,
#                           'GLOBAL': 7,
#                           'IMF': 3,
#                           'Economic': 7,
#                           'Since': 63,
#                           'Debtor': 1,
#                           'SPANISH': 5,
#                           'Cuevas': 2,
#                           'LEAD': 1,
#                           'Delayed': 1,
#                           'Mexican': 1,
#                           'Merchant': 6,
#                           'Specific': 2,
#                           'Gothenburg': 1,
#                           'Warehouses': 1,
#                           'Labour': 10,
#                           'Noranda': 10,
#                           'REXHAM': 3,
#                           '1987': 47,
#                           'FIRST': 89,
#                           'FHLBB': 10,
#                           'ANCHOR': 4,
#                           'Waccamaw': 1,
#                           'ASARCO': 3,
#                           'Hutton': 23,
#                           'Purolator': 16,
#                           'Following': 29,
#                           'PC': 1,
#                           'ABBOTT': 4,
#                           'INDIA': 33,
#                           'Actual': 9,
#                           'Taking': 5,
#                           'Simultaneously': 1,
#                           'CERTIFICATED': 2,
#                           'REICHHOLD': 6,
#                           'Reichhold': 6,
#                           'Details': 10,
#                           'HANSON': 11,
#                           'SPAIN': 18,
#                           'Exports': 75,
#                           'EXXON': 11,
#                           'SALLIE': 2,
#                           'FREDDIE': 3,
#                           'YUGOSLAVIA': 2,
#                           'FEDERATED': 11,
#                           'PRICES': 2,
#                           'BAGS': 1,
#                           'Brown': 17,
#                           'HIGHLAND': 1,
#                           'LVI': 6,
#                           'TEXAS': 21,
#                           'VORNADO': 2,
#                           'BRENDA': 1,
#                           'Financial': 10,
#                           'PHOENIX': 2,
#                           'Data': 7,
#                           'HEALTH': 8,
#                           'T': 6,
#                           'HERITAGE': 2,
#                           'Oswald': 1,
#                           'Rexham': 3,
#                           'Fed': 21,
#                           'Yesterday': 59,
#                           'DIAMOND': 18,
#                           'Diamond': 6,
#                           'LAWSON': 24,
#                           'Lawson': 39,
#                           'Therefore': 2,
#                           'Barley': 5,
#                           'Rebates': 3,
#                           'POTATO': 1,
#                           'Farmers': 17,
#                           'April': 16,
#                           'Bill': 3,
#                           'Harris': 4,
#                           'Sources': 10,
#                           '.': 5,
#                           'CANAM': 1,
#                           'Canam': 1,
#                           'SPOT': 2,
#                           'Stability': 1,
#                           'Reported': 1,
#                           'Small': 8,
#                           'DOLLAR': 18,
#                           'Koch': 3,
#                           'Bundebank': 1,
#                           'Hopes': 1,
#                           'Euromark': 1,
#                           'Eurodollars': 1,
#                           'Sterling': 20,
#                           'EMS': 2,
#                           'CONSOLIDATED': 12,
#                           'HUMANA': 7,
#                           'MET': 3,
#                           'FORD': 13,
#                           'Armco': 3,
#                           'Bradford': 2,
#                           'USX': 17,
#                           'Applebaum': 2,
#                           'Peter': 9,
#                           'DEKALB': 2,
#                           'Abbott': 1,
#                           'Research': 4,
#                           'Sales': 61,
#                           'Hospital': 2,
#                           'First': 50,
#                           'EASTERN': 3,
#                           'Yield': 3,
#                           'LBS': 1,
#                           'Hot': 2,
#                           'Nearly': 7,
#                           'Cotton': 13,
#                           'TREASURY': 51,
#                           'RJR': 5,
#                           'Unlike': 4,
#                           'Baker': 71,
#                           'TIME': 4,
#                           'SPRINKEL': 2,
#                           'Sprinkel': 10,
#                           'ROYAL': 24,
#                           'RULE': 1,
#                           'NEW': 62,
#                           'Henry': 7,
#                           'Income': 6,
#                           'WEATHER': 3,
#                           'WASTE': 16,
#                           'BRANCH': 1,
#                           'KURZ': 1,
#                           'Due': 6,
#                           'ZAYRE': 5,
#                           'BAYBANKS': 2,
#                           'FRANCE': 14,
#                           'STUDENT': 1,
#                           'FIRE': 1,
#                           'Five': 8,
#                           'JP': 3,
#                           'John': 6,
#                           'MEDITRUST': 2,
#                           'MONSANTO': 6,
#                           'Searle': 1,
#                           'Gilgore': 1,
#                           'STATUS': 1,
#                           'BETZ': 1,
#                           'NORTHWESTERN': 1,
#                           'GRAIN': 23,
#                           'ELEVATOR': 3,
#                           'FOOTHILL': 2,
#                           'Foothill': 1,
#                           'Completion': 12,
#                           'FAB': 1,
#                           'NORTHERN': 9,
#                           'Reference': 3,
#                           'TBN': 1,
#                           'ENQUIRIES': 1,
#                           'Inchon': 1,
#                           'Reunion': 1,
#                           'Naantali': 1,
#                           'Dunkirk': 1,
#                           'Toledo': 3,
#                           'River': 3,
#                           'AMOSKEAG': 5,
#                           'MSR': 1,
#                           'Proved': 3,
#                           'Southmark': 8,
#                           'Holders': 12,
#                           'EXPORTS': 1,
#                           'TAFT': 14,
#                           'Taft': 19,
#                           'Analyst': 15,
#                           'Overall': 15,
#                           'Brennan': 7,
#                           'Lawrence': 2,
#                           'Penney': 6,
#                           'Hudson': 6,
#                           'Mortner': 1,
#                           'MARCH': 3,
#                           'RETAILERS': 3,
#                           'MOROCCO': 2,
#                           'MIDLANTIC': 2,
#                           'COMMUNITY': 4,
#                           'FITCHBURG': 1,
#                           'Should': 6,
#                           'DOE': 9,
#                           'FINAL': 5,
#                           'PROTECTIVE': 1,
#                           'SMITH': 1,
#                           'CENTRAL': 15,
#                           'VLSI': 1,
#                           'BELGIAN': 16,
#                           'Private': 22,
#                           'SILICON': 1,
#                           'DISEASE': 1,
#                           'Normally': 5,
#                           'Commenting': 38,
#                           'Zimbabwe': 4,
#                           'Projected': 3,
#                           'SHAWMUT': 2,
#                           'Loan': 5,
#                           'MINNTECH': 2,
#                           'GORDEX': 2,
#                           'Gordex': 2,
#                           'CONGRESSMAN': 3,
#                           'Sugar': 7,
#                           'Representatives': 8,
#                           'REPUBLIC': 8,
#                           'Periods': 2,
#                           'WALL': 16,
#                           'Coniston': 1,
#                           'Tenders': 5,
#                           'CONSENSUS': 2,
#                           'SLATER': 2,
#                           'CITY': 6,
#                           'ALLIED': 20,
#                           'MAGMA': 7,
#                           'CENTERRE': 2,
#                           'SEA': 4,
#                           'HOUSE': 15,
#                           'STOCKPILE': 2,
#                           'Responsibility': 2,
#                           'Jestin': 1,
#                           'Nonaccrual': 1,
#                           'Stocks': 10,
#                           'Domestic': 39,
#                           'Usage': 3,
#                           'Wheat': 32,
#                           '1985': 83,
#                           'Soybeans': 7,
#                           'Crushings': 2,
#                           'Florida': 2,
#                           'USSR': 13,
#                           'Spring': 2,
#                           'Acreage': 1,
#                           'Corn': 18,
#                           'WHEAT': 17,
#                           'HARD': 1,
#                           'X': 9,
#                           'SOFT': 1,
#                           'DURUM': 1,
#                           'STOP': 4,
#                           'Australian': 10,
#                           'NET': 1,
#                           'Y': 6,
#                           'ALL': 3,
#                           'SOYBEAN': 14,
#                           'BARLEY': 3,
#                           'nil': 1,
#                           '302': 1,
#                           '301': 1,
#                           '82': 1,
#                           '260': 1,
#                           'wheat': 1,
#                           'CORN': 4,
#                           ...}),
#              (None,
#               'ASIAN'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'EXPORTERS': 1,
#                           'COCOA': 1,
#                           'DOLLAR': 2}),
#              ('ASIAN',
#               'EXPORTERS'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'FEAR': 1}),
#              ('EXPORTERS',
#               'FEAR'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'DAMAGE': 1}),
#              ('FEAR',
#               'DAMAGE'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'FROM': 1}),
#              ('DAMAGE',
#               'FROM'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'U': 1,
#                           'SPILL': 1}),
#              ('FROM',
#               'U'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 4}),
#              ('U',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'S': 5693,
#                           'K': 624,
#                           None: 3,
#                           'N': 28,
#                           'F': 2}),
#              ('.',
#               'S'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.-': 120,
#                           '.': 5340,
#                           '.,"': 11,
#                           '.,': 155,
#                           '>': 78,
#                           '>,': 7,
#                           '..': 5,
#                           'where': 1,
#                           '.)': 15,
#                           '>-': 4,
#                           'courier': 1,
#                           'Customs': 1,
#                           '.).': 2,
#                           '.),': 1,
#                           'consumer': 1,
#                           '>.': 6,
#                           ',': 7,
#                           ".'": 4,
#                           'TRADE': 1,
#                           '."': 1,
#                           './': 19,
#                           'domestic': 1,
#                           'COMMERCE': 1,
#                           'SENATE': 1,
#                           'ANGER': 1,
#                           '-': 1,
#                           'agriculture': 1,
#                           'and': 1,
#                           'grains': 1,
#                           'SAYS': 1,
#                           'Agriculture': 1,
#                           'in': 2,
#                           'to': 1,
#                           'economy': 1,
#                           'responded': 2,
#                           'OIL': 1,
#                           'dlrs': 1,
#                           'corn': 1,
#                           'ENERGY': 1,
#                           'warship': 2,
#                           '>/': 1,
#                           'later': 1,
#                           '/': 2,
#                           '.>': 1,
#                           'sugar': 1,
#                           'TREASURY': 1}),
#              ('S',
#               '.-'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'JAPAN': 8,
#                           'Japanese': 20,
#                           'based': 5,
#                           'dlr': 2,
#                           'USSR': 13,
#                           'Japan': 14,
#                           'China': 2,
#                           'owned': 3,
#                           'CANADA': 1,
#                           'Canadian': 4,
#                           'European': 2,
#                           'IRAN': 1,
#                           'flag': 2,
#                           'flagged': 12,
#                           'West': 3,
#                           'WEST': 1,
#                           'protected': 1,
#                           'Israeli': 1,
#                           'German': 1,
#                           'GERMAN': 2,
#                           'made': 4,
#                           'South': 1,
#                           'Greek': 1,
#                           'EC': 1,
#                           'Soviet': 3,
#                           'Canada': 2,
#                           'origin': 2,
#                           'produced': 3,
#                           'SOVIET': 1,
#                           'British': 2,
#                           'U': 2}),
#              ('.-',
#               'JAPAN'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'RIFT': 1,
#                           'AGREEMENT': 1,
#                           'TRADE': 4,
#                           'NOT': 1,
#                           'MICROCHIP': 1}),
#              ('JAPAN',
#               'RIFT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Mounting': 1}),
#              ('RIFT',
#               'Mounting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'trade': 1}),
#              ('Mounting',
#               'trade'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'friction': 1}),
#              ('trade',
#               'friction'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'between': 3,
#                           'with': 1,
#                           'diplomacy': 1,
#                           '.': 2,
#                           'and': 5,
#                           'unless': 1,
#                           'flared': 1,
#                           'could': 1,
#                           'will': 1,
#                           'is': 1}),
#              ('friction',
#               'between'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 4}),
#              ('between',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'U': 21,
#                           'start': 2,
#                           'two': 85,
#                           'employers': 2,
#                           'United': 16,
#                           'demands': 1,
#                           'countries': 1,
#                           'EC': 6,
#                           'dollar': 2,
#                           'White': 1,
#                           'prime': 4,
#                           'report': 2,
#                           'increased': 1,
#                           'secured': 1,
#                           'pork': 1,
#                           'Omani': 1,
#                           'Group': 3,
#                           'purchase': 1,
#                           'Federal': 1,
#                           'first': 1,
#                           'heaviest': 1,
#                           'growth': 1,
#                           'factories': 1,
#                           'old': 2,
#                           'European': 2,
#                           'prices': 1,
#                           'government': 2,
#                           'Canadian': 1,
#                           'seven': 2,
#                           'study': 1,
#                           'ebullient': 1,
#                           'Bundesbank': 1,
#                           'guilder': 2,
#                           'origins': 1,
#                           '(': 1,
#                           'candidates': 1,
#                           'declaration': 1,
#                           'central': 1,
#                           'Cenepa': 2,
#                           'Japanese': 1,
#                           'Wilkinson': 1,
#                           'parties': 2,
#                           'total': 1,
#                           '15': 1,
#                           'acceptance': 1,
#                           'bank': 1,
#                           'Bank': 1,
#                           'companies': 2,
#                           'pressures': 1,
#                           '3': 1,
#                           '2': 1,
#                           'Fed': 1,
#                           'big': 2,
#                           'Finance': 1,
#                           'ministry': 1,
#                           'beginning': 1,
#                           'company': 1,
#                           'use': 1,
#                           'Dutch': 1,
#                           'latest': 1,
#                           'fall': 1,
#                           'union': 2,
#                           'leading': 1,
#                           'five': 1,
#                           'Philippines': 1,
#                           'six': 2,
#                           'world': 3,
# ...
#                           'liquid': 2,
#                           'producer': 3,
#                           'rate': 1,
#                           'for': 1,
#                           'bubble': 1,
#                           'marketing': 1,
#                           'output': 2,
#                           'would': 1,
#                           'compressor': 1,
#                           'last': 1,
#                           'suplies': 1,
#                           'sector': 1,
#                           'cost': 1,
#                           'was': 1,
#                           'declined': 2,
#                           'each': 1}),
#              ('gas',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {None: 16}),
#              (None,
#               'Nuclear'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'energy': 1}),
#              ('Nuclear',
#               'energy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'provided': 1}),
#              ('energy',
#               'provided'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1}),
#              ('provided',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'bulk': 2,
#                           'money': 34,
#                           'market': 8,
#                           'U': 1,
#                           'country': 1,
#                           'guilder': 1,
#                           'system': 1,
#                           'accord': 1,
#                           'perfect': 1,
#                           'companies': 1,
#                           'exercise': 1}),
#              ('the',
#               'bulk'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'of': 20,
#                           'carrier': 1,
#                           'would': 1,
#                           'will': 1,
#                           'being': 1}),
#              ('bulk',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Japan': 1,
#                           'the': 13,
#                           'material': 1,
#                           'mortgage': 1,
#                           'wheat': 1,
#                           'winterkill': 1,
#                           'this': 1,
#                           'a': 1,
#                           'properties': 1,
#                           'liquidity': 1,
#                           'direction': 1,
#                           'its': 1,
#                           'world': 1,
#                           'tax': 1}),
#              ('s',
#               'electric'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'power': 1}),
#              ('power',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 3,
#                           'respect': 3,
#                           'some': 1,
#                           'Resorts': 1}),
#              ('the',
#               'fiscal'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'year': 54,
#                           'system': 2,
#                           '1987': 6,
#                           'side': 3,
#                           '1988': 2,
#                           'budget': 1,
#                           '1986': 1,
#                           'yearend': 1,
#                           'scope': 1}),
#              ('fiscal',
#               'year'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ended': 24,
#                           'ending': 26,
#                           'in': 2,
#                           ',': 17,
#                           'that': 1,
#                           'earnings': 2,
#                           'net': 2,
#                           '1987': 12,
#                           '.': 20,
#                           'recently': 1,
#                           'of': 1,
#                           'the': 1,
#                           'for': 1,
#                           'from': 3,
#                           'higher': 1,
#                           'revenues': 1,
#                           'ends': 4,
#                           'will': 2,
#                           'on': 6,
#                           '-': 3,
#                           "'": 2,
#                           '."': 1,
#                           'beginning': 7,
#                           'to': 12,
#                           'end': 4,
#                           'started': 2,
#                           '1989': 1,
#                           'which': 1,
#                           'results': 1,
#                           '1985': 1,
#                           'compared': 2,
#                           'with': 1,
#                           'against': 1,
#                           'reached': 1,
#                           '1986': 3,
#                           'remain': 1,
#                           'is': 1,
#                           '1988': 2,
#                           'by': 1,
#                           'should': 1,
#                           'and': 2,
#                           'just': 1,
#                           ',"': 1,
#                           'starting': 1,
#                           'progresses': 1}),
#              ('year',
#               'ended'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'March': 19,
#                           'October': 5,
#                           'December': 16,
#                           'September': 8,
#                           'Dec': 2,
#                           'June': 8,
#                           'Jan': 2,
#                           'April': 3,
#                           'January': 22,
#                           'in': 2,
#                           'this': 1,
#                           'February': 10,
#                           'November': 8,
#                           'May': 3,
#                           'July': 4,
#                           'Sept': 2,
#                           'last': 1,
#                           '30': 1,
#                           'August': 2,
#                           'december': 1,
#                           'Feb': 2}),
#              ('ended',
#               'March'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'31': 49,
#                           '28': 9,
#                           '21': 3,
#                           '1987': 2,
#                           '1986': 1,
#                           'from': 1,
#                           '18': 2,
#                           '19': 4,
#                           ',': 3,
#                           '14': 8,
#                           'One': 2,
#                           '20': 8,
#                           '6': 1,
#                           '29': 5,
#                           '27': 5,
#                           '30': 2,
#                           'one': 1,
#                           '25': 2,
#                           '4': 5,
#                           'six': 3,
#                           '9': 1,
#                           '7': 5,
#                           '12': 2,
#                           '11': 5,
#                           'five': 1,
#                           '13': 7,
#                           'seven': 1,
#                           '26': 1,
#                           '8': 1,
#                           '1': 1}),
#              ('March',
#               '31'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {',': 104,
#                           '.': 81,
#                           'Shr': 12,
#                           'end': 4,
#                           'offered': 1,
#                           'book': 1,
#                           'which': 1,
#                           'Net': 1,
#                           'at': 3,
#                           'against': 3,
#                           'Oper': 1,
#                           'from': 5,
#                           'Fin': 1,
#                           '1987': 3,
#                           'Final': 1,
#                           'improved': 1,
#                           'would': 1,
#                           'Group': 2,
#                           'the': 2,
#                           None: 49,
#                           'and': 8,
#                           'mainly': 1,
#                           'drew': 1,
#                           '-': 1,
#                           'compared': 1,
#                           'since': 1,
#                           'were': 2,
#                           'closing': 1,
#                           'Record': 33,
#                           'of': 3,
#                           'balance': 1,
#                           'to': 13,
#                           'said': 1,
#                           'due': 2,
#                           'for': 1,
#                           'as': 1,
#                           'NOTE': 11,
#                           'after': 2,
#                           'Note': 2,
#                           ';': 1,
#                           'whether': 1,
#                           ',"': 1,
#                           'will': 1,
#                           '(': 1,
#                           'annual': 1,
#                           'in': 1,
#                           'proposals': 1}),
#              ('31',
#               ','): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'supplying': 1,
#                           '1983': 1,
#                           'compared': 5,
#                           'above': 1,
#                           '1987': 60,
#                           '680': 1,
#                           'including': 2,
#                           'it': 3,
#                           'director': 1,
#                           'a': 4,
#                           '1986': 74,
#                           'loss': 1,
#                           '000': 11,
#                           '1990': 3,
#                           'up': 4,
#                           '900': 1,
#                           '750': 2,
#                           '1988': 18,
#                           'the': 11,
#                           'Personal': 1,
#                           '300': 1,
#                           'Merrill': 1,
#                           '1982': 1,
#                           '640': 1,
#                           '1992': 2,
#                           'Kellwood': 1,
#                           '600': 1,
#                           'next': 1,
#                           '841': 1,
#                           'results': 1,
#                           'BHP': 1,
#                           'against': 2,
#                           'to': 2,
#                           '1985': 18,
#                           '1991': 2,
#                           'thus': 1,
#                           '429': 1,
#                           'National': 1,
#                           'will': 1,
#                           '1989': 6,
#                           'totaled': 1,
#                           '720': 1,
#                           'which': 2,
#                           '858': 1,
#                           'down': 3,
#                           'interest': 1,
#                           '011': 1,
#                           '528': 1,
#                           'unchanged': 1,
#                           'Britain': 1,
#                           'record': 3,
#                           'of': 1,
#                           'said': 3,
#                           'but': 2,
#                           'Paradyne': 1,
#                           '2002': 1,
#                           '1997': 2,
#                           'Caesars': 1,
#                           'ACT': 1,
#                           '500': 1,
#                           '1993': 2,
#                           'for': 2,
#                           'UFCWU': 1,
#                           '781': 1,
#                           '063': 1,
#                           'after': 1,
#                           'Farah': 1,
#                           'Heinz': 1,
#                           'lost': 1,
#                           'from': 1,
#                           'Winley': 1,
#                           'and': 2,
#                           'm': 1,
#                           'they': 1,
#                           'BPI': 1,
#                           '734': 1,
#                           '896': 1,
#                           'because': 2,
#                           'Economic': 1,
#                           'its': 2,
#                           'as': 1,
#                           'Fleet': 1,
#                           'according': 1,
#                           'due': 1,
#                           '867': 1,
#                           '831': 1,
#                           '100': 1,
#                           '117': 1,
#                           'would': 1,
#                           'CRSS': 1,
#                           'despite': 1,
#                           'CPC': 1}),
#              (',',
#               'supplying'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'an': 1}),
#              ('supplying',
#               'an'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'estimated': 1}),
#              ('an',
#               'estimated'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'27': 1,
#                           '1': 11,
#                           '270': 3,
#                           '544': 1,
#                           '127': 1,
#                           '171': 1,
#                           '445': 1,
#                           'total': 1,
#                           '3': 3,
#                           '14': 2,
#                           'offtake': 1,
#                           '4': 4,
#                           'record': 3,
#                           '25': 2,
#                           'one': 2,
#                           'five': 2,
#                           '77': 1,
#                           '8': 2,
#                           '5': 3,
#                           'overall': 1,
#                           '54': 1,
#                           '55': 1,
#                           'annualised': 1,
#                           '10': 4,
#                           '67': 1,
#                           '600': 1,
#                           'two': 2,
#                           'surplus': 1,
#                           '30': 2,
#                           '160': 3,
#                           '2': 3,
#                           '720': 1,
#                           '326': 1,
#                           '300': 2,
#                           'current': 1,
#                           '106': 1,
#                           '6': 2,
#                           '800': 1,
#                           'value': 1,
#                           '20': 1,
#                           '17': 1,
#                           '40': 1,
#                           '44': 1,
#                           '0': 1,
#                           '273': 1,
#                           '286': 1,
#                           '193': 1,
#                           '200': 2,
#                           '117': 1,
#                           '686': 1,
#                           '16': 1,
#                           '80': 1,
#                           '45': 1,
#                           '500': 1,
#                           '660': 1,
#                           'nine': 1,
#                           '98': 1,
#                           '12': 1,
#                           '879': 1,
#                           '100': 1,
#                           '15': 1}),
#              ('estimated',
#               '27'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'pct': 1}),
#              ('27',
#               'pct'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'on': 1,
#                           'increase': 3,
#                           'and': 1,
#                           'interest': 1,
#                           'to': 3,
#                           'of': 4,
#                           'late': 1,
#                           'a': 2,
#                           'Year': 1,
#                           '.': 3,
#                           'deduction': 1,
#                           'higher': 2,
#                           'but': 1,
#                           'in': 2,
#                           '(': 1,
#                           ',': 2,
#                           'below': 1,
#                           'from': 1,
#                           'per': 1,
#                           'above': 1}),
#              ...})

# %%
import numpy as np

class Trigram:
    
    def __init__(self, corpus: list):
        """ Initialized the class """
        self.corpus = corpus
        self._trigrams = self._get_trigrams()
        self.model = self._gen_model()
        
    def _get_trigrams(self):
        """ Gets the bigram count """
        trigram_count = defaultdict(lambda: defaultdict(lambda: 0))
        for tokens in self.corpus:
            for w1, w2, w3 in zip(tokens, tokens[1:], tokens[2:]):
                trigram_count[(w1, w2)][w3] += 1
        return trigram_count
    
    def _gen_model(self):
        """ Generates the trigram model """
        model = defaultdict(lambda: defaultdict(lambda: 0))
        for bigram, seq in self._trigrams.items():
            vals = np.array(list(seq.values()))
            count = float(np.sum(vals))
            vals = vals / count
            model[bigram] = dict(zip(seq.keys(), vals))
        return model

# %%
sents = list()
for s in reuters.sents():
    s.insert(0, '<s>')
    s.append('</s>')
    sents.append(s)
sents
# Out:
# [['<s>',
#   'ASIAN',
#   'EXPORTERS',
#   'FEAR',
#   'DAMAGE',
#   'FROM',
#   'U',
#   '.',
#   'S',
#   '.-',
#   'JAPAN',
#   'RIFT',
#   'Mounting',
#   'trade',
#   'friction',
#   'between',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   'And',
#   'Japan',
#   'has',
#   'raised',
#   'fears',
#   'among',
#   'many',
#   'of',
#   'Asia',
#   "'",
#   's',
#   'exporting',
#   'nations',
#   'that',
#   'the',
#   'row',
#   'could',
#   'inflict',
#   'far',
#   '-',
#   'reaching',
#   'economic',
#   'damage',
#   ',',
#   'businessmen',
#   'and',
#   'officials',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'They',
#   'told',
#   'Reuter',
#   'correspondents',
#   'in',
#   'Asian',
#   'capitals',
#   'a',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Move',
#   'against',
#   'Japan',
#   'might',
#   'boost',
#   'protectionist',
#   'sentiment',
#   'in',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   'And',
#   'lead',
#   'to',
#   'curbs',
#   'on',
#   'American',
#   'imports',
#   'of',
#   'their',
#   'products',
#   '.',
#   '</s>'],
#  ['<s>',
#   'But',
#   'some',
#   'exporters',
#   'said',
#   'that',
#   'while',
#   'the',
#   'conflict',
#   'would',
#   'hurt',
#   'them',
#   'in',
#   'the',
#   'long',
#   '-',
#   'run',
#   ',',
#   'in',
#   'the',
#   'short',
#   '-',
#   'term',
#   'Tokyo',
#   "'",
#   's',
#   'loss',
#   'might',
#   'be',
#   'their',
#   'gain',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Has',
#   'said',
#   'it',
#   'will',
#   'impose',
#   '300',
#   'mln',
#   'dlrs',
#   'of',
#   'tariffs',
#   'on',
#   'imports',
#   'of',
#   'Japanese',
#   'electronics',
#   'goods',
#   'on',
#   'April',
#   '17',
#   ',',
#   'in',
#   'retaliation',
#   'for',
#   'Japan',
#   "'",
#   's',
#   'alleged',
#   'failure',
#   'to',
#   'stick',
#   'to',
#   'a',
#   'pact',
#   'not',
#   'to',
#   'sell',
#   'semiconductors',
#   'on',
#   'world',
#   'markets',
#   'at',
#   'below',
#   'cost',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Unofficial',
#   'Japanese',
#   'estimates',
#   'put',
#   'the',
#   'impact',
#   'of',
#   'the',
#   'tariffs',
#   'at',
#   '10',
#   'billion',
#   'dlrs',
#   'and',
#   'spokesmen',
#   'for',
#   'major',
#   'electronics',
#   'firms',
#   'said',
#   'they',
#   'would',
#   'virtually',
#   'halt',
#   'exports',
#   'of',
#   'products',
#   'hit',
#   'by',
#   'the',
#   'new',
#   'taxes',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'We',
#   'wouldn',
#   "'",
#   't',
#   'be',
#   'able',
#   'to',
#   'do',
#   'business',
#   ',"',
#   'said',
#   'a',
#   'spokesman',
#   'for',
#   'leading',
#   'Japanese',
#   'electronics',
#   'firm',
#   'Matsushita',
#   'Electric',
#   'Industrial',
#   'Co',
#   'Ltd',
#   '&',
#   'lt',
#   ';',
#   'MC',
#   '.',
#   'T',
#   '>.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'If',
#   'the',
#   'tariffs',
#   'remain',
#   'in',
#   'place',
#   'for',
#   'any',
#   'length',
#   'of',
#   'time',
#   'beyond',
#   'a',
#   'few',
#   'months',
#   'it',
#   'will',
#   'mean',
#   'the',
#   'complete',
#   'erosion',
#   'of',
#   'exports',
#   '(',
#   'of',
#   'goods',
#   'subject',
#   'to',
#   'tariffs',
#   ')',
#   'to',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.,"',
#   'said',
#   'Tom',
#   'Murtha',
#   ',',
#   'a',
#   'stock',
#   'analyst',
#   'at',
#   'the',
#   'Tokyo',
#   'office',
#   'of',
#   'broker',
#   '&',
#   'lt',
#   ';',
#   'James',
#   'Capel',
#   'and',
#   'Co',
#   '>.',
#   '</s>'],
#  ['<s>',
#   'In',
#   'Taiwan',
#   ',',
#   'businessmen',
#   'and',
#   'officials',
#   'are',
#   'also',
#   'worried',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'We',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'seriousness',
#   'of',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Threat',
#   'against',
#   'Japan',
#   'because',
#   'it',
#   'serves',
#   'as',
#   'a',
#   'warning',
#   'to',
#   'us',
#   ',"',
#   'said',
#   'a',
#   'senior',
#   'Taiwanese',
#   'trade',
#   'official',
#   'who',
#   'asked',
#   'not',
#   'to',
#   'be',
#   'named',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Taiwan',
#   'had',
#   'a',
#   'trade',
#   'trade',
#   'surplus',
#   'of',
#   '15',
#   '.',
#   '6',
#   'billion',
#   'dlrs',
#   'last',
#   'year',
#   ',',
#   '95',
#   'pct',
#   'of',
#   'it',
#   'with',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'surplus',
#   'helped',
#   'swell',
#   'Taiwan',
#   "'",
#   's',
#   'foreign',
#   'exchange',
#   'reserves',
#   'to',
#   '53',
#   'billion',
#   'dlrs',
#   ',',
#   'among',
#   'the',
#   'world',
#   "'",
#   's',
#   'largest',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'We',
#   'must',
#   'quickly',
#   'open',
#   'our',
#   'markets',
#   ',',
#   'remove',
#   'trade',
#   'barriers',
#   'and',
#   'cut',
#   'import',
#   'tariffs',
#   'to',
#   'allow',
#   'imports',
#   'of',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Products',
#   ',',
#   'if',
#   'we',
#   'want',
#   'to',
#   'defuse',
#   'problems',
#   'from',
#   'possible',
#   'U',
#   '.',
#   'S',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Retaliation',
#   ',"',
#   'said',
#   'Paul',
#   'Sheen',
#   ',',
#   'chairman',
#   'of',
#   'textile',
#   'exporters',
#   '&',
#   'lt',
#   ';',
#   'Taiwan',
#   'Safe',
#   'Group',
#   '>.',
#   '</s>'],
#  ['<s>',
#   'A',
#   'senior',
#   'official',
#   'of',
#   'South',
#   'Korea',
#   "'",
#   's',
#   'trade',
#   'promotion',
#   'association',
#   'said',
#   'the',
#   'trade',
#   'dispute',
#   'between',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   'And',
#   'Japan',
#   'might',
#   'also',
#   'lead',
#   'to',
#   'pressure',
#   'on',
#   'South',
#   'Korea',
#   ',',
#   'whose',
#   'chief',
#   'exports',
#   'are',
#   'similar',
#   'to',
#   'those',
#   'of',
#   'Japan',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Last',
#   'year',
#   'South',
#   'Korea',
#   'had',
#   'a',
#   'trade',
#   'surplus',
#   'of',
#   '7',
#   '.',
#   '1',
#   'billion',
#   'dlrs',
#   'with',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.,',
#   'Up',
#   'from',
#   '4',
#   '.',
#   '9',
#   'billion',
#   'dlrs',
#   'in',
#   '1985',
#   '.',
#   '</s>'],
#  ['<s>',
#   'In',
#   'Malaysia',
#   ',',
#   'trade',
#   'officers',
#   'and',
#   'businessmen',
#   'said',
#   'tough',
#   'curbs',
#   'against',
#   'Japan',
#   'might',
#   'allow',
#   'hard',
#   '-',
#   'hit',
#   'producers',
#   'of',
#   'semiconductors',
#   'in',
#   'third',
#   'countries',
#   'to',
#   'expand',
#   'their',
#   'sales',
#   'to',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   '</s>'],
#  ['<s>',
#   'In',
#   'Hong',
#   'Kong',
#   ',',
#   'where',
#   'newspapers',
#   'have',
#   'alleged',
#   'Japan',
#   'has',
#   'been',
#   'selling',
#   'below',
#   '-',
#   'cost',
#   'semiconductors',
#   ',',
#   'some',
#   'electronics',
#   'manufacturers',
#   'share',
#   'that',
#   'view',
#   '.',
#   '</s>'],
#  ['<s>',
#   'But',
#   'other',
#   'businessmen',
#   'said',
#   'such',
#   'a',
#   'short',
#   '-',
#   'term',
#   'commercial',
#   'advantage',
#   'would',
#   'be',
#   'outweighed',
#   'by',
#   'further',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Pressure',
#   'to',
#   'block',
#   'imports',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'That',
#   'is',
#   'a',
#   'very',
#   'short',
#   '-',
#   'term',
#   'view',
#   ',"',
#   'said',
#   'Lawrence',
#   'Mills',
#   ',',
#   'director',
#   '-',
#   'general',
#   'of',
#   'the',
#   'Federation',
#   'of',
#   'Hong',
#   'Kong',
#   'Industry',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'If',
#   'the',
#   'whole',
#   'purpose',
#   'is',
#   'to',
#   'prevent',
#   'imports',
#   ',',
#   'one',
#   'day',
#   'it',
#   'will',
#   'be',
#   'extended',
#   'to',
#   'other',
#   'sources',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Much',
#   'more',
#   'serious',
#   'for',
#   'Hong',
#   'Kong',
#   'is',
#   'the',
#   'disadvantage',
#   'of',
#   'action',
#   'restraining',
#   'trade',
#   ',"',
#   'he',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Last',
#   'year',
#   'was',
#   'Hong',
#   'Kong',
#   "'",
#   's',
#   'biggest',
#   'export',
#   'market',
#   ',',
#   'accounting',
#   'for',
#   'over',
#   '30',
#   'pct',
#   'of',
#   'domestically',
#   'produced',
#   'exports',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'Australian',
#   'government',
#   'is',
#   'awaiting',
#   'the',
#   'outcome',
#   'of',
#   'trade',
#   'talks',
#   'between',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   'And',
#   'Japan',
#   'with',
#   'interest',
#   'and',
#   'concern',
#   ',',
#   'Industry',
#   'Minister',
#   'John',
#   'Button',
#   'said',
#   'in',
#   'Canberra',
#   'last',
#   'Friday',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'This',
#   'kind',
#   'of',
#   'deterioration',
#   'in',
#   'trade',
#   'relations',
#   'between',
#   'two',
#   'countries',
#   'which',
#   'are',
#   'major',
#   'trading',
#   'partners',
#   'of',
#   'ours',
#   'is',
#   'a',
#   'very',
#   'serious',
#   'matter',
#   ',"',
#   'Button',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'He',
#   'said',
#   'Australia',
#   "'",
#   's',
#   'concerns',
#   'centred',
#   'on',
#   'coal',
#   'and',
#   'beef',
#   ',',
#   'Australia',
#   "'",
#   's',
#   'two',
#   'largest',
#   'exports',
#   'to',
#   'Japan',
#   'and',
#   'also',
#   'significant',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Exports',
#   'to',
#   'that',
#   'country',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Meanwhile',
#   'U',
#   '.',
#   'S',
#   '.-',
#   'Japanese',
#   'diplomatic',
#   'manoeuvres',
#   'to',
#   'solve',
#   'the',
#   'trade',
#   'stand',
#   '-',
#   'off',
#   'continue',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Japan',
#   "'",
#   's',
#   'ruling',
#   'Liberal',
#   'Democratic',
#   'Party',
#   'yesterday',
#   'outlined',
#   'a',
#   'package',
#   'of',
#   'economic',
#   'measures',
#   'to',
#   'boost',
#   'the',
#   'Japanese',
#   'economy',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'measures',
#   'proposed',
#   'include',
#   'a',
#   'large',
#   'supplementary',
#   'budget',
#   'and',
#   'record',
#   'public',
#   'works',
#   'spending',
#   'in',
#   'the',
#   'first',
#   'half',
#   'of',
#   'the',
#   'financial',
#   'year',
#   '.',
#   '</s>'],
#  ['<s>',
#   'They',
#   'also',
#   'call',
#   'for',
#   'stepped',
#   '-',
#   'up',
#   'spending',
#   'as',
#   'an',
#   'emergency',
#   'measure',
#   'to',
#   'stimulate',
#   'the',
#   'economy',
#   'despite',
#   'Prime',
#   'Minister',
#   'Yasuhiro',
#   'Nakasone',
#   "'",
#   's',
#   'avowed',
#   'fiscal',
#   'reform',
#   'program',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Deputy',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Trade',
#   'Representative',
#   'Michael',
#   'Smith',
#   'and',
#   'Makoto',
#   'Kuroda',
#   ',',
#   'Japan',
#   "'",
#   's',
#   'deputy',
#   'minister',
#   'of',
#   'International',
#   'Trade',
#   'and',
#   'Industry',
#   '(',
#   'MITI',
#   '),',
#   'are',
#   'due',
#   'to',
#   'meet',
#   'in',
#   'Washington',
#   'this',
#   'week',
#   'in',
#   'an',
#   'effort',
#   'to',
#   'end',
#   'the',
#   'dispute',
#   '.',
#   '</s>'],
#  ['<s>',
#   'CHINA',
#   'DAILY',
#   'SAYS',
#   'VERMIN',
#   'EAT',
#   '7',
#   '-',
#   '12',
#   'PCT',
#   'GRAIN',
#   'STOCKS',
#   'A',
#   'survey',
#   'of',
#   '19',
#   'provinces',
#   'and',
#   'seven',
#   'cities',
#   'showed',
#   'vermin',
#   'consume',
#   'between',
#   'seven',
#   'and',
#   '12',
#   'pct',
#   'of',
#   'China',
#   "'",
#   's',
#   'grain',
#   'stocks',
#   ',',
#   'the',
#   'China',
#   'Daily',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'It',
#   'also',
#   'said',
#   'that',
#   'each',
#   'year',
#   '1',
#   '.',
#   '575',
#   'mln',
#   'tonnes',
#   ',',
#   'or',
#   '25',
#   'pct',
#   ',',
#   'of',
#   'China',
#   "'",
#   's',
#   'fruit',
#   'output',
#   'are',
#   'left',
#   'to',
#   'rot',
#   ',',
#   'and',
#   '2',
#   '.',
#   '1',
#   'mln',
#   'tonnes',
#   ',',
#   'or',
#   'up',
#   'to',
#   '30',
#   'pct',
#   ',',
#   'of',
#   'its',
#   'vegetables',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'paper',
#   'blamed',
#   'the',
#   'waste',
#   'on',
#   'inadequate',
#   'storage',
#   'and',
#   'bad',
#   'preservation',
#   'methods',
#   '.',
#   '</s>'],
#  ['<s>',
#   'It',
#   'said',
#   'the',
#   'government',
#   'had',
#   'launched',
#   'a',
#   'national',
#   'programme',
#   'to',
#   'reduce',
#   'waste',
#   ',',
#   'calling',
#   'for',
#   'improved',
#   'technology',
#   'in',
#   'storage',
#   'and',
#   'preservation',
#   ',',
#   'and',
#   'greater',
#   'production',
#   'of',
#   'additives',
#   '.',
#   '</s>'],
#  ['<s>', 'The', 'paper', 'gave', 'no', 'further', 'details', '.', '</s>'],
#  ['<s>',
#   'JAPAN',
#   'TO',
#   'REVISE',
#   'LONG',
#   '-',
#   'TERM',
#   'ENERGY',
#   'DEMAND',
#   'DOWNWARDS',
#   'The',
#   'Ministry',
#   'of',
#   'International',
#   'Trade',
#   'and',
#   'Industry',
#   '(',
#   'MITI',
#   ')',
#   'will',
#   'revise',
#   'its',
#   'long',
#   '-',
#   'term',
#   'energy',
#   'supply',
#   '/',
#   'demand',
#   'outlook',
#   'by',
#   'August',
#   'to',
#   'meet',
#   'a',
#   'forecast',
#   'downtrend',
#   'in',
#   'Japanese',
#   'energy',
#   'demand',
#   ',',
#   'ministry',
#   'officials',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'MITI',
#   'is',
#   'expected',
#   'to',
#   'lower',
#   'the',
#   'projection',
#   'for',
#   'primary',
#   'energy',
#   'supplies',
#   'in',
#   'the',
#   'year',
#   '2000',
#   'to',
#   '550',
#   'mln',
#   'kilolitres',
#   '(',
#   'kl',
#   ')',
#   'from',
#   '600',
#   'mln',
#   ',',
#   'they',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'decision',
#   'follows',
#   'the',
#   'emergence',
#   'of',
#   'structural',
#   'changes',
#   'in',
#   'Japanese',
#   'industry',
#   'following',
#   'the',
#   'rise',
#   'in',
#   'the',
#   'value',
#   'of',
#   'the',
#   'yen',
#   'and',
#   'a',
#   'decline',
#   'in',
#   'domestic',
#   'electric',
#   'power',
#   'demand',
#   '.',
#   '</s>'],
#  ['<s>',
#   'MITI',
#   'is',
#   'planning',
#   'to',
#   'work',
#   'out',
#   'a',
#   'revised',
#   'energy',
#   'supply',
#   '/',
#   'demand',
#   'outlook',
#   'through',
#   'deliberations',
#   'of',
#   'committee',
#   'meetings',
#   'of',
#   'the',
#   'Agency',
#   'of',
#   'Natural',
#   'Resources',
#   'and',
#   'Energy',
#   ',',
#   'the',
#   'officials',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'They',
#   'said',
#   'MITI',
#   'will',
#   'also',
#   'review',
#   'the',
#   'breakdown',
#   'of',
#   'energy',
#   'supply',
#   'sources',
#   ',',
#   'including',
#   'oil',
#   ',',
#   'nuclear',
#   ',',
#   'coal',
#   'and',
#   'natural',
#   'gas',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Nuclear',
#   'energy',
#   'provided',
#   'the',
#   'bulk',
#   'of',
#   'Japan',
#   "'",
#   's',
#   'electric',
#   'power',
#   'in',
#   'the',
#   'fiscal',
#   'year',
#   'ended',
#   'March',
#   '31',
#   ',',
#   'supplying',
#   'an',
#   'estimated',
#   '27',
#   'pct',
#   'on',
#   'a',
#   'kilowatt',
#   '/',
#   'hour',
#   'basis',
#   ',',
#   'followed',
#   'by',
#   'oil',
#   '(',
#   '23',
#   'pct',
#   ')',
#   'and',
#   'liquefied',
#   'natural',
#   'gas',
#   '(',
#   '21',
#   'pct',
#   '),',
#   'they',
#   'noted',
#   '.',
#   '</s>'],
#  ['<s>',
#   'THAI',
#   'TRADE',
#   'DEFICIT',
#   'WIDENS',
#   'IN',
#   'FIRST',
#   'QUARTER',
#   'Thailand',
#   "'",
#   's',
#   'trade',
#   'deficit',
#   'widened',
#   'to',
#   '4',
#   '.',
#   '5',
#   'billion',
#   'baht',
#   'in',
#   'the',
#   'first',
#   'quarter',
#   'of',
#   '1987',
#   'from',
#   '2',
#   '.',
#   '1',
#   'billion',
#   'a',
#   'year',
#   'ago',
#   ',',
#   'the',
#   'Business',
#   'Economics',
#   'Department',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'It',
#   'said',
#   'Janunary',
#   '/',
#   'March',
#   'imports',
#   'rose',
#   'to',
#   '65',
#   '.',
#   '1',
#   'billion',
#   'baht',
#   'from',
#   '58',
#   '.',
#   '7',
#   'billion',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Thailand',
#   "'",
#   's',
#   'improved',
#   'business',
#   'climate',
#   'this',
#   'year',
#   'resulted',
#   'in',
#   'a',
#   '27',
#   'pct',
#   'increase',
#   'in',
#   'imports',
#   'of',
#   'raw',
#   'materials',
#   'and',
#   'semi',
#   '-',
#   'finished',
#   'products',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'country',
#   "'",
#   's',
#   'oil',
#   'import',
#   'bill',
#   ',',
#   'however',
#   ',',
#   'fell',
#   '23',
#   'pct',
#   'in',
#   'the',
#   'first',
#   'quarter',
#   'due',
#   'to',
#   'lower',
#   'oil',
#   'prices',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'department',
#   'said',
#   'first',
#   'quarter',
#   'exports',
#   'expanded',
#   'to',
#   '60',
#   '.',
#   '6',
#   'billion',
#   'baht',
#   'from',
#   '56',
#   '.',
#   '6',
#   'billion',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Export',
#   'growth',
#   'was',
#   'smaller',
#   'than',
#   'expected',
#   'due',
#   'to',
#   'lower',
#   'earnings',
#   'from',
#   'many',
#   'key',
#   'commodities',
#   'including',
#   'rice',
#   'whose',
#   'earnings',
#   'declined',
#   '18',
#   'pct',
#   ',',
#   'maize',
#   '66',
#   'pct',
#   ',',
#   'sugar',
#   '45',
#   'pct',
#   ',',
#   'tin',
#   '26',
#   'pct',
#   'and',
#   'canned',
#   'pineapples',
#   'seven',
#   'pct',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Products',
#   'registering',
#   'high',
#   'export',
#   'growth',
#   'were',
#   'jewellery',
#   'up',
#   '64',
#   'pct',
#   ',',
#   'clothing',
#   '57',
#   'pct',
#   'and',
#   'rubber',
#   '35',
#   'pct',
#   '.',
#   '</s>'],
#  ['<s>',
#   'INDONESIA',
#   'SEES',
#   'CPO',
#   'PRICE',
#   'RISING',
#   'SHARPLY',
#   'Indonesia',
#   'expects',
#   'crude',
#   'palm',
#   'oil',
#   '(',
#   'CPO',
#   ')',
#   'prices',
#   'to',
#   'rise',
#   'sharply',
#   'to',
#   'between',
#   '450',
#   'and',
#   '550',
#   'dlrs',
#   'a',
#   'tonne',
#   'FOB',
#   'sometime',
#   'this',
#   'year',
#   'because',
#   'of',
#   'better',
#   'European',
#   'demand',
#   'and',
#   'a',
#   'fall',
#   'in',
#   'Malaysian',
#   'output',
#   ',',
#   'Hasrul',
#   'Harahap',
#   ',',
#   'junior',
#   'minister',
#   'for',
#   'tree',
#   'crops',
#   ',',
#   'told',
#   'Indonesian',
#   'reporters',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Prices',
#   'of',
#   'Malaysian',
#   'and',
#   'Sumatran',
#   'CPO',
#   'are',
#   'now',
#   'around',
#   '332',
#   'dlrs',
#   'a',
#   'tonne',
#   'CIF',
#   'for',
#   'delivery',
#   'in',
#   'Rotterdam',
#   ',',
#   'traders',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Harahap',
#   'said',
#   'Indonesia',
#   'would',
#   'maintain',
#   'its',
#   'exports',
#   ',',
#   'despite',
#   'making',
#   'recent',
#   'palm',
#   'oil',
#   'purchases',
#   'from',
#   'Malaysia',
#   ',',
#   'so',
#   'that',
#   'it',
#   'could',
#   'possibly',
#   'increase',
#   'its',
#   'international',
#   'market',
#   'share',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Indonesia',
#   ',',
#   'the',
#   'world',
#   "'",
#   's',
#   'second',
#   'largest',
#   'producer',
#   'of',
#   'palm',
#   'oil',
#   'after',
#   'Malaysia',
#   ',',
#   'has',
#   'been',
#   'forced',
#   'to',
#   'import',
#   'palm',
#   'oil',
#   'to',
#   'ensure',
#   'supplies',
#   'during',
#   'the',
#   'Moslem',
#   'fasting',
#   'month',
#   'of',
#   'Ramadan',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Harahap',
#   'said',
#   'it',
#   'was',
#   'better',
#   'to',
#   'import',
#   'to',
#   'cover',
#   'a',
#   'temporary',
#   'shortage',
#   'than',
#   'to',
#   'lose',
#   'export',
#   'markets',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Indonesian',
#   'exports',
#   'of',
#   'CPO',
#   'in',
#   'calendar',
#   '1986',
#   'were',
#   '530',
#   ',',
#   '500',
#   'tonnes',
#   ',',
#   'against',
#   '468',
#   ',',
#   '500',
#   'in',
#   '1985',
#   ',',
#   'according',
#   'to',
#   'central',
#   'bank',
#   'figures',
#   '.',
#   '</s>'],
#  ['<s>',
#   'AUSTRALIAN',
#   'FOREIGN',
#   'SHIP',
#   'BAN',
#   'ENDS',
#   'BUT',
#   'NSW',
#   'PORTS',
#   'HIT',
#   'Tug',
#   'crews',
#   'in',
#   'New',
#   'South',
#   'Wales',
#   '(',
#   'NSW',
#   '),',
#   'Victoria',
#   'and',
#   'Western',
#   'Australia',
#   'yesterday',
#   'lifted',
#   'their',
#   'ban',
#   'on',
#   'foreign',
#   '-',
#   'flag',
#   'ships',
#   'carrying',
#   'containers',
#   'but',
#   'NSW',
#   'ports',
#   'are',
#   'still',
#   'being',
#   'disrupted',
#   'by',
#   'a',
#   'separate',
#   'dispute',
#   ',',
#   'shipping',
#   'sources',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'ban',
#   ',',
#   'imposed',
#   'a',
#   'week',
#   'ago',
#   'over',
#   'a',
#   'pay',
#   'claim',
#   ',',
#   'had',
#   'prevented',
#   'the',
#   'movement',
#   'in',
#   'or',
#   'out',
#   'of',
#   'port',
#   'of',
#   'nearly',
#   '20',
#   'vessels',
#   ',',
#   'they',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'pay',
#   'dispute',
#   'went',
#   'before',
#   'a',
#   'hearing',
#   'of',
#   'the',
#   'Arbitration',
#   'Commission',
#   'today',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Meanwhile',
#   ',',
#   'disruption',
#   'began',
#   'today',
#   'to',
#   'cargo',
#   'handling',
#   'in',
#   'the',
#   'ports',
#   'of',
#   'Sydney',
#   ',',
#   'Newcastle',
#   'and',
#   'Port',
#   'Kembla',
#   ',',
#   'they',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'industrial',
#   'action',
#   'at',
#   'the',
#   'NSW',
#   'ports',
#   'is',
#   'part',
#   'of',
#   'the',
#   'week',
#   'of',
#   'action',
#   'called',
#   'by',
#   'the',
#   'NSW',
#   'Trades',
#   'and',
#   'Labour',
#   'Council',
#   'to',
#   'protest',
#   'changes',
#   'to',
#   'the',
#   'state',
#   "'",
#   's',
#   'workers',
#   "'",
#   'compensation',
#   'laws',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'shipping',
#   'sources',
#   'said',
#   'the',
#   'various',
#   'port',
#   'unions',
#   'appear',
#   'to',
#   'be',
#   'taking',
#   'it',
#   'in',
#   'turn',
#   'to',
#   'work',
#   'for',
#   'a',
#   'short',
#   'time',
#   'at',
#   'the',
#   'start',
#   'of',
#   'each',
#   'shift',
#   'and',
#   'then',
#   'to',
#   'walk',
#   'off',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Cargo',
#   'handling',
#   'in',
#   'the',
#   'ports',
#   'has',
#   'been',
#   'disrupted',
#   ',',
#   'with',
#   'container',
#   'movements',
#   'most',
#   'affected',
#   ',',
#   'but',
#   'has',
#   'not',
#   'stopped',
#   'altogether',
#   ',',
#   'they',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'They',
#   'said',
#   'they',
#   'could',
#   'not',
#   'say',
#   'how',
#   'long',
#   'the',
#   'disruption',
#   'will',
#   'go',
#   'on',
#   'and',
#   'what',
#   'effect',
#   'it',
#   'will',
#   'have',
#   'on',
#   'shipping',
#   'movements',
#   '.',
#   '</s>'],
#  ['<s>',
#   'INDONESIAN',
#   'COMMODITY',
#   'EXCHANGE',
#   'MAY',
#   'EXPAND',
#   'The',
#   'Indonesian',
#   'Commodity',
#   'Exchange',
#   'is',
#   'likely',
#   'to',
#   'start',
#   'trading',
#   'in',
#   'at',
#   'least',
#   'one',
#   'new',
#   'commodity',
#   ',',
#   'and',
#   'possibly',
#   'two',
#   ',',
#   'during',
#   'calendar',
#   '1987',
#   ',',
#   'exchange',
#   'chairman',
#   'Paian',
#   'Nainggolan',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'He',
#   'told',
#   'Reuters',
#   'in',
#   'a',
#   'telephone',
#   'interview',
#   'that',
#   'trading',
#   'in',
#   'palm',
#   'oil',
#   ',',
#   'sawn',
#   'timber',
#   ',',
#   'pepper',
#   'or',
#   'tobacco',
#   'was',
#   'being',
#   'considered',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Trading',
#   'in',
#   'either',
#   'crude',
#   'palm',
#   'oil',
#   '(',
#   'CPO',
#   ')',
#   'or',
#   'refined',
#   'palm',
#   'oil',
#   'may',
#   'also',
#   'be',
#   'introduced',
#   '.',
#   '</s>'],
#  ['<s>',
#   'But',
#   'he',
#   'said',
#   'the',
#   'question',
#   'was',
#   'still',
#   'being',
#   'considered',
#   'by',
#   'Trade',
#   'Minister',
#   'Rachmat',
#   'Saleh',
#   'and',
#   'no',
#   'decision',
#   'on',
#   'when',
#   'to',
#   'go',
#   'ahead',
#   'had',
#   'been',
#   'made',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'fledgling',
#   'exchange',
#   'currently',
#   'trades',
#   'coffee',
#   'and',
#   'rubber',
#   'physicals',
#   'on',
#   'an',
#   'open',
#   'outcry',
#   'system',
#   'four',
#   'days',
#   'a',
#   'week',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'Several',
#   'factors',
#   'make',
#   'us',
#   'move',
#   'cautiously',
#   ',"',
#   'Nainggolan',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'We',
#   'want',
#   'to',
#   'move',
#   'slowly',
#   'and',
#   'safely',
#   'so',
#   'that',
#   'we',
#   'do',
#   'not',
#   'make',
#   'a',
#   'mistake',
#   'and',
#   'undermine',
#   'confidence',
#   'in',
#   'the',
#   'exchange',
#   '."',
#   '</s>'],
#  ['<s>',
#   'Physical',
#   'rubber',
#   'trading',
#   'was',
#   'launched',
#   'in',
#   '1985',
#   ',',
#   'with',
#   'coffee',
#   'added',
#   'in',
#   'January',
#   '1986',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Rubber',
#   'contracts',
#   'are',
#   'traded',
#   'FOB',
#   ',',
#   'up',
#   'to',
#   'five',
#   'months',
#   'forward',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Robusta',
#   'coffee',
#   'grades',
#   'four',
#   'and',
#   'five',
#   'are',
#   'traded',
#   'for',
#   'prompt',
#   'delivery',
#   'and',
#   'up',
#   'to',
#   'five',
#   'months',
#   'forward',
#   ',',
#   'exchange',
#   'officials',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'trade',
#   'ministry',
#   'and',
#   'exchange',
#   'board',
#   'are',
#   'considering',
#   'the',
#   'introduction',
#   'of',
#   'futures',
#   'trading',
#   'later',
#   'for',
#   'rubber',
#   ',',
#   'but',
#   'one',
#   'official',
#   'said',
#   'a',
#   'feasibility',
#   'study',
#   'was',
#   'needed',
#   'first',
#   '.',
#   '</s>'],
#  ['<s>',
#   'No',
#   'decisions',
#   'are',
#   'likely',
#   'until',
#   'after',
#   'Indonesia',
#   "'",
#   's',
#   'elections',
#   'on',
#   'April',
#   '23',
#   ',',
#   'traders',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Trade',
#   'Minister',
#   'Saleh',
#   'said',
#   'on',
#   'Monday',
#   'that',
#   'Indonesia',
#   ',',
#   'as',
#   'the',
#   'world',
#   "'",
#   's',
#   'second',
#   'largest',
#   'producer',
#   'of',
#   'natural',
#   'rubber',
#   ',',
#   'should',
#   'expand',
#   'its',
#   'rubber',
#   'marketing',
#   'effort',
#   'and',
#   'he',
#   'hoped',
#   'development',
#   'of',
#   'the',
#   'exchange',
#   'would',
#   'help',
#   'this',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Nainggolan',
#   'said',
#   'that',
#   'the',
#   'exchange',
#   'was',
#   'trying',
#   'to',
#   'boost',
#   'overseas',
#   'interest',
#   'by',
#   'building',
#   'up',
#   'contacts',
#   'with',
#   'end',
#   '-',
#   'users',
#   '.',
#   '</s>'],
#  ['<s>',
#   'He',
#   'said',
#   'teams',
#   'had',
#   'already',
#   'been',
#   'to',
#   'South',
#   'Korea',
#   'and',
#   'Taiwan',
#   'to',
#   'encourage',
#   'direct',
#   'use',
#   'of',
#   'the',
#   'exchange',
#   ',',
#   'while',
#   'a',
#   'delegation',
#   'would',
#   'also',
#   'visit',
#   'Europe',
#   ',',
#   'Mexico',
#   'and',
#   'some',
#   'Latin',
#   'American',
#   'states',
#   'to',
#   'encourage',
#   'participation',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Officials',
#   'say',
#   'the',
#   'infant',
#   'exchange',
#   'has',
#   'made',
#   'a',
#   'good',
#   'start',
#   'although',
#   'trading',
#   'in',
#   'coffee',
#   'has',
#   'been',
#   'disappointing',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Transactions',
#   'in',
#   'rubber',
#   'between',
#   'the',
#   'start',
#   'of',
#   'trading',
#   'in',
#   'April',
#   '1985',
#   'and',
#   'December',
#   '1986',
#   'totalled',
#   '9',
#   ',',
#   '595',
#   'tonnes',
#   ',',
#   'worth',
#   '6',
#   '.',
#   '9',
#   'mln',
#   'dlrs',
#   'FOB',
#   ',',
#   'plus',
#   '184',
#   '.',
#   '3',
#   'mln',
#   'rupiah',
#   'for',
#   'rubber',
#   'delivered',
#   'locally',
#   ',',
#   'the',
#   'latest',
#   'exchange',
#   'report',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Trading',
#   'in',
#   'coffee',
#   'in',
#   'calendar',
#   '1986',
#   'amounted',
#   'to',
#   'only',
#   '1',
#   ',',
#   '905',
#   'tonnes',
#   'in',
#   '381',
#   'lots',
#   ',',
#   'valued',
#   'at',
#   '6',
#   '.',
#   '87',
#   'billion',
#   'rupiah',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Total',
#   'membership',
#   'of',
#   'the',
#   'exchange',
#   'is',
#   'now',
#   'nine',
#   'brokers',
#   'and',
#   '44',
#   'traders',
#   '.',
#   '</s>'],
#  ['<s>',
#   'SRI',
#   'LANKA',
#   'GETS',
#   'USDA',
#   'APPROVAL',
#   'FOR',
#   'WHEAT',
#   'PRICE',
#   'Food',
#   'Department',
#   'officials',
#   'said',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Department',
#   'of',
#   'Agriculture',
#   'approved',
#   'the',
#   'Continental',
#   'Grain',
#   'Co',
#   'sale',
#   'of',
#   '52',
#   ',',
#   '500',
#   'tonnes',
#   'of',
#   'soft',
#   'wheat',
#   'at',
#   '89',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Dlrs',
#   'a',
#   'tonne',
#   'C',
#   'and',
#   'F',
#   'from',
#   'Pacific',
#   'Northwest',
#   'to',
#   'Colombo',
#   '.',
#   '</s>'],
#  ['<s>',
#   'They',
#   'said',
#   'the',
#   'shipment',
#   'was',
#   'for',
#   'April',
#   '8',
#   'to',
#   '20',
#   'delivery',
#   '.',
#   '</s>'],
#  ['<s>',
#   'WESTERN',
#   'MINING',
#   'TO',
#   'OPEN',
#   'NEW',
#   'GOLD',
#   'MINE',
#   'IN',
#   'AUSTRALIA',
#   'Western',
#   'Mining',
#   'Corp',
#   'Holdings',
#   'Ltd',
#   '&',
#   'lt',
#   ';',
#   'WMNG',
#   '.',
#   'S',
#   '>',
#   '(',
#   'WMC',
#   ')',
#   'said',
#   'it',
#   'will',
#   'establish',
#   'a',
#   'new',
#   'joint',
#   'venture',
#   'gold',
#   'mine',
#   'in',
#   'the',
#   'Northern',
#   'Territory',
#   'at',
#   'a',
#   'cost',
#   'of',
#   'about',
#   '21',
#   'mln',
#   'dlrs',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'mine',
#   ',',
#   'to',
#   'be',
#   'known',
#   'as',
#   'the',
#   'Goodall',
#   'project',
#   ',',
#   'will',
#   'be',
#   'owned',
#   '60',
#   'pct',
#   'by',
#   'WMC',
#   'and',
#   '40',
#   'pct',
#   'by',
#   'a',
#   'local',
#   'W',
#   '.',
#   'R',
#   '.',
#   'Grace',
#   'and',
#   'Co',
#   '&',
#   'lt',
#   ';',
#   'GRA',
#   '>',
#   'unit',
#   '.',
#   '</s>'],
#  ['<s>',
#   'It',
#   'is',
#   'located',
#   '30',
#   'kms',
#   'east',
#   'of',
#   'the',
#   'Adelaide',
#   'River',
#   'at',
#   'Mt',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Bundey',
#   ',',
#   'WMC',
#   'said',
#   'in',
#   'a',
#   'statement',
#   'It',
#   'said',
#   'the',
#   'open',
#   '-',
#   'pit',
#   'mine',
#   ',',
#   'with',
#   'a',
#   'conventional',
#   'leach',
#   'treatment',
#   'plant',
#   ',',
#   'is',
#   'expected',
#   'to',
#   'produce',
#   'about',
#   '50',
#   ',',
#   '000',
#   'ounces',
#   'of',
#   'gold',
#   'in',
#   'its',
#   'first',
#   'year',
#   'of',
#   'production',
#   'from',
#   'mid',
#   '-',
#   '1988',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Annual',
#   'ore',
#   'capacity',
#   'will',
#   'be',
#   'about',
#   '750',
#   ',',
#   '000',
#   'tonnes',
#   '.',
#   '</s>'],
#  ['<s>',
#   'SUMITOMO',
#   'BANK',
#   'AIMS',
#   'AT',
#   'QUICK',
#   'RECOVERY',
#   'FROM',
#   'MERGER',
#   'Sumitomo',
#   'Bank',
#   'Ltd',
#   '&',
#   'lt',
#   ';',
#   'SUMI',
#   '.',
#   'T',
#   '>',
#   'is',
#   'certain',
#   'to',
#   'lose',
#   'its',
#   'status',
#   'as',
#   'Japan',
#   "'",
#   's',
#   'most',
#   'profitable',
#   'bank',
#   'as',
#   'a',
#   'result',
#   'of',
#   'its',
#   'merger',
#   'with',
#   'the',
#   'Heiwa',
#   'Sogo',
#   'Bank',
#   ',',
#   'financial',
#   'analysts',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Osaka',
#   '-',
#   'based',
#   'Sumitomo',
#   ',',
#   'with',
#   'desposits',
#   'of',
#   'around',
#   '23',
#   '.',
#   '9',
#   'trillion',
#   'yen',
#   ',',
#   'merged',
#   'with',
#   'Heiwa',
#   'Sogo',
#   ',',
#   'a',
#   'small',
#   ',',
#   'struggling',
#   'bank',
#   'with',
#   'an',
#   'estimated',
#   '1',
#   '.',
#   '29',
#   'billion',
#   'dlrs',
#   'in',
#   'unrecoverable',
#   'loans',
#   ',',
#   'in',
#   'October',
#   '.',
#   '</s>'],
#  ['<s>',
#   'But',
#   'despite',
#   'the',
#   'link',
#   '-',
#   'up',
#   ',',
#   'Sumitomo',
#   'President',
#   'Koh',
#   'Komatsu',
#   'told',
#   'Reuters',
#   'he',
#   'is',
#   'confident',
#   'his',
#   'bank',
#   'can',
#   'quickly',
#   'regain',
#   'its',
#   'position',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'We',
#   "'",
#   'll',
#   'be',
#   'back',
#   'in',
#   'position',
#   'in',
#   'first',
#   'place',
#   'within',
#   'three',
#   'years',
#   ',"',
#   'Komatsu',
#   'said',
#   'in',
#   'an',
#   'interview',
#   '.',
#   '</s>'],
#  ['<s>',
#   'He',
#   'said',
#   'that',
#   'while',
#   'the',
#   'merger',
#   'will',
#   'initially',
#   'reduce',
#   'Sumitomo',
#   "'",
#   's',
#   'profitability',
#   'and',
#   'efficiency',
#   ',',
#   'it',
#   'will',
#   'vastly',
#   'expand',
#   'Sumitomo',
#   "'",
#   's',
#   'branch',
#   'network',
#   'in',
#   'the',
#   'Tokyo',
#   'metropolitan',
#   'area',
#   'where',
#   'it',
#   'has',
#   'been',
#   'relatively',
#   'weak',
#   '.',
#   '</s>'],
#  ['<s>',
#   'But',
#   'financial',
#   'analysts',
#   'are',
#   'divided',
#   'on',
#   'whether',
#   'and',
#   'how',
#   'quickly',
#   'the',
#   'gamble',
#   'will',
#   'pay',
#   'off',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Some',
#   'said',
#   'Sumitomo',
#   'may',
#   'have',
#   'paid',
#   'too',
#   'much',
#   'for',
#   'Heiwa',
#   'Sogo',
#   'in',
#   'view',
#   'of',
#   'the',
#   'smaller',
#   'bank',
#   "'",
#   's',
#   'large',
#   'debts',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Others',
#   'argue',
#   'the',
#   'merger',
#   'was',
#   'more',
#   'cost',
#   'effective',
#   'than',
#   'creating',
#   'a',
#   'comparable',
#   'branch',
#   'network',
#   'from',
#   'scratch',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'analysts',
#   'agreed',
#   'the',
#   'bank',
#   'was',
#   'aggressive',
#   '.',
#   '</s>'],
#  ['<s>',
#   'It',
#   'has',
#   'expanded',
#   'overseas',
#   ',',
#   'entered',
#   'the',
#   'lucrative',
#   'securities',
#   'business',
#   'and',
#   'geared',
#   'up',
#   'for',
#   'domestic',
#   'competition',
#   ',',
#   'but',
#   'they',
#   'questioned',
#   'the',
#   'wisdom',
#   'of',
#   'some',
#   'of',
#   'those',
#   'moves',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'They',
#   "'",
#   've',
#   'made',
#   'bold',
#   'moves',
#   'to',
#   'put',
#   'everything',
#   'in',
#   'place',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Now',
#   'it',
#   "'",
#   's',
#   'largely',
#   'out',
#   'of',
#   'their',
#   'hands',
#   ',"',
#   'said',
#   'Kleinwort',
#   'Benson',
#   'Ltd',
#   'financial',
#   'analyst',
#   'Simon',
#   'Smithson',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Among',
#   'Sumitomo',
#   "'",
#   's',
#   'problems',
#   'are',
#   'limits',
#   'placed',
#   'on',
#   'its',
#   'move',
#   'to',
#   'enter',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Securities',
#   'business',
#   'by',
#   'taking',
#   'a',
#   'share',
#   'in',
#   'American',
#   'investment',
#   'bank',
#   'Goldman',
#   ',',
#   'Sachs',
#   'and',
#   'Co',
#   '.',
#   'Sumitomo',
#   'last',
#   'August',
#   'agreed',
#   'to',
#   'pay',
#   '500',
#   'mln',
#   'dlrs',
#   'for',
#   'a',
#   '12',
#   '.',
#   '5',
#   'pct',
#   'limited',
#   'partnership',
#   'in',
#   'the',
#   'bank',
#   ',',
#   'but',
#   'for',
#   'the',
#   'time',
#   'being',
#   'at',
#   'least',
#   ',',
#   'the',
#   'Federal',
#   'Reserve',
#   'Board',
#   'has',
#   'forbidden',
#   'them',
#   'to',
#   'exchange',
#   'personnel',
#   ',',
#   'or',
#   'increase',
#   'the',
#   'business',
#   'they',
#   'do',
#   'with',
#   'each',
#   'other',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'The',
#   'tie',
#   '-',
#   'up',
#   'is',
#   'widely',
#   'looked',
#   'on',
#   'as',
#   'a',
#   'lame',
#   'duck',
#   'because',
#   'the',
#   'Fed',
#   'was',
#   'stricter',
#   'than',
#   'Sumitomo',
#   'expected',
#   ',"',
#   'said',
#   'one',
#   'analyst',
#   '.',
#   '</s>'],
#  ['<s>',
#   'But',
#   'Komatsu',
#   'said',
#   'the',
#   'move',
#   'will',
#   'pay',
#   'off',
#   'in',
#   'time',
#   '.',
#   '</s>'],
#  ['<s>', '"', 'U', '.', 'S', '.', '</s>'],
#  ['<s>',
#   'Regulations',
#   'will',
#   'change',
#   'in',
#   'the',
#   'near',
#   'future',
#   'and',
#   'if',
#   'so',
#   ',',
#   'we',
#   'can',
#   'do',
#   'various',
#   'things',
#   '.',
#   '</s>'],
#  ['<s>',
#   'We',
#   'only',
#   'have',
#   'to',
#   'wait',
#   'two',
#   'or',
#   'three',
#   'years',
#   ',',
#   'not',
#   'until',
#   'the',
#   '21st',
#   'century',
#   ',"',
#   'Komatsu',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Komatsu',
#   'is',
#   'also',
#   'willing',
#   'to',
#   'be',
#   'patient',
#   'about',
#   'possible',
#   'routes',
#   'into',
#   'the',
#   'securities',
#   'business',
#   'at',
#   'home',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Article',
#   '65',
#   'of',
#   'the',
#   'Securities',
#   'and',
#   'Exchange',
#   'Act',
#   ',',
#   'Japan',
#   "'",
#   's',
#   'version',
#   'of',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Glass',
#   '-',
#   'Steagall',
#   'Act',
#   ',',
#   'separates',
#   'commercial',
#   'from',
#   'investment',
#   'banking',
#   '.',
#   '</s>'],
#  ['<s>',
#   'But',
#   'the',
#   'walls',
#   'between',
#   'the',
#   'two',
#   'are',
#   'crumbling',
#   'and',
#   'Komatsu',
#   'said',
#   'he',
#   'hopes',
#   'further',
#   'deregulation',
#   'will',
#   'create',
#   'new',
#   'opportunities',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'We',
#   'need',
#   'to',
#   'find',
#   'new',
#   'business',
#   'chances',
#   ',"',
#   'Komatsu',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'In',
#   'some',
#   'cases',
#   'these',
#   'will',
#   'be',
#   'securities',
#   'related',
#   ',',
#   'in',
#   'some',
#   'cases',
#   'trust',
#   'bank',
#   'related',
#   '.',
#   '</s>'],
#  ['<s>',
#   'That',
#   "'",
#   's',
#   'the',
#   'kind',
#   'of',
#   'deregulation',
#   'we',
#   'want',
#   '."',
#   '</s>'],
#  ['<s>',
#   'Until',
#   'such',
#   'changes',
#   'occur',
#   ',',
#   'Sumitomo',
#   'will',
#   'focus',
#   'on',
#   'such',
#   'domestic',
#   'securities',
#   'business',
#   'as',
#   'profitable',
#   'government',
#   'bond',
#   'dealing',
#   'and',
#   'strengthening',
#   'relations',
#   'with',
#   'Meiko',
#   'Securities',
#   'Co',
#   'Ltd',
#   ',',
#   'in',
#   'which',
#   'it',
#   'holds',
#   'a',
#   'five',
#   'pct',
#   'share',
#   ',',
#   'Komatsu',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'He',
#   'said',
#   'Sumitomo',
#   'is',
#   'cautiously',
#   'optimistic',
#   'about',
#   'entering',
#   'the',
#   'securities',
#   'business',
#   'here',
#   'through',
#   'its',
#   'Swiss',
#   'universal',
#   'bank',
#   'subsidiary',
#   ',',
#   'Banca',
#   'del',
#   'Gottardo',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'Finance',
#   'Ministry',
#   'is',
#   'expected',
#   'to',
#   'grant',
#   'licences',
#   'to',
#   'securities',
#   'subsidiaries',
#   'of',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Commercial',
#   'banks',
#   'soon',
#   ',',
#   'following',
#   'a',
#   'similar',
#   'decision',
#   'for',
#   'subsidiaries',
#   'of',
#   'European',
#   'universal',
#   'banks',
#   'in',
#   'which',
#   'the',
#   'parent',
#   'holds',
#   'a',
#   'less',
#   'than',
#   '50',
#   'pct',
#   '.',
#   '</s>'],
#  ['<s>',
#   'But',
#   'Komatsu',
#   'is',
#   'reluctant',
#   'to',
#   'push',
#   'hard',
#   'for',
#   'a',
#   'similar',
#   'decision',
#   'on',
#   'a',
#   'Gottardo',
#   'subsidiary',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'We',
#   'don',
#   "'",
#   't',
#   'want',
#   'to',
#   'make',
#   'waves',
#   '.',
#   '</s>'],
#  ['<s>',
#   'We',
#   'expect',
#   'this',
#   'will',
#   'be',
#   'allowed',
#   'in',
#   'two',
#   'or',
#   'three',
#   'years',
#   ',"',
#   'he',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Like',
#   'other',
#   'city',
#   'banks',
#   ',',
#   'Sumitomo',
#   'is',
#   'also',
#   'pushing',
#   'to',
#   'expand',
#   'lending',
#   'to',
#   'individuals',
#   'and',
#   'small',
#   'and',
#   'medium',
#   'businesses',
#   'to',
#   'replace',
#   'disappearing',
#   'demand',
#   'from',
#   'big',
#   'business',
#   ',',
#   'he',
#   'added',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'analysts',
#   'said',
#   'Sumitomo',
#   'will',
#   'have',
#   'to',
#   'devote',
#   'a',
#   'lot',
#   'of',
#   'time',
#   'to',
#   'digesting',
#   'its',
#   'most',
#   'recent',
#   'initiatives',
#   ',',
#   'including',
#   'the',
#   'merger',
#   'with',
#   'ailing',
#   'Heiwa',
#   'Sogo',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'It',
#   "'",
#   's',
#   '(',
#   'Sumitomo',
#   ')',
#   'been',
#   'bold',
#   'in',
#   'its',
#   'strategies',
#   ',"',
#   'said',
#   'Kleinwort',
#   "'",
#   's',
#   'Smithson',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'After',
#   'that',
#   ',',
#   'it',
#   "'",
#   's',
#   'a',
#   'question',
#   'of',
#   'absorbing',
#   'and',
#   'juggling',
#   'around',
#   '.',
#   '</s>'],
#  ['<s>',
#   'It',
#   'will',
#   'be',
#   'the',
#   'next',
#   'decade',
#   'before',
#   'we',
#   'see',
#   'if',
#   'the',
#   'strategy',
#   'is',
#   'right',
#   'or',
#   'wrong',
#   '."',
#   '</s>'],
#  ['<s>',
#   'SUBROTO',
#   'SAYS',
#   'INDONESIA',
#   'SUPPORTS',
#   'TIN',
#   'PACT',
#   'EXTENSION',
#   'Mines',
#   'and',
#   'Energy',
#   'Minister',
#   'Subroto',
#   'confirmed',
#   'Indonesian',
#   'support',
#   'for',
#   'an',
#   'extension',
#   'of',
#   'the',
#   'sixth',
#   'International',
#   'Tin',
#   'Agreement',
#   '(',
#   'ITA',
#   '),',
#   'but',
#   'said',
#   'a',
#   'new',
#   'pact',
#   'was',
#   'not',
#   'necessary',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Asked',
#   'by',
#   'Reuters',
#   'to',
#   'clarify',
#   'his',
#   'statement',
#   'on',
#   'Monday',
#   'in',
#   'which',
#   'he',
#   'said',
#   'the',
#   'pact',
#   'should',
#   'be',
#   'allowed',
#   'to',
#   'lapse',
#   ',',
#   'Subroto',
#   'said',
#   'Indonesia',
#   'was',
#   'ready',
#   'to',
#   'back',
#   'extension',
#   'of',
#   'the',
#   'ITA',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'We',
#   'can',
#   'support',
#   'extension',
#   'of',
#   'the',
#   'sixth',
#   'agreement',
#   ',"',
#   'he',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'But',
#   'a',
#   'seventh',
#   'accord',
#   'we',
#   'believe',
#   'to',
#   'be',
#   'unnecessary',
#   '."',
#   '</s>'],
#  ['<s>',
#   'The',
#   'sixth',
#   'ITA',
#   'will',
#   'expire',
#   'at',
#   'the',
#   'end',
#   'of',
#   'June',
#   'unless',
#   'a',
#   'two',
#   '-',
#   'thirds',
#   'majority',
#   'of',
#   'members',
#   'vote',
#   'for',
#   'an',
#   'extension',
#   '.',
#   '</s>'],
#  ['<s>',
#   'BUNDESBANK',
#   'ALLOCATES',
#   '6',
#   '.',
#   '1',
#   'BILLION',
#   'MARKS',
#   'IN',
#   'TENDER',
#   'The',
#   'Bundesbank',
#   'accepted',
#   'bids',
#   'for',
#   '6',
#   '.',
#   '1',
#   'billion',
#   'marks',
#   'at',
#   'today',
#   "'",
#   's',
#   'tender',
#   'for',
#   'a',
#   '28',
#   '-',
#   'day',
#   'securities',
#   'repurchase',
#   'pact',
#   'at',
#   'a',
#   'fixed',
#   'rate',
#   'of',
#   '3',
#   '.',
#   '80',
#   'pct',
#   ',',
#   'a',
#   'central',
#   'bank',
#   'spokesman',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Banks',
#   ',',
#   'which',
#   'bid',
#   'for',
#   'a',
#   'total',
#   '12',
#   '.',
#   '2',
#   'billion',
#   'marks',
#   'liquidity',
#   ',',
#   'will',
#   'be',
#   'credited',
#   'with',
#   'the',
#   'funds',
#   'allocated',
#   'today',
#   'and',
#   'must',
#   'buy',
#   'back',
#   'securities',
#   'pledged',
#   'on',
#   'May',
#   '6',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Some',
#   '14',
#   '.',
#   '9',
#   'billion',
#   'marks',
#   'will',
#   'drain',
#   'from',
#   'the',
#   'market',
#   'today',
#   'as',
#   'an',
#   'earlier',
#   'pact',
#   'expires',
#   ',',
#   'so',
#   'the',
#   'Bundesbank',
#   'is',
#   'effectively',
#   'withdrawing',
#   'a',
#   'net',
#   '8',
#   '.',
#   '1',
#   'billion',
#   'marks',
#   'from',
#   'the',
#   'market',
#   'with',
#   'today',
#   "'",
#   's',
#   'allocation',
#   '.',
#   '</s>'],
#  ['<s>',
#   'A',
#   'Bundesbank',
#   'spokesman',
#   'said',
#   'in',
#   'answer',
#   'to',
#   'enquiries',
#   'that',
#   'the',
#   'withdrawal',
#   'of',
#   'funds',
#   'did',
#   'not',
#   'reflect',
#   'a',
#   'tightening',
#   'of',
#   'credit',
#   'policy',
#   ',',
#   'but',
#   'was',
#   'to',
#   'be',
#   'seen',
#   'in',
#   'the',
#   'context',
#   'of',
#   'plentiful',
#   'liquidity',
#   'in',
#   'the',
#   'banking',
#   'system',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Banks',
#   'held',
#   'an',
#   'average',
#   '59',
#   '.',
#   '3',
#   'billion',
#   'marks',
#   'at',
#   'the',
#   'Bundesbank',
#   'over',
#   'the',
#   'first',
#   'six',
#   'days',
#   'of',
#   'the',
#   'month',
#   ',',
#   'well',
#   'clear',
#   'of',
#   'the',
#   'likely',
#   'April',
#   'minimum',
#   'reserve',
#   'requirement',
#   'of',
#   '51',
#   'billion',
#   'marks',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'Bundesbank',
#   'spokesman',
#   'noted',
#   'that',
#   'by',
#   'bidding',
#   'only',
#   '12',
#   '.',
#   '2',
#   'billion',
#   'marks',
#   ',',
#   'below',
#   'the',
#   'outgoing',
#   '14',
#   '.',
#   '9',
#   'billion',
#   ',',
#   'banks',
#   'themselves',
#   'had',
#   'shown',
#   'they',
#   'felt',
#   'they',
#   'had',
#   'plenty',
#   'of',
#   'liquidity',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Dealers',
#   'said',
#   'the',
#   'Bundesbank',
#   'is',
#   'keen',
#   'to',
#   'prevent',
#   'too',
#   'much',
#   'liquidity',
#   'accruing',
#   'in',
#   'the',
#   'market',
#   ',',
#   'as',
#   'that',
#   'would',
#   'blunt',
#   'the',
#   'effectiveness',
#   'of',
#   'the',
#   'security',
#   'repurchase',
#   'agreement',
#   ',',
#   'its',
#   'main',
#   'open',
#   '-',
#   'market',
#   'instrument',
#   'for',
#   'steering',
#   'market',
#   'interest',
#   'rates',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Two',
#   'further',
#   'pacts',
#   'are',
#   'likely',
#   'this',
#   'month',
#   'over',
#   'the',
#   'next',
#   'two',
#   'weeks',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'Bundesbank',
#   'is',
#   'currently',
#   'steering',
#   'call',
#   'money',
#   'between',
#   '3',
#   '.',
#   '6',
#   'and',
#   '3',
#   '.',
#   '8',
#   'pct',
#   ',',
#   'although',
#   'short',
#   '-',
#   'term',
#   'fluctuations',
#   'outside',
#   'that',
#   'range',
#   'are',
#   'possible',
#   ',',
#   'dealers',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'BOND',
#   'CORP',
#   'STILL',
#   'CONSIDERING',
#   'ATLAS',
#   'MINING',
#   'BAIL',
#   '-',
#   'OUT',
#   'Bond',
#   'Corp',
#   'Holdings',
#   'Ltd',
#   '&',
#   'lt',
#   ';',
#   'BONA',
#   '.',
#   'S',
#   '>',
#   'and',
#   'Atlas',
#   'Consolidated',
#   'Mining',
#   'and',
#   'Development',
#   'Corp',
#   '&',
#   'lt',
#   ';',
#   'ATLC',
#   '.',
#   'MN',
#   '>',
#   'are',
#   'still',
#   'holding',
#   'talks',
#   'on',
#   'a',
#   'bail',
#   '-',
#   'out',
#   'package',
#   'for',
#   'the',
#   'troubled',
#   'mining',
#   'firm',
#   ',',
#   'an',
#   'Atlas',
#   'statement',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Atlas',
#   ',',
#   'the',
#   'Philippines',
#   "'",
#   'biggest',
#   'copper',
#   'producer',
#   ',',
#   'said',
#   'it',
#   'had',
#   'been',
#   'hit',
#   'by',
#   'depressed',
#   'world',
#   'copper',
#   'prices',
#   '.',
#   '</s>'],
#  ['<s>',
#   'It',
#   'reported',
#   'a',
#   'net',
#   'loss',
#   'of',
#   '976',
#   '.',
#   '38',
#   'mln',
#   'pesos',
#   'in',
#   'the',
#   'year',
#   'ending',
#   'December',
#   '1986',
#   ',',
#   'compared',
#   'with',
#   'a',
#   'net',
#   'loss',
#   'of',
#   '1',
#   '.',
#   '53',
#   'billion',
#   'in',
#   '1985',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'company',
#   'said',
#   'it',
#   'had',
#   'been',
#   'able',
#   'to',
#   'cut',
#   'its',
#   'losses',
#   'because',
#   'its',
#   'scaled',
#   '-',
#   'down',
#   'copper',
#   'operations',
#   'in',
#   'the',
#   'central',
#   'island',
#   'of',
#   'Cebu',
#   'started',
#   'in',
#   'the',
#   'second',
#   'half',
#   'of',
#   '1986',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Atlas',
#   'said',
#   'negotiations',
#   'were',
#   'continuing',
#   'on',
#   'the',
#   'acquisition',
#   'by',
#   'Bond',
#   'of',
#   'the',
#   'company',
#   "'",
#   's',
#   'existing',
#   'bank',
#   'loans',
#   'and',
#   'their',
#   'restructuring',
#   'into',
#   'a',
#   'gold',
#   'loan',
#   '.',
#   '</s>'],
#  ['<s>',
#   'A',
#   'memorandum',
#   'of',
#   'understanding',
#   'signed',
#   'by',
#   'the',
#   'two',
#   'sides',
#   'in',
#   'October',
#   'last',
#   'year',
#   'said',
#   'Bond',
#   'would',
#   'acquire',
#   'Atlas',
#   "'",
#   'total',
#   'loans',
#   'of',
#   '275',
#   'mln',
#   'dlrs',
#   ',',
#   'to',
#   'be',
#   'repaid',
#   'by',
#   'the',
#   'mining',
#   'company',
#   'in',
#   'gold',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Atlas',
#   'said',
#   'the',
#   'two',
#   'sides',
#   'were',
#   'also',
#   'discussing',
#   'equity',
#   'infusion',
#   'into',
#   'Atlas',
#   'and',
#   'the',
#   'creation',
#   'of',
#   'a',
#   'development',
#   'fund',
#   'for',
#   'further',
#   'exploration',
#   'and',
#   'development',
#   'of',
#   'the',
#   'company',
#   "'",
#   's',
#   'gold',
#   'properties',
#   'in',
#   'the',
#   'central',
#   'province',
#   'of',
#   'Masbate',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Wilson',
#   'Banks',
#   ',',
#   'general',
#   'manager',
#   'of',
#   '&',
#   'lt',
#   ';',
#   'Bond',
#   'Corp',
#   'International',
#   'Ltd',
#   '>',
#   'in',
#   'Hong',
#   'Kong',
#   ',',
#   'told',
#   'Reuters',
#   'the',
#   'Atlas',
#   'statement',
#   'on',
#   'the',
#   'negotiations',
#   'was',
#   '"',
#   'reasonably',
#   'accurate',
#   '."',
#   '</s>'],
#  ['<s>',
#   'Banks',
#   'said',
#   'Bond',
#   'Corp',
#   'was',
#   'seriously',
#   'considering',
#   'several',
#   'investments',
#   'in',
#   'the',
#   'Philippines',
#   'but',
#   'did',
#   'not',
#   'give',
#   'details',
#   '.',
#   '</s>'],
#  ['<s>',
#   'In',
#   'its',
#   'statement',
#   ',',
#   'Atlas',
#   'said',
#   'development',
#   'of',
#   'the',
#   'pre',
#   '-',
#   'World',
#   'War',
#   'Two',
#   'underground',
#   'mines',
#   'in',
#   'Masbate',
#   'had',
#   'been',
#   'accelerated',
#   'and',
#   'the',
#   'ore',
#   'tonnage',
#   'had',
#   'increased',
#   ',',
#   'extending',
#   'the',
#   'operation',
#   "'",
#   's',
#   'life',
#   'at',
#   'least',
#   'until',
#   '1993',
#   '.',
#   '</s>'],
#  ['<s>',
#   'CHINA',
#   'INDUSTRIAL',
#   'OUTPUT',
#   'RISES',
#   'IN',
#   'FIRST',
#   'QUARTER',
#   'China',
#   "'",
#   's',
#   'industrial',
#   'output',
#   'rose',
#   '14',
#   '.',
#   '1',
#   'pct',
#   'in',
#   'the',
#   'first',
#   'quarter',
#   'of',
#   '1987',
#   'against',
#   'the',
#   'same',
#   '1986',
#   'period',
#   ',',
#   'the',
#   'People',
#   "'",
#   's',
#   'Daily',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Its',
#   'overseas',
#   'edition',
#   'said',
#   'the',
#   'growth',
#   'rate',
#   ',',
#   'which',
#   'compares',
#   'with',
#   'a',
#   'target',
#   'of',
#   'seven',
#   'pct',
#   'for',
#   'the',
#   'whole',
#   'of',
#   '1987',
#   ',',
#   'was',
#   '"',
#   'rather',
#   'high',
#   '"',
#   'but',
#   'the',
#   'base',
#   'in',
#   'the',
#   'first',
#   'quarter',
#   'of',
#   '1986',
#   'was',
#   'on',
#   'the',
#   'low',
#   'side',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Industrial',
#   'output',
#   'grew',
#   '4',
#   '.',
#   '4',
#   'pct',
#   'in',
#   'the',
#   'first',
#   'quarter',
#   'of',
#   '1986',
#   '.',
#   '</s>'],
#  ['<s>',
#   'It',
#   'said',
#   'China',
#   "'",
#   's',
#   'industrial',
#   'production',
#   'this',
#   'year',
#   'has',
#   'been',
#   'normal',
#   'but',
#   'product',
#   'quality',
#   'and',
#   'efficiency',
#   'need',
#   'further',
#   'improvement',
#   '.',
#   '</s>'],
#  ['<s>', 'It', 'gave', 'no', 'further', 'details', '.', '</s>'],
#  ['<s>',
#   'JAPAN',
#   'MINISTRY',
#   'SAYS',
#   'OPEN',
#   'FARM',
#   'TRADE',
#   'WOULD',
#   'HIT',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Japan',
#   "'",
#   's',
#   'Agriculture',
#   'Ministry',
#   ',',
#   'angered',
#   'by',
#   'U',
#   '.',
#   'S',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Demands',
#   'that',
#   'Japan',
#   'open',
#   'its',
#   'farm',
#   'products',
#   'market',
#   ',',
#   'will',
#   'tell',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Officials',
#   'at',
#   'talks',
#   'later',
#   'this',
#   'month',
#   'that',
#   'liberalisation',
#   'would',
#   'harm',
#   'existing',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Farm',
#   'exports',
#   'to',
#   'Japan',
#   ',',
#   'a',
#   'senior',
#   'ministry',
#   'official',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'Imports',
#   'from',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Would',
#   'drop',
#   'due',
#   'to',
#   'active',
#   'sales',
#   'drives',
#   'by',
#   'other',
#   'suppliers',
#   ',"',
#   'the',
#   'official',
#   ',',
#   'who',
#   'declined',
#   'to',
#   'be',
#   'named',
#   ',',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'Japan',
#   'is',
#   'the',
#   'largest',
#   'customer',
#   'for',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Farm',
#   'products',
#   'and',
#   'it',
#   'is',
#   'not',
#   'reasonable',
#   'for',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   'To',
#   'demand',
#   'Japan',
#   'liberalise',
#   'its',
#   'farm',
#   'import',
#   'market',
#   ',"',
#   'he',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Agriculture',
#   'Minister',
#   'Mutsuki',
#   'Kato',
#   'has',
#   'said',
#   'if',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Insists',
#   'Japan',
#   'open',
#   'its',
#   'protected',
#   'rice',
#   'market',
#   'it',
#   'will',
#   'also',
#   'open',
#   'its',
#   'wheat',
#   'market',
#   ',',
#   'where',
#   'volume',
#   'and',
#   'origin',
#   'are',
#   'regulated',
#   'to',
#   'protect',
#   'local',
#   'farmers',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Australia',
#   'and',
#   'Canada',
#   'could',
#   'then',
#   'increase',
#   'their',
#   'wheat',
#   'exports',
#   'as',
#   'they',
#   'are',
#   'more',
#   'competitive',
#   'than',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.,',
#   'He',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'End',
#   '-',
#   'users',
#   'would',
#   'also',
#   'buy',
#   'other',
#   'origins',
#   ',',
#   'grain',
#   'traders',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Agriculture',
#   'Secretary',
#   'Richard',
#   'Lyng',
#   ',',
#   'who',
#   'is',
#   'due',
#   'to',
#   'visit',
#   'Japan',
#   'for',
#   'talks',
#   'between',
# ...
#   'Cannon',
#   'Inc',
#   '&',
#   'lt',
#   ';',
#   'FLD',
#   '>,',
#   'the',
#   'result',
#   'of',
#   'a',
#   'merger',
#   'of',
#   'Fieldcrest',
#   'and',
#   'Cannon',
#   ',',
#   'rose',
#   '1',
#   '-',
#   '1',
#   '/',
#   '8',
#   'to',
#   '39',
#   '-',
#   '3',
#   '/',
#   '4',
#   '.',
#   '</s>'],
#  ['<s>',
#   'West',
#   'Point',
#   '-',
#   'Pepperell',
#   'Inc',
#   '&',
#   'lt',
#   ';',
#   'WPM',
#   '>',
#   'rose',
#   '1',
#   '-',
#   '7',
#   '/',
#   '8',
#   'to',
#   '67',
#   '-',
#   '1',
#   '/',
#   '8',
#   '.',
#   '</s>'],
#  ['<s>',
#   'STERIVET',
#   'LABORATORIES',
#   'LTD',
#   '&',
#   'lt',
#   ';',
#   'STVTF',
#   '>',
#   '1ST',
#   'QTR',
#   'NET',
#   'Shr',
#   'profit',
#   '10',
#   'cts',
#   'vs',
#   'loss',
#   '17',
#   'cts',
#   'Net',
#   'profit',
#   '206',
#   ',',
#   '000',
#   'vs',
#   'loss',
#   '281',
#   ',',
#   '000',
#   'Revs',
#   '1',
#   ',',
#   '022',
#   ',',
#   '00',
#   'vs',
#   '344',
#   ',',
#   '000',
#   '</s>'],
#  ['<s>',
#   'STERIVET',
#   'LABORATORIES',
#   'LTD',
#   '&',
#   'lt',
#   ';',
#   'STVTF',
#   '>',
#   'YEAR',
#   'LOSS',
#   'Shr',
#   'loss',
#   '48',
#   'cts',
#   'vs',
#   'loss',
#   '19',
#   'cts',
#   'Net',
#   'loss',
#   '746',
#   ',',
#   '000',
#   'vs',
#   'loss',
#   '342',
#   ',',
#   '000',
#   'Revs',
#   '3',
#   ',',
#   '213',
#   ',',
#   '000',
#   'vs',
#   '2',
#   ',',
#   '925',
#   ',',
#   '000',
#   '</s>'],
#  ['<s>',
#   'JAPAN',
#   'IN',
#   'LAST',
#   '-',
#   'DITCH',
#   'EFFORT',
#   'TO',
#   'AVERT',
#   'TARIFFS',
#   'Senior',
#   'Japanese',
#   'officials',
#   'tomorrow',
#   'open',
#   'talks',
#   'with',
#   'American',
#   'trade',
#   'negotiators',
#   'in',
#   'a',
#   'last',
#   '-',
#   'ditch',
#   'effort',
#   'to',
#   'avert',
#   'new',
#   'high',
#   'U',
#   '.',
#   'S',
#   '.',
#   'tariffs',
#   'to',
#   'be',
#   'imposed',
#   'on',
#   'a',
#   'wide',
#   'variety',
#   'of',
#   'Japanese',
#   'electronic',
#   'exports',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Makoto',
#   'Kuroda',
#   ',',
#   'vice',
#   'minister',
#   'of',
#   'Japan',
#   "'",
#   's',
#   'Ministry',
#   'of',
#   'International',
#   'Trade',
#   'and',
#   'Industry',
#   '(',
#   'MITI',
#   '),',
#   'is',
#   'to',
#   'hold',
#   'two',
#   'days',
#   'of',
#   'meetings',
#   'with',
#   'the',
#   'Deputy',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Trade',
#   'Representative',
#   ',',
#   'Michael',
#   'Smith',
#   ',',
#   'and',
#   'the',
#   'Under',
#   'Secretary',
#   'of',
#   'Commerce',
#   ',',
#   'Bruce',
#   'Smart',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'new',
#   'tariffs',
#   ',',
#   'to',
#   'go',
#   'into',
#   'effect',
#   'on',
#   'April',
#   '17',
#   ',',
#   'are',
#   'in',
#   'retaliation',
#   'for',
#   'Japan',
#   "'",
#   's',
#   'failure',
#   'to',
#   'adhere',
#   'to',
#   'an',
#   'agreement',
#   'to',
#   'end',
#   'dumping',
#   'semiconductors',
#   'in',
#   'world',
#   'markets',
#   'at',
#   'below',
#   'cost',
#   'and',
#   'to',
#   'open',
#   'its',
#   'home',
#   'market',
#   'to',
#   'U',
#   '.',
#   'S',
#   '.',
#   'semiconductor',
#   'shipments',
#   '.',
#   '</s>'],
#  ['<s>',
#   'They',
#   'are',
#   'to',
#   'be',
#   'imposed',
#   'on',
#   'goods',
#   'which',
#   'use',
#   'semiconductors',
#   ',',
#   'including',
#   'television',
#   'and',
#   'audio',
#   'equipment',
#   'and',
#   'computers',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Both',
#   'U',
#   '.',
#   'S',
#   '.',
#   'and',
#   'Japanese',
#   'officials',
#   'have',
#   'said',
#   'there',
#   'was',
#   'little',
#   'likelihood',
#   'the',
#   'talks',
#   'would',
#   'do',
#   'anything',
#   'to',
#   'avert',
#   'the',
#   '100',
#   'pct',
#   'duties',
#   'on',
#   '300',
#   'mln',
#   'dlrs',
#   'worth',
#   'of',
#   'Japanese',
#   'shipments',
#   '.',
#   '</s>'],
#  ['<s>',
#   'President',
#   'Reagan',
#   'announced',
#   'the',
#   'planned',
#   'tariffs',
#   'on',
#   'March',
#   '27',
#   'after',
#   'he',
#   'said',
#   'that',
#   'close',
#   'monitoring',
#   'of',
#   'the',
#   'July',
#   '1986',
#   'U',
#   '.',
#   'S',
#   '.-',
#   'Japanese',
#   'semiconductor',
#   'pact',
#   'convinced',
#   'U',
#   '.',
#   'S',
#   '.',
#   'officials',
#   'that',
#   'Japan',
#   'was',
#   'not',
#   'honoring',
#   'the',
#   'agreement',
#   '.',
#   '</s>'],
#  ['<s>',
#   'In',
#   'making',
#   'the',
#   'annoucement',
#   ',',
#   'Reagan',
#   'said',
#   '"',
#   'I',
#   'am',
#   'committed',
#   'to',
#   'the',
#   'full',
#   'enforcement',
#   'of',
#   'our',
#   'trade',
#   'agreements',
#   'designed',
#   'to',
#   'provide',
#   'American',
#   'industry',
#   'with',
#   'free',
#   'and',
#   'fair',
#   'trade',
#   '."',
#   '</s>'],
#  ['<s>',
#   'Trade',
#   'analysts',
#   'said',
#   'his',
#   'move',
#   'was',
#   'aimed',
#   'as',
#   'much',
#   'at',
#   'Japan',
#   "'",
#   's',
#   'semiconductor',
#   'trade',
#   'practices',
#   ',',
#   'which',
#   'are',
#   'said',
#   'to',
#   'have',
#   'injured',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   'semiconductor',
#   'industry',
#   ',',
#   'as',
#   'Congress',
#   ',',
#   'which',
#   'has',
#   'complained',
#   'about',
#   'presidential',
#   'timidity',
#   'on',
#   'trade',
#   'issues',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Congressional',
#   'Democrats',
#   'have',
#   'pledged',
#   'to',
#   'enact',
#   'aggressive',
#   'trade',
#   'laws',
#   'to',
#   'counter',
#   'what',
#   'they',
#   'contend',
#   'has',
#   'been',
#   'Reagan',
#   "'",
#   's',
#   'inaction',
#   'to',
#   'redress',
#   'the',
#   'growing',
#   'U',
#   '.',
#   'S',
#   '.',
#   'trade',
#   'deficit',
#   ',',
#   'which',
#   'last',
#   'year',
#   'reached',
#   '169',
#   '.',
#   '8',
#   'billion',
#   'dlrs',
#   '.',
#   '</s>'],
#  ['<s>',
#   'About',
#   'one',
#   '-',
#   'third',
#   'of',
#   'the',
#   'deficit',
#   'was',
#   'with',
#   'Japan',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Reagan',
#   'said',
#   'there',
#   'were',
#   'recent',
#   'signs',
#   'Japan',
#   'was',
#   'beginning',
#   'to',
#   'adhere',
#   'to',
#   'the',
#   'pact',
#   'and',
#   'that',
#   'was',
#   'why',
#   'he',
#   'was',
#   'not',
#   'terminating',
#   'it',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Kuroda',
#   'said',
#   'on',
#   'leaving',
#   'Tokyo',
#   'today',
#   'he',
#   'had',
#   'no',
#   'new',
#   'proposals',
#   'but',
#   'did',
#   'have',
#   'an',
#   'explanation',
#   'of',
#   'the',
#   'semiconductor',
#   'situation',
#   '.',
#   '</s>'],
#  ['<s>',
#   'He',
#   'told',
#   'the',
#   'daily',
#   'newspaper',
#   'Ashai',
#   'Shimbun',
#   'that',
#   'Reagan',
#   "'",
#   's',
#   'decision',
#   'was',
#   'based',
#   'on',
#   'inaccurate',
#   'data',
#   'and',
#   'an',
#   'exaggerated',
#   'sense',
#   'of',
#   'MITI',
#   "'",
#   's',
#   'power',
#   'to',
#   'control',
#   'Japanese',
#   'traders',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'The',
#   'United',
#   'States',
#   'has',
#   'excessive',
#   'expectations',
#   '.,"',
#   'he',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'To',
#   'stabilize',
#   'supply',
#   '-',
#   'demand',
#   'relations',
#   'which',
#   'have',
#   'been',
#   'disrupted',
#   'by',
#   'excess',
#   'inventories',
#   'since',
#   '1985',
#   'will',
#   'take',
#   'some',
#   'time',
#   '."',
#   '</s>'],
#  ['<s>',
#   'He',
#   'also',
#   'said',
#   'that',
#   'U',
#   '.',
#   'S',
#   '.',
#   'firms',
#   'had',
#   'not',
#   'been',
#   'aggressive',
#   'enough',
#   'in',
#   'trying',
#   'to',
#   'sell',
#   'in',
#   'the',
#   'Japanese',
#   'market',
#   '.',
#   '</s>'],
#  ['<s>',
#   'HOECHST',
#   'CELANESE',
#   'SENDS',
#   'REPORT',
#   'ON',
#   'NEW',
#   'FACILITIES',
#   '&',
#   'lt',
#   ';',
#   'Hoechst',
#   'Celanese',
#   'Corp',
#   '>',
#   'said',
#   'it',
#   'sent',
#   'propsective',
#   'customers',
#   'a',
#   'confidential',
#   'report',
#   'describing',
#   'its',
#   'polyester',
#   'textile',
#   'fiber',
#   'facilities',
#   'in',
#   'North',
#   'Carolina',
#   'and',
#   'South',
#   'Carolina',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'company',
#   'did',
#   'not',
#   'disclose',
#   'any',
#   'prices',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'report',
#   'describes',
#   'the',
#   'facilities',
#   'in',
#   'Darlington',
#   'County',
#   ',',
#   'S',
#   '.',
#   'C',
#   '.,',
#   'and',
#   'Fayetteville',
#   ',',
#   'N',
#   '.',
#   'C',
#   '.,',
#   'the',
#   'company',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'report',
#   'also',
#   'decribes',
#   'related',
#   'manufacturing',
#   ',',
#   'marketing',
#   ',',
#   'administrative',
#   'and',
#   'technical',
#   'resources',
#   'that',
#   'could',
#   'be',
#   'made',
#   'avialable',
#   'to',
#   'a',
#   'buyer',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Hoechst',
#   'Celanese',
#   'was',
#   'formed',
#   'Feb',
#   '27',
#   'by',
#   'the',
#   'merger',
#   'of',
#   'Celanese',
#   'Corp',
#   'and',
#   'American',
#   'Hoechst',
#   'Corp',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'merger',
#   'took',
#   'place',
#   'after',
#   'an',
#   'agreement',
#   'was',
#   'reached',
#   'with',
#   'the',
#   'Federal',
#   'Trade',
#   'Commission',
#   'that',
#   'certain',
#   'domestic',
#   'polyester',
#   'textile',
#   'fiber',
#   'assets',
#   'of',
#   'the',
#   'combined',
#   'companies',
#   'would',
#   'be',
#   'divested',
#   ',',
#   'it',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Hoechst',
#   'Celanese',
#   'said',
#   'it',
#   'has',
#   'the',
#   'option',
#   'of',
#   'divesting',
#   'either',
#   'the',
#   'South',
#   'Carolina',
#   'facilities',
#   'of',
#   'the',
#   'former',
#   'American',
#   'Hoechst',
#   'or',
#   'a',
#   'package',
#   'of',
#   'polyester',
#   'textile',
#   'fiber',
#   'facilities',
#   'of',
#   'the',
#   'former',
#   'Celanese',
#   '.',
#   '</s>'],
#  ['<s>',
#   'MELLON',
#   'PARTICIPATING',
#   'MORTGAGE',
#   'TRUST',
#   '&',
#   'lt',
#   ';',
#   'MPMTS',
#   '>',
#   'DIV',
#   'Qtly',
#   'div',
#   '25',
#   'cts',
#   'vs',
#   '25',
#   'cts',
#   'prior',
#   'Payable',
#   'May',
#   '6',
#   'Record',
#   'April',
#   '24',
#   '</s>'],
#  ['<s>',
#   'U',
#   '.',
#   'K',
#   '.',
#   'GEC',
#   'DECLINES',
#   'COMMENT',
#   'ON',
#   'U',
#   '.',
#   'S',
#   '.',
#   'PURCHASE',
#   'RUMOUR',
#   'General',
#   'Electric',
#   'Co',
#   'Plc',
#   '&',
#   'lt',
#   ';',
#   'GECL',
#   '.',
#   'L',
#   '>',
#   '(',
#   'GEC',
#   ')',
#   'declined',
#   'comment',
#   'on',
#   'rumours',
#   'on',
#   'the',
#   'London',
#   'stock',
#   'market',
#   'that',
#   'it',
#   'is',
#   'planning',
#   'another',
#   'purchase',
#   'in',
#   'the',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Medical',
#   'equipment',
#   'field',
#   ',',
#   'in',
#   'addition',
#   'to',
#   'its',
#   'existing',
#   'U',
#   '.',
#   'S',
#   '.',
#   'Subsidiary',
#   '&',
#   'lt',
#   ';',
#   'Picker',
#   'International',
#   'Inc',
#   '>.',
#   '</s>'],
#  ['<s>',
#   'A',
#   'GEC',
#   'spokesman',
#   'said',
#   'that',
#   'it',
#   'is',
#   'company',
#   'policy',
#   'not',
#   'to',
#   'comment',
#   'on',
#   'acquisition',
#   'rumours',
#   '.',
#   '</s>'],
#  ['<s>',
#   'Stock',
#   'Exchange',
#   'traders',
#   'said',
#   'the',
#   'rumour',
#   'helped',
#   'GEC',
#   "'",
#   's',
#   'share',
#   'price',
#   'to',
#   'rise',
#   '5p',
#   ',',
#   'to',
#   'a',
#   'final',
#   '206p',
#   'from',
#   'yesterday',
#   "'",
#   's',
#   'closing',
#   'price',
#   'of',
#   '201p',
#   '.',
#   '</s>'],
#  ['<s>',
#   'PRESTON',
#   'CORP',
#   '&',
#   'lt',
#   ';',
#   'PTRK',
#   '>',
#   'SEES',
#   'FIRST',
#   'QUARTER',
#   'LOSS',
#   'Preston',
#   'corp',
#   'said',
#   'it',
#   'expects',
#   'to',
#   'report',
#   'a',
#   'loss',
#   'of',
#   'about',
#   '300',
#   ',',
#   '000',
#   'dlrs',
#   'or',
#   'five',
#   'cts',
#   'per',
#   'share',
#   'for',
#   'the',
#   'first',
#   'quarter',
#   ',',
#   'compared',
#   'with',
#   'a',
#   'profit',
#   'of',
#   '1',
#   ',',
#   '081',
#   ',',
#   '000',
#   'dlrs',
#   'or',
#   '19',
#   'cts',
#   'per',
#   'share',
#   'a',
#   'year',
#   'before',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'trucking',
#   'company',
#   'attributed',
#   'the',
#   'loss',
#   'to',
#   'the',
#   'continued',
#   'rate',
#   'of',
#   'discounted',
#   'in',
#   'its',
#   'primary',
#   'markets',
#   ',',
#   'flat',
#   'revenues',
#   'and',
#   'increased',
#   'costs',
#   ',',
#   'including',
#   'uninsured',
#   'claims',
#   'expense',
#   'resulting',
#   'from',
#   'adverse',
#   'weather',
#   'conditions',
#   'during',
#   'the',
#   'last',
#   'three',
#   'months',
#   '.',
#   '</s>'],
#  ['<s>',
#   'It',
#   'said',
#   'results',
#   'outside',
#   'the',
#   'Northeast',
#   'were',
#   'strong',
#   ',',
#   'and',
#   'it',
#   'expects',
#   'to',
#   'show',
#   'improved',
#   'results',
#   'for',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'year',
#   '.',
#   '</s>'],
#  ['<s>',
#   'WHITE',
#   'HOUSE',
#   'STANDING',
#   'FIRM',
#   'ON',
#   'JAPANESE',
#   'SANCTIONS',
#   'Presidential',
#   'spokesman',
#   'Marlin',
#   'Fitzwater',
#   'said',
#   'U',
#   '.',
#   'S',
#   '.',
#   'trade',
#   'sanctions',
#   'against',
#   'Japan',
#   'were',
#   'likely',
#   'take',
#   'effect',
#   'on',
#   'April',
#   '17',
#   'in',
#   'spite',
#   'of',
#   'a',
#   '"',
#   'full',
#   'court',
#   'press',
#   '"',
#   'by',
#   'Japanese',
#   'officials',
#   'to',
#   'avoid',
#   'them',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'All',
#   'indications',
#   'are',
#   'they',
#   'will',
#   'take',
#   'effect',
#   ',"',
#   'he',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   '"',
#   'I',
#   'would',
#   'say',
#   'Japan',
#   'is',
#   'applying',
#   'the',
#   'full',
#   'court',
#   'press',
#   '...',
#   '</s>'],
#  ['<s>',
#   'They',
#   'certainly',
#   'are',
#   'putting',
#   'both',
#   'feet',
#   'forward',
#   'in',
#   'terms',
#   'of',
#   'explaining',
#   'their',
#   'position',
#   ',"',
#   'Fitzwater',
#   'told',
#   'reporters',
#   '.',
#   '</s>'],
#  ['<s>',
#   'He',
#   'noted',
#   'high',
#   'level',
#   'meetings',
#   'on',
#   'the',
#   'trade',
#   'dispute',
#   'are',
#   'underway',
#   'here',
#   'but',
#   'said',
#   ',',
#   '"',
#   'I',
#   'don',
#   "'",
#   't',
#   'think',
#   'there',
#   "'",
#   's',
#   'anything',
#   'I',
#   'can',
#   'report',
#   'and',
#   'I',
#   'don',
#   "'",
#   't',
#   'believe',
#   'there',
#   "'",
#   's',
#   'been',
#   'any',
#   'official',
#   'movement',
#   '."',
#   '</s>'],
#  ['<s>',
#   'DOW',
#   'JONES',
#   'AND',
#   'CO',
#   'INC',
#   'FIRST',
#   'QUARTER',
#   'SHR',
#   '69',
#   'CTS',
#   'VS',
#   '64',
#   'CTS',
#   '</s>'],
#  ['<s>',
#   'DOW',
#   'JONES',
#   'AND',
#   'CO',
#   'INC',
#   'FIRST',
#   'QUARTER',
#   'SHR',
#   '69',
#   'CTS',
#   'VS',
#   '64',
#   'CTS',
#   '</s>'],
#  ['<s>',
#   '&',
#   'lt',
#   ';',
#   'HAYES',
#   '-',
#   'DANA',
#   'INC',
#   '>',
#   '1ST',
#   'QTR',
#   'NET',
#   'Shr',
#   '30',
#   'cts',
#   'vs',
#   '28',
#   'cts',
#   'Net',
#   '5',
#   ',',
#   '000',
#   ',',
#   '000',
#   'vs',
#   '4',
#   ',',
#   '600',
#   ',',
#   '000',
#   'Revs',
#   '125',
#   '.',
#   '2',
#   'mln',
#   'vs',
#   '123',
#   '.',
#   '9',
#   'mln',
#   'Note',
#   ':',
#   '52',
#   'pct',
#   '-',
#   'owned',
#   'by',
#   'Dana',
#   'Corp',
#   '&',
#   'lt',
#   ';',
#   'DCN',
#   '>.',
#   '</s>'],
#  ['<s>',
#   'COCOA',
#   'TERMINAL',
#   'DEPOSITS',
#   'TO',
#   'BE',
#   'CUT',
#   '25',
#   'PCT',
#   '-',
#   'ICCH',
#   'The',
#   'basic',
#   'deposit',
#   'on',
#   'cocoa',
#   'futures',
#   'contracts',
#   'will',
#   'be',
#   'reduced',
#   'by',
#   '25',
#   'pct',
#   'as',
#   'from',
#   'Friday',
#   ',',
#   'April',
#   '10',
#   ',',
#   'taking',
#   'the',
#   'required',
#   'deposit',
#   'for',
#   'one',
#   '10',
#   'tonne',
#   'lot',
#   'to',
#   '300',
#   'stg',
#   'from',
#   '400',
#   'previously',
#   ',',
#   'a',
#   'spokesman',
#   'for',
#   'the',
#   'International',
#   'Commodity',
#   'Clearing',
#   'House',
#   '(',
#   'ICCH',
#   ')',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'deposit',
#   'for',
#   'spread',
#   'contracts',
#   'will',
#   'be',
#   'similarly',
#   'cut',
#   ',',
#   'to',
#   '150',
#   'stg',
#   'for',
#   'a',
#   'one',
#   '10',
#   'tonne',
#   'lot',
#   'from',
#   '200',
#   'previously',
#   ',',
#   'he',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'ICCH',
#   'had',
#   'been',
#   'looking',
#   'at',
#   'cocoa',
#   'market',
#   'fluctuations',
#   'over',
#   'a',
#   'period',
#   'of',
#   'weeks',
#   ',',
#   'he',
#   'said',
#   ',',
#   'adding',
#   'the',
#   'market',
#   "'",
#   's',
#   'basic',
#   'stability',
#   'had',
#   'warranted',
#   'a',
#   'cut',
#   'in',
#   'deposit',
#   'rates',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'decision',
#   'to',
#   'cut',
#   'deposits',
#   'was',
#   'taken',
#   'by',
#   'the',
#   'ICCH',
#   'after',
#   'consultation',
#   'with',
#   'the',
#   'London',
#   'Cocoa',
#   'Terminal',
#   'Market',
#   ',',
#   'the',
#   'spokesman',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'The',
#   'cuts',
#   'were',
#   'likely',
#   'to',
#   'attract',
#   'more',
#   'business',
#   'to',
#   'the',
#   'market',
#   ',',
#   'he',
#   'said',
#   '.',
#   '</s>'],
#  ['<s>',
#   'ELECTRO',
#   'RENT',
#   'CORP',
#   '&',
#   'lt',
#   ';',
#   'ELRC',
#   '>',
#   '3RD',
#   'QTR',
#   'FEB',
#   '28',
#   'NET',
#   'Shr',
#   '20',
#   'cts',
#   'vs',
#   '32',
#   'cts',
#   'Net',
#   '1',
#   ',',
#   '358',
#   ',',
#   '000',
#   'vs',
#   '2',
#   ',',
#   '476',
#   ',',
#   '000',
#   'Revs',
#   '27',
#   '.',
#   '1',
#   'mln',
#   'vs',
#   '26',
#   '.',
#   '2',
#   'mln',
#   'Nine',
#   'Mths',
#   'Shr',
#   '68',
#   'cts',
#   'vs',
#   '1',
#   '.',
#   '05',
#   'dlrs',
#   'Net',
#   '4',
#   ',',
#   '957',
#   ',',
#   '000',
#   'vs',
#   '8',
#   ',',
#   '129',
#   ',',
#   '000',
#   'Revs',
#   '82',
#   '.',
#   '6',
#   'mln',
#   'vs',
#   '78',
#   '.',
#   '8',
#   'mln',
#   '</s>'],
#  ['<s>',
#   'WALGREEN',
#   'CO',
#   '2ND',
#   'QTR',
#   'SHR',
#   '62',
#   'CTS',
#   'VS',
#   '58',
#   'CTS',
#   '</s>'],
#  ['<s>',
#   'WALGREEN',
#   'CO',
#   '2ND',
#   'QTR',
#   'SHR',
#   '62',
#   'CTS',
#   'VS',
#   '58',
#   'CTS',
#   '</s>'],
#  ...]

# %%
trigram = Trigram(sents)

# %%
sorted(trigram.model[("the", "price")], key=trigram.model[("the", "price")].get, reverse=True)
# Out:
# ['of',
#  'it',
#  'to',
#  'for',
#  '.',
#  'at',
#  'adjustment',
#  'is',
#  ',',
#  'paid',
#  'increases',
#  'per',
#  'the',
#  'will',
#  'cut',
#  'cuts',
#  '(',
#  'differentials',
#  'has',
#  'stayed',
#  'was',
#  'freeze',
#  'increase',
#  'would',
#  'yesterday',
#  'effect',
#  'used',
#  'climate',
#  'reductions',
#  'limit',
#  'now',
#  'moved',
#  'adjustments',
#  'slumped',
#  'move',
#  'evolution',
#  'went',
#  'factor',
#  'Royal',
#  'again',
#  'changes',
#  'holds',
#  'fall',
#  '-',
#  'from',
#  'base',
#  'on',
#  'review',
#  'while',
#  'collapse',
#  'being',
#  'outlook',
#  'rises',
#  'drop',
#  'guaranteed',
#  ',"',
#  'structure',
#  'and',
#  'could',
#  'related',
#  'hike',
#  'we',
#  'policy',
#  'revision',
#  'led',
#  'action',
#  'zone',
#  'slump',
#  'had',
#  'difference',
#  'in',
#  'raise',
#  'support',
#  'gap',
#  'projected',
#  'approached',
#  'instability']

# %%
trigram.model[("the", "price")]
# Out:
# {'yesterday': 0.004651162790697674,
#  'of': 0.3209302325581395,
#  'it': 0.05581395348837209,
#  'effect': 0.004651162790697674,
#  'cut': 0.009302325581395349,
#  'for': 0.05116279069767442,
#  'paid': 0.013953488372093023,
#  'to': 0.05581395348837209,
#  'increases': 0.013953488372093023,
#  'used': 0.004651162790697674,
#  'climate': 0.004651162790697674,
#  '.': 0.023255813953488372,
#  'cuts': 0.009302325581395349,
#  'reductions': 0.004651162790697674,
#  'limit': 0.004651162790697674,
#  'now': 0.004651162790697674,
#  'moved': 0.004651162790697674,
#  'per': 0.013953488372093023,
#  'adjustments': 0.004651162790697674,
#  '(': 0.009302325581395349,
#  'slumped': 0.004651162790697674,
#  'is': 0.018604651162790697,
#  'move': 0.004651162790697674,
#  'evolution': 0.004651162790697674,
#  'differentials': 0.009302325581395349,
#  'went': 0.004651162790697674,
#  'the': 0.013953488372093023,
#  'factor': 0.004651162790697674,
#  'Royal': 0.004651162790697674,
#  ',': 0.018604651162790697,
#  'again': 0.004651162790697674,
#  'changes': 0.004651162790697674,
#  'holds': 0.004651162790697674,
#  'has': 0.009302325581395349,
#  'fall': 0.004651162790697674,
#  '-': 0.004651162790697674,
#  'from': 0.004651162790697674,
#  'base': 0.004651162790697674,
#  'on': 0.004651162790697674,
#  'review': 0.004651162790697674,
#  'while': 0.004651162790697674,
#  'collapse': 0.004651162790697674,
#  'being': 0.004651162790697674,
#  'at': 0.023255813953488372,
#  'outlook': 0.004651162790697674,
#  'rises': 0.004651162790697674,
#  'drop': 0.004651162790697674,
#  'guaranteed': 0.004651162790697674,
#  ',"': 0.004651162790697674,
#  'stayed': 0.009302325581395349,
#  'structure': 0.004651162790697674,
#  'and': 0.004651162790697674,
#  'could': 0.004651162790697674,
#  'related': 0.004651162790697674,
#  'hike': 0.004651162790697674,
#  'we': 0.004651162790697674,
#  'adjustment': 0.023255813953488372,
#  'policy': 0.004651162790697674,
#  'was': 0.009302325581395349,
#  'revision': 0.004651162790697674,
#  'freeze': 0.009302325581395349,
#  'led': 0.004651162790697674,
#  'action': 0.004651162790697674,
#  'zone': 0.004651162790697674,
#  'slump': 0.004651162790697674,
#  'had': 0.004651162790697674,
#  'difference': 0.004651162790697674,
#  'in': 0.004651162790697674,
#  'raise': 0.004651162790697674,
#  'increase': 0.009302325581395349,
#  'will': 0.013953488372093023,
#  'support': 0.004651162790697674,
#  'gap': 0.004651162790697674,
#  'would': 0.009302325581395349,
#  'projected': 0.004651162790697674,
#  'approached': 0.004651162790697674,
#  'instability': 0.004651162790697674}

# %%
from nltk.corpus import gutenberg
from nltk.util import ngrams

gut_ngrams = (
    ngram for sent in gutenberg.sents() for ngram in ngrams(sent, 3,
    pad_left=True, pad_right=True, left_pad_symbol="<s>", right_pad_symbol="</s>"))

n = 0
for ngram in gut_ngrams:
    print(ngram)
    n += 1
    if n == 7:
        break
# Out:
# ('<s>', '<s>', '[')
# ('<s>', '[', 'Emma')
# ('[', 'Emma', 'by')
# ('Emma', 'by', 'Jane')
# ('by', 'Jane', 'Austen')
# ('Jane', 'Austen', '1816')
# ('Austen', '1816', ']')

# %%
import math
import random
from collections import Counter, defaultdict

class KneserNeyLM:

    def __init__(self, highest_order, ngrams, start_pad_symbol='<s>',
            end_pad_symbol='</s>'):
        """
        Constructor for KneserNeyLM.
        Params:
            highest_order [int] The order of the language model.
            ngrams [list->tuple->string] Ngrams of the highest_order specified.
                Ngrams at beginning / end of sentences should be padded.
            start_pad_symbol [string] The symbol used to pad the beginning of
                sentences.
            end_pad_symbol [string] The symbol used to pad the beginning of
                sentences.
        """
        self.highest_order = highest_order
        self.start_pad_symbol = start_pad_symbol
        self.end_pad_symbol = end_pad_symbol
        self.lm = self.train(ngrams)

    def train(self, ngrams):
        """
        Train the language model on the given ngrams.
        Params:
            ngrams [list->tuple->string] Ngrams of the highest_order specified.
        """
        kgram_counts = self._calc_adj_counts(Counter(ngrams))
        probs = self._calc_probs(kgram_counts)
        return probs

    def highest_order_probs(self):
        return self.lm[0]

    def _calc_adj_counts(self, highest_order_counts):
        """
        Calculates the adjusted counts for all ngrams up to the highest order.
        Params:
            highest_order_counts [dict{tuple->string, int}] Counts of the highest
                order ngrams.
        Returns:
            kgrams_counts [list->dict] List of dict from kgram to counts
                where k is in descending order from highest_order to 0.
        """
        kgrams_counts = [highest_order_counts]
        for i in range(1, self.highest_order):
            last_order = kgrams_counts[-1]
            new_order = defaultdict(int)
            for ngram in last_order.keys():
                suffix = ngram[1:]
                new_order[suffix] += 1
            kgrams_counts.append(new_order)
        return kgrams_counts

    def _calc_probs(self, orders):
        """
        Calculates interpolated probabilities of kgrams for all orders.
        """
        backoffs = []
        for order in orders[:-1]:
            backoff = self._calc_order_backoff_probs(order)
            backoffs.append(backoff)
        orders[-1] = self._calc_unigram_probs(orders[-1])
        backoffs.append(defaultdict(int))
        self._interpolate(orders, backoffs)
        return orders

    def _calc_unigram_probs(self, unigrams):
        sum_vals = sum(v for v in unigrams.values())
        unigrams = dict((k, math.log(v/sum_vals)) for k, v in unigrams.items())
        return unigrams

    def _calc_order_backoff_probs(self, order):
        num_kgrams_with_count = Counter(
            value for value in order.values() if value <= 4)
        discounts = self._calc_discounts(num_kgrams_with_count)
        prefix_sums = defaultdict(int)
        backoffs = defaultdict(int)
        for key in order.keys():
            prefix = key[:-1]
            count = order[key]
            prefix_sums[prefix] += count
            discount = self._get_discount(discounts, count)
            order[key] -= discount
            backoffs[prefix] += discount
        for key in order.keys():
            prefix = key[:-1]
            order[key] = math.log(order[key]/prefix_sums[prefix])
        for prefix in backoffs.keys():
            backoffs[prefix] = math.log(backoffs[prefix]/prefix_sums[prefix])
        return backoffs

    def _get_discount(self, discounts, count):
        if count > 3:
            return discounts[3]
        return discounts[count]

    def _calc_discounts(self, num_with_count):
        """
        Calculate the optimal discount values for kgrams with counts 1, 2, & 3+.
        """
        common = num_with_count[1]/(num_with_count[1] + 2 * num_with_count[2])
        # Init discounts[0] to 0 so that discounts[i] is for counts of i
        discounts = [0]
        for i in range(1, 4):
            if num_with_count[i] == 0:
                discount = 0
            else:
                discount = (i - (i + 1) * common
                        * num_with_count[i + 1] / num_with_count[i])
            discounts.append(discount)
        if any(d for d in discounts[1:] if d <= 0):
            raise Exception(
                '***Warning*** Non-positive discounts detected. '
                'Your dataset is probably too small.')
        return discounts

    def _interpolate(self, orders, backoffs):
        """
        """
        for last_order, order, backoff in zip(
                reversed(orders), reversed(orders[:-1]), reversed(backoffs[:-1])):
            for kgram in order.keys():
                prefix, suffix = kgram[:-1], kgram[1:]
                order[kgram] += last_order[suffix] + backoff[prefix]

    def logprob(self, ngram):
        for i, order in enumerate(self.lm):
            if ngram[i:] in order:
                return order[ngram[i:]]
        return None

    def score_sent(self, sent):
        """
        Return log prob of the sentence.
        Params:
            sent [tuple->string] The words in the unpadded sentence.
        """
        padded = (
            (self.start_pad_symbol,) * (self.highest_order - 1) + sent +
            (self.end_pad_symbol,))
        sent_logprob = 0
        for i in range(len(sent) - self.highest_order + 1):
            ngram = sent[i:i+self.highest_order]
            sent_logprob += self.logprob(ngram)
        return sent_logprob

    def generate_sentence(self, min_length=4):
        """
        Generate a sentence using the probabilities in the language model.
        Params:
            min_length [int] The mimimum number of words in the sentence.
        """
        sent = []
        probs = self.highest_order_probs()
        while len(sent) < min_length + self.highest_order:
            sent = [self.start_pad_symbol] * (self.highest_order - 1)
            # Append first to avoid case where start & end symbal are same
            sent.append(self._generate_next_word(sent, probs))
            while sent[-1] != self.end_pad_symbol:
                sent.append(self._generate_next_word(sent, probs))
        sent = ' '.join(sent[(self.highest_order - 1):-1])
        return sent

    def _get_context(self, sentence):
        """
        Extract context to predict next word from sentence.
        Params:
            sentence [tuple->string] The words currently in sentence.
        """
        return sentence[(len(sentence) - self.highest_order + 1):]

    def _generate_next_word(self, sent, probs):
        context = tuple(self._get_context(sent))
        pos_ngrams = list(
            (ngram, logprob) for ngram, logprob in probs.items()
            if ngram[:-1] == context)
        # Normalize to get conditional probability.
        # Subtract max logprob from all logprobs to avoid underflow.
        _, max_logprob = max(pos_ngrams, key=lambda x: x[1])
        pos_ngrams = list(
            (ngram, math.exp(prob - max_logprob)) for ngram, prob in pos_ngrams)
        total_prob = sum(prob for ngram, prob in pos_ngrams)
        pos_ngrams = list(
            (ngram, prob/total_prob) for ngram, prob in pos_ngrams)
        rand = random.random()
        for ngram, prob in pos_ngrams:
            rand -= prob
            if rand < 0:
                return ngram[-1]
        return ngram[-1]

# %%
gut_ngrams = (
    ngram for sent in gutenberg.sents() for ngram in ngrams(sent, 3,
    pad_left=True, pad_right=True, left_pad_symbol="<s>", right_pad_symbol="</s>"))
Counter(gut_ngrams)
# Out:
# Counter({('<s>', '<s>', '['): 81,
#          ('<s>', '[', 'Emma'): 1,
#          ('[', 'Emma', 'by'): 1,
#          ('Emma', 'by', 'Jane'): 1,
#          ('by', 'Jane', 'Austen'): 3,
#          ('Jane', 'Austen', '1816'): 1,
#          ('Austen', '1816', ']'): 1,
#          ('1816', ']', '</s>'): 1,
#          (']', '</s>', '</s>'): 78,
#          ('<s>', '<s>', 'VOLUME'): 3,
#          ('<s>', 'VOLUME', 'I'): 1,
#          ('VOLUME', 'I', '</s>'): 1,
#          ('I', '</s>', '</s>'): 13,
#          ('<s>', '<s>', 'CHAPTER'): 276,
#          ('<s>', 'CHAPTER', 'I'): 8,
#          ('CHAPTER', 'I', '</s>'): 4,
#          ('<s>', '<s>', 'Emma'): 212,
#          ('<s>', 'Emma', 'Woodhouse'): 1,
#          ('Emma', 'Woodhouse', ','): 4,
#          ('Woodhouse', ',', 'handsome'): 1,
#          (',', 'handsome', ','): 6,
#          ('handsome', ',', 'clever'): 1,
#          (',', 'clever', ','): 1,
#          ('clever', ',', 'and'): 4,
#          (',', 'and', 'rich'): 4,
#          ('and', 'rich', ','): 1,
#          ('rich', ',', 'with'): 1,
#          (',', 'with', 'a'): 435,
#          ('with', 'a', 'comfortable'): 1,
#          ('a', 'comfortable', 'home'): 3,
#          ('comfortable', 'home', 'and'): 1,
#          ('home', 'and', 'happy'): 1,
#          ('and', 'happy', 'disposition'): 1,
#          ('happy', 'disposition', ','): 1,
#          ('disposition', ',', 'seemed'): 1,
#          (',', 'seemed', 'to'): 21,
#          ('seemed', 'to', 'unite'): 1,
#          ('to', 'unite', 'some'): 1,
#          ('unite', 'some', 'of'): 1,
#          ('some', 'of', 'the'): 97,
#          ('of', 'the', 'best'): 27,
#          ('the', 'best', 'blessings'): 2,
#          ('best', 'blessings', 'of'): 2,
#          ('blessings', 'of', 'existence'): 2,
#          ('of', 'existence', ';'): 2,
#          ('existence', ';', 'and'): 1,
#          (';', 'and', 'had'): 18,
#          ('and', 'had', 'lived'): 3,
#          ('had', 'lived', 'nearly'): 1,
#          ('lived', 'nearly', 'twenty'): 1,
#          ('nearly', 'twenty', '-'): 1,
#          ('twenty', '-', 'one'): 1,
#          ('-', 'one', 'years'): 2,
#          ('one', 'years', 'in'): 2,
#          ('years', 'in', 'the'): 10,
#          ('in', 'the', 'world'): 243,
#          ('the', 'world', 'with'): 8,
#          ('world', 'with', 'very'): 1,
#          ('with', 'very', 'little'): 4,
#          ('very', 'little', 'to'): 5,
#          ('little', 'to', 'distress'): 2,
#          ('to', 'distress', 'or'): 1,
#          ('distress', 'or', 'vex'): 1,
#          ('or', 'vex', 'her'): 1,
#          ('vex', 'her', '.'): 2,
#          ('her', '.', '</s>'): 448,
#          ('.', '</s>', '</s>'): 69877,
#          ('<s>', '<s>', 'She'): 1321,
#          ('<s>', 'She', 'was'): 250,
#          ('She', 'was', 'the'): 4,
#          ('was', 'the', 'youngest'): 5,
#          ('the', 'youngest', 'of'): 5,
#          ('youngest', 'of', 'the'): 3,
#          ('of', 'the', 'two'): 72,
#          ('the', 'two', 'daughters'): 2,
#          ('two', 'daughters', 'of'): 2,
#          ('daughters', 'of', 'a'): 2,
#          ('of', 'a', 'most'): 6,
#          ('a', 'most', 'affectionate'): 2,
#          ('most', 'affectionate', ','): 1,
#          ('affectionate', ',', 'indulgent'): 1,
#          (',', 'indulgent', 'father'): 1,
#          ('indulgent', 'father', ';'): 1,
#          ('father', ';', 'and'): 23,
#          ('and', 'had', ','): 5,
#          ('had', ',', 'in'): 11,
#          (',', 'in', 'consequence'): 10,
#          ('in', 'consequence', 'of'): 11,
#          ('consequence', 'of', 'her'): 2,
#          ('of', 'her', 'sister'): 28,
#          ('her', 'sister', "'"): 45,
#          ('sister', "'", 's'): 84,
#          ("'", 's', 'marriage'): 15,
#          ('s', 'marriage', ','): 4,
#          ('marriage', ',', 'been'): 2,
#          (',', 'been', 'mistress'): 1,
#          ('been', 'mistress', 'of'): 3,
#          ('mistress', 'of', 'his'): 1,
#          ('of', 'his', 'house'): 32,
#          ('his', 'house', 'from'): 1,
#          ('house', 'from', 'a'): 1,
#          ('from', 'a', 'very'): 2,
#          ('a', 'very', 'early'): 5,
#          ('very', 'early', 'period'): 2,
#          ('early', 'period', '.'): 1,
#          ('period', '.', '</s>'): 3,
#          ('<s>', '<s>', 'Her'): 263,
#          ('<s>', 'Her', 'mother'): 14,
#          ('Her', 'mother', 'had'): 2,
#          ('mother', 'had', 'died'): 2,
#          ('had', 'died', 'too'): 1,
#          ('died', 'too', 'long'): 1,
#          ('too', 'long', 'ago'): 1,
#          ('long', 'ago', 'for'): 1,
#          ('ago', 'for', 'her'): 1,
#          ('for', 'her', 'to'): 31,
#          ('her', 'to', 'have'): 5,
#          ('to', 'have', 'more'): 4,
#          ('have', 'more', 'than'): 10,
#          ('more', 'than', 'an'): 4,
#          ('than', 'an', 'indistinct'): 1,
#          ('an', 'indistinct', 'remembrance'): 1,
#          ('indistinct', 'remembrance', 'of'): 1,
#          ('remembrance', 'of', 'her'): 2,
#          ('of', 'her', 'caresses'): 1,
#          ('her', 'caresses', ';'): 1,
#          ('caresses', ';', 'and'): 1,
#          (';', 'and', 'her'): 34,
#          ('and', 'her', 'place'): 1,
#          ('her', 'place', 'had'): 1,
#          ('place', 'had', 'been'): 1,
#          ('had', 'been', 'supplied'): 2,
#          ('been', 'supplied', 'by'): 1,
#          ('supplied', 'by', 'an'): 1,
#          ('by', 'an', 'excellent'): 1,
#          ('an', 'excellent', 'woman'): 2,
#          ('excellent', 'woman', 'as'): 1,
#          ('woman', 'as', 'governess'): 1,
#          ('as', 'governess', ','): 2,
#          ('governess', ',', 'who'): 1,
#          (',', 'who', 'had'): 221,
#          ('who', 'had', 'fallen'): 1,
#          ('had', 'fallen', 'little'): 1,
#          ('fallen', 'little', 'short'): 1,
#          ('little', 'short', 'of'): 2,
#          ('short', 'of', 'a'): 2,
#          ('of', 'a', 'mother'): 2,
#          ('a', 'mother', 'in'): 3,
#          ('mother', 'in', 'affection'): 1,
#          ('in', 'affection', '.'): 1,
#          ('affection', '.', '</s>'): 11,
#          ('<s>', '<s>', 'Sixteen'): 3,
#          ('<s>', 'Sixteen', 'years'): 1,
#          ('Sixteen', 'years', 'had'): 1,
#          ('years', 'had', 'Miss'): 1,
#          ('had', 'Miss', 'Taylor'): 2,
#          ('Miss', 'Taylor', 'been'): 1,
#          ('Taylor', 'been', 'in'): 1,
#          ('been', 'in', 'Mr'): 2,
#          ('in', 'Mr', '.'): 21,
#          ('Mr', '.', 'Woodhouse'): 132,
#          ('.', 'Woodhouse', "'"): 25,
#          ('Woodhouse', "'", 's'): 36,
#          ("'", 's', 'family'): 20,
#          ('s', 'family', ','): 9,
#          ('family', ',', 'less'): 1,
#          (',', 'less', 'as'): 1,
#          ('less', 'as', 'a'): 1,
#          ('as', 'a', 'governess'): 1,
#          ('a', 'governess', 'than'): 1,
#          ('governess', 'than', 'a'): 1,
#          ('than', 'a', 'friend'): 1,
#          ('a', 'friend', ','): 23,
#          ('friend', ',', 'very'): 1,
#          (',', 'very', 'fond'): 1,
#          ('very', 'fond', 'of'): 25,
#          ('fond', 'of', 'both'): 1,
#          ('of', 'both', 'daughters'): 1,
#          ('both', 'daughters', ','): 1,
#          ('daughters', ',', 'but'): 4,
#          (',', 'but', 'particularly'): 4,
#          ('but', 'particularly', 'of'): 1,
#          ('particularly', 'of', 'Emma'): 1,
#          ('of', 'Emma', '.'): 2,
#          ('Emma', '.', '</s>'): 44,
#          ('<s>', '<s>', 'Between'): 16,
#          ('<s>', 'Between', '_them_'): 1,
#          ('Between', '_them_', 'it'): 1,
#          ('_them_', 'it', 'was'): 1,
#          ('it', 'was', 'more'): 8,
#          ('was', 'more', 'the'): 1,
#          ('more', 'the', 'intimacy'): 1,
#          ('the', 'intimacy', 'of'): 1,
#          ('intimacy', 'of', 'sisters'): 1,
#          ('of', 'sisters', '.'): 1,
#          ('sisters', '.', '</s>'): 11,
#          ('<s>', '<s>', 'Even'): 73,
#          ('<s>', 'Even', 'before'): 1,
#          ('Even', 'before', 'Miss'): 1,
#          ('before', 'Miss', 'Taylor'): 1,
#          ('Miss', 'Taylor', 'had'): 4,
#          ('Taylor', 'had', 'ceased'): 1,
#          ('had', 'ceased', 'to'): 8,
#          ('ceased', 'to', 'hold'): 1,
#          ('to', 'hold', 'the'): 8,
#          ('hold', 'the', 'nominal'): 1,
#          ('the', 'nominal', 'office'): 1,
#          ('nominal', 'office', 'of'): 1,
#          ('office', 'of', 'governess'): 1,
#          ('of', 'governess', ','): 1,
#          ('governess', ',', 'the'): 1,
#          (',', 'the', 'mildness'): 1,
#          ('the', 'mildness', 'of'): 2,
#          ('mildness', 'of', 'her'): 2,
#          ('of', 'her', 'temper'): 4,
#          ('her', 'temper', 'had'): 1,
#          ('temper', 'had', 'hardly'): 1,
#          ('had', 'hardly', 'allowed'): 1,
#          ('hardly', 'allowed', 'her'): 1,
#          ('allowed', 'her', 'to'): 2,
#          ('her', 'to', 'impose'): 1,
#          ('to', 'impose', 'any'): 1,
#          ('impose', 'any', 'restraint'): 1,
#          ('any', 'restraint', ';'): 1,
#          ('restraint', ';', 'and'): 1,
#          (';', 'and', 'the'): 750,
#          ('and', 'the', 'shadow'): 5,
#          ('the', 'shadow', 'of'): 55,
#          ('shadow', 'of', 'authority'): 1,
#          ('of', 'authority', 'being'): 1,
#          ('authority', 'being', 'now'): 1,
#          ('being', 'now', 'long'): 1,
#          ('now', 'long', 'passed'): 1,
#          ('long', 'passed', 'away'): 2,
#          ('passed', 'away', ','): 9,
#          ('away', ',', 'they'): 10,
#          (',', 'they', 'had'): 42,
#          ('they', 'had', 'been'): 43,
#          ('had', 'been', 'living'): 2,
#          ('been', 'living', 'together'): 1,
#          ('living', 'together', 'as'): 1,
#          ('together', 'as', 'friend'): 1,
#          ('as', 'friend', 'and'): 1,
#          ('friend', 'and', 'friend'): 1,
#          ('and', 'friend', 'very'): 1,
#          ('friend', 'very', 'mutually'): 1,
#          ('very', 'mutually', 'attached'): 1,
#          ('mutually', 'attached', ','): 1,
#          ('attached', ',', 'and'): 1,
#          (',', 'and', 'Emma'): 19,
#          ('and', 'Emma', 'doing'): 1,
#          ('Emma', 'doing', 'just'): 1,
#          ('doing', 'just', 'what'): 2,
#          ('just', 'what', 'she'): 2,
#          ('what', 'she', 'liked'): 2,
#          ('she', 'liked', ';'): 1,
#          ('liked', ';', 'highly'): 1,
#          (';', 'highly', 'esteeming'): 1,
#          ('highly', 'esteeming', 'Miss'): 1,
#          ('esteeming', 'Miss', 'Taylor'): 1,
#          ('Miss', 'Taylor', "'"): 8,
#          ('Taylor', "'", 's'): 8,
#          ("'", 's', 'judgment'): 8,
#          ('s', 'judgment', ','): 2,
#          ('judgment', ',', 'but'): 3,
#          (',', 'but', 'directed'): 1,
#          ('but', 'directed', 'chiefly'): 1,
#          ('directed', 'chiefly', 'by'): 1,
#          ('chiefly', 'by', 'her'): 1,
#          ('by', 'her', 'own'): 10,
#          ('her', 'own', '.'): 21,
#          ('own', '.', '</s>'): 75,
#          ('<s>', '<s>', 'The'): 3475,
#          ('<s>', 'The', 'real'): 4,
#          ('The', 'real', 'evils'): 1,
#          ('real', 'evils', ','): 1,
#          ('evils', ',', 'indeed'): 1,
#          (',', 'indeed', ','): 177,
#          ('indeed', ',', 'of'): 2,
#          (',', 'of', 'Emma'): 2,
#          ('of', 'Emma', "'"): 7,
#          ('Emma', "'", 's'): 79,
#          ("'", 's', 'situation'): 14,
#          ('s', 'situation', 'were'): 1,
#          ('situation', 'were', 'the'): 1,
#          ('were', 'the', 'power'): 1,
#          ('the', 'power', 'of'): 83,
#          ('power', 'of', 'having'): 1,
#          ('of', 'having', 'rather'): 1,
#          ('having', 'rather', 'too'): 1,
#          ('rather', 'too', 'much'): 9,
#          ('too', 'much', 'her'): 1,
#          ('much', 'her', 'own'): 1,
#          ('her', 'own', 'way'): 8,
#          ('own', 'way', ','): 11,
#          ('way', ',', 'and'): 94,
#          (',', 'and', 'a'): 581,
#          ('and', 'a', 'disposition'): 3,
#          ('a', 'disposition', 'to'): 6,
#          ('disposition', 'to', 'think'): 1,
#          ('to', 'think', 'a'): 3,
#          ('think', 'a', 'little'): 1,
#          ('a', 'little', 'too'): 10,
#          ('little', 'too', 'well'): 1,
#          ('too', 'well', 'of'): 1,
#          ('well', 'of', 'herself'): 1,
#          ('of', 'herself', ';'): 4,
#          ('herself', ';', 'these'): 1,
#          (';', 'these', 'were'): 7,
#          ('these', 'were', 'the'): 31,
#          ('were', 'the', 'disadvantages'): 1,
#          ('the', 'disadvantages', 'which'): 1,
#          ('disadvantages', 'which', 'threatened'): 1,
#          ('which', 'threatened', 'alloy'): 1,
#          ('threatened', 'alloy', 'to'): 1,
#          ('alloy', 'to', 'her'): 1,
#          ('to', 'her', 'many'): 1,
#          ('her', 'many', 'enjoyments'): 1,
#          ('many', 'enjoyments', '.'): 1,
#          ('enjoyments', '.', '</s>'): 2,
#          ('<s>', 'The', 'danger'): 3,
#          ('The', 'danger', ','): 2,
#          ('danger', ',', 'however'): 1,
#          (',', 'however', ','): 371,
#          ('however', ',', 'was'): 25,
#          (',', 'was', 'at'): 10,
#          ('was', 'at', 'present'): 4,
#          ('at', 'present', 'so'): 2,
#          ('present', 'so', 'unperceived'): 1,
#          ('so', 'unperceived', ','): 1,
#          ('unperceived', ',', 'that'): 1,
#          (',', 'that', 'they'): 389,
#          ('that', 'they', 'did'): 8,
#          ('they', 'did', 'not'): 32,
#          ('did', 'not', 'by'): 2,
#          ('not', 'by', 'any'): 11,
#          ('by', 'any', 'means'): 26,
#          ('any', 'means', 'rank'): 1,
#          ('means', 'rank', 'as'): 1,
#          ('rank', 'as', 'misfortunes'): 1,
#          ('as', 'misfortunes', 'with'): 1,
#          ('misfortunes', 'with', 'her'): 1,
#          ('with', 'her', '.'): 32,
#          ('<s>', '<s>', 'Sorrow'): 1,
#          ('<s>', 'Sorrow', 'came'): 1,
#          ('Sorrow', 'came', '--'): 1,
#          ('came', '--', 'a'): 1,
#          ('--', 'a', 'gentle'): 1,
#          ('a', 'gentle', 'sorrow'): 1,
#          ('gentle', 'sorrow', '--'): 1,
#          ('sorrow', '--', 'but'): 1,
#          ('--', 'but', 'not'): 8,
#          ('but', 'not', 'at'): 8,
#          ('not', 'at', 'all'): 79,
#          ('at', 'all', 'in'): 17,
#          ('all', 'in', 'the'): 21,
#          ('in', 'the', 'shape'): 7,
#          ('the', 'shape', 'of'): 22,
#          ('shape', 'of', 'any'): 2,
#          ('of', 'any', 'disagreeable'): 1,
#          ('any', 'disagreeable', 'consciousness'): 1,
#          ('disagreeable', 'consciousness', '.--'): 1,
#          ('consciousness', '.--', 'Miss'): 1,
#          ('.--', 'Miss', 'Taylor'): 1,
#          ('Miss', 'Taylor', 'married'): 1,
#          ('Taylor', 'married', '.'): 1,
#          ('married', '.', '</s>'): 19,
#          ('<s>', '<s>', 'It'): 1675,
#          ('<s>', 'It', 'was'): 655,
#          ('It', 'was', 'Miss'): 1,
#          ('was', 'Miss', 'Taylor'): 1,
#          ("'", 's', 'loss'): 5,
#          ('s', 'loss', 'which'): 1,
#          ('loss', 'which', 'first'): 1,
#          ('which', 'first', 'brought'): 1,
#          ('first', 'brought', 'grief'): 1,
#          ('brought', 'grief', '.'): 1,
#          ('grief', '.', '</s>'): 6,
#          ('It', 'was', 'on'): 6,
#          ('was', 'on', 'the'): 43,
#          ('on', 'the', 'wedding'): 1,
#          ('the', 'wedding', '-'): 2,
#          ('wedding', '-', 'day'): 4,
#          ('-', 'day', 'of'): 4,
#          ('day', 'of', 'this'): 9,
#          ('of', 'this', 'beloved'): 1,
#          ('this', 'beloved', 'friend'): 1,
#          ('beloved', 'friend', 'that'): 1,
#          ('friend', 'that', 'Emma'): 1,
#          ('that', 'Emma', 'first'): 1,
#          ('Emma', 'first', 'sat'): 1,
#          ('first', 'sat', 'in'): 1,
#          ('sat', 'in', 'mournful'): 1,
#          ('in', 'mournful', 'thought'): 1,
#          ('mournful', 'thought', 'of'): 1,
#          ('thought', 'of', 'any'): 2,
#          ('of', 'any', 'continuance'): 1,
#          ('any', 'continuance', '.'): 1,
#          ('continuance', '.', '</s>'): 2,
#          ('<s>', 'The', 'wedding'): 3,
#          ('The', 'wedding', 'over'): 1,
#          ('wedding', 'over', ','): 1,
#          ('over', ',', 'and'): 39,
#          (',', 'and', 'the'): 3557,
#          ('and', 'the', 'bride'): 4,
#          ('the', 'bride', '-'): 1,
#          ('bride', '-', 'people'): 1,
#          ('-', 'people', 'gone'): 1,
#          ('people', 'gone', ','): 1,
#          ('gone', ',', 'her'): 1,
#          (',', 'her', 'father'): 9,
#          ('her', 'father', 'and'): 30,
#          ('father', 'and', 'herself'): 3,
#          ('and', 'herself', 'were'): 1,
#          ('herself', 'were', 'left'): 1,
#          ('were', 'left', 'to'): 3,
#          ('left', 'to', 'dine'): 2,
#          ('to', 'dine', 'together'): 1,
#          ('dine', 'together', ','): 1,
#          ('together', ',', 'with'): 1,
#          (',', 'with', 'no'): 14,
#          ('with', 'no', 'prospect'): 1,
#          ('no', 'prospect', 'of'): 1,
#          ('prospect', 'of', 'a'): 3,
#          ('of', 'a', 'third'): 4,
#          ('a', 'third', 'to'): 1,
#          ('third', 'to', 'cheer'): 1,
#          ('to', 'cheer', 'a'): 1,
#          ('cheer', 'a', 'long'): 1,
#          ('a', 'long', 'evening'): 2,
#          ('long', 'evening', '.'): 1,
#          ('evening', '.', '</s>'): 49,
#          ('<s>', 'Her', 'father'): 16,
#          ('Her', 'father', 'composed'): 1,
#          ('father', 'composed', 'himself'): 1,
#          ('composed', 'himself', 'to'): 1,
#          ('himself', 'to', 'sleep'): 1,
#          ('to', 'sleep', 'after'): 1,
#          ('sleep', 'after', 'dinner'): 1,
#          ('after', 'dinner', ','): 12,
#          ('dinner', ',', 'as'): 5,
#          (',', 'as', 'usual'): 20,
#          ('as', 'usual', ','): 24,
#          ('usual', ',', 'and'): 6,
#          (',', 'and', 'she'): 336,
#          ('and', 'she', 'had'): 47,
#          ('she', 'had', 'then'): 3,
#          ('had', 'then', 'only'): 1,
#          ('then', 'only', 'to'): 1,
#          ('only', 'to', 'sit'): 1,
#          ('to', 'sit', 'and'): 5,
#          ('sit', 'and', 'think'): 1,
#          ('and', 'think', 'of'): 1,
#          ('think', 'of', 'what'): 4,
#          ('of', 'what', 'she'): 15,
#          ('what', 'she', 'had'): 41,
#          ('she', 'had', 'lost'): 4,
#          ('had', 'lost', '.'): 2,
#          ('lost', '.', '</s>'): 25,
#          ('<s>', 'The', 'event'): 6,
#          ('The', 'event', 'had'): 1,
#          ('event', 'had', 'every'): 1,
#          ('had', 'every', 'promise'): 1,
#          ('every', 'promise', 'of'): 1,
#          ('promise', 'of', 'happiness'): 1,
#          ('of', 'happiness', 'for'): 1,
#          ('happiness', 'for', 'her'): 1,
#          ('for', 'her', 'friend'): 6,
#          ('her', 'friend', '.'): 9,
#          ('friend', '.', '</s>'): 75,
#          ('<s>', '<s>', 'Mr'): 358,
#          ('<s>', 'Mr', '.'): 302,
#          ('Mr', '.', 'Weston'): 162,
#          ('.', 'Weston', 'was'): 33,
#          ('Weston', 'was', 'a'): 4,
#          ('was', 'a', 'man'): 43,
#          ('a', 'man', 'of'): 129,
#          ('man', 'of', 'unexceptionable'): 1,
#          ('of', 'unexceptionable', 'character'): 1,
#          ('unexceptionable', 'character', ','): 1,
#          ('character', ',', 'easy'): 1,
#          (',', 'easy', 'fortune'): 1,
#          ('easy', 'fortune', ','): 1,
#          ('fortune', ',', 'suitable'): 1,
#          (',', 'suitable', 'age'): 1,
#          ('suitable', 'age', ','): 1,
#          ('age', ',', 'and'): 17,
#          (',', 'and', 'pleasant'): 3,
#          ('and', 'pleasant', 'manners'): 1,
#          ('pleasant', 'manners', ';'): 1,
#          ('manners', ';', 'and'): 2,
#          (';', 'and', 'there'): 138,
#          ('and', 'there', 'was'): 107,
#          ('there', 'was', 'some'): 5,
#          ('was', 'some', 'satisfaction'): 1,
#          ('some', 'satisfaction', 'in'): 2,
#          ('satisfaction', 'in', 'considering'): 1,
#          ('in', 'considering', 'with'): 1,
#          ('considering', 'with', 'what'): 1,
#          ('with', 'what', 'self'): 1,
#          ('what', 'self', '-'): 1,
#          ('self', '-', 'denying'): 5,
#          ('-', 'denying', ','): 2,
#          ('denying', ',', 'generous'): 1,
#          (',', 'generous', 'friendship'): 1,
#          ('generous', 'friendship', 'she'): 1,
#          ('friendship', 'she', 'had'): 1,
#          ('she', 'had', 'always'): 11,
#          ('had', 'always', 'wished'): 1,
#          ('always', 'wished', 'and'): 1,
#          ('wished', 'and', 'promoted'): 1,
#          ('and', 'promoted', 'the'): 1,
#          ('promoted', 'the', 'match'): 1,
#          ('the', 'match', ';'): 2,
#          ('match', ';', 'but'): 2,
#          (';', 'but', 'it'): 138,
#          ('but', 'it', 'was'): 96,
#          ('it', 'was', 'a'): 145,
#          ('was', 'a', 'black'): 3,
#          ('a', 'black', 'morning'): 1,
#          ('black', 'morning', "'"): 1,
#          ('morning', "'", 's'): 15,
#          ("'", 's', 'work'): 36,
#          ('s', 'work', 'for'): 4,
#          ('work', 'for', 'her'): 1,
#          ('for', 'her', '.'): 43,
#          ('<s>', 'The', 'want'): 2,
#          ('The', 'want', 'of'): 2,
#          ('want', 'of', 'Miss'): 1,
#          ('of', 'Miss', 'Taylor'): 4,
#          ('Miss', 'Taylor', 'would'): 1,
#          ('Taylor', 'would', 'be'): 1,
#          ('would', 'be', 'felt'): 1,
#          ('be', 'felt', 'every'): 1,
#          ('felt', 'every', 'hour'): 1,
#          ('every', 'hour', 'of'): 9,
#          ('hour', 'of', 'every'): 2,
#          ('of', 'every', 'day'): 7,
#          ('every', 'day', '.'): 19,
#          ('day', '.', '</s>'): 329,
#          ('<s>', 'She', 'recalled'): 1,
#          ('She', 'recalled', 'her'): 1,
#          ('recalled', 'her', 'past'): 1,
#          ('her', 'past', 'kindness'): 1,
#          ('past', 'kindness', '--'): 1,
#          ('kindness', '--', 'the'): 1,
#          ('--', 'the', 'kindness'): 1,
#          ('the', 'kindness', ','): 1,
#          ('kindness', ',', 'the'): 2,
#          (',', 'the', 'affection'): 1,
#          ('the', 'affection', 'of'): 5,
#          ('affection', 'of', 'sixteen'): 1,
#          ('of', 'sixteen', 'years'): 1,
#          ('sixteen', 'years', '--'): 1,
#          ('years', '--', 'how'): 1,
#          ('--', 'how', 'she'): 3,
#          ('how', 'she', 'had'): 6,
#          ('she', 'had', 'taught'): 1,
#          ('had', 'taught', 'and'): 1,
#          ('taught', 'and', 'how'): 1,
#          ('and', 'how', 'she'): 8,
#          ('she', 'had', 'played'): 3,
#          ('had', 'played', 'with'): 2,
#          ('played', 'with', 'her'): 1,
#          ('with', 'her', 'from'): 2,
#          ('her', 'from', 'five'): 1,
#          ('from', 'five', 'years'): 2,
#          ('five', 'years', 'old'): 16,
#          ('years', 'old', '--'): 1,
#          ('old', '--', 'how'): 1,
#          ('she', 'had', 'devoted'): 1,
#          ('had', 'devoted', 'all'): 1,
#          ('devoted', 'all', 'her'): 1,
#          ('all', 'her', 'powers'): 2,
#          ('her', 'powers', 'to'): 1,
#          ('powers', 'to', 'attach'): 1,
#          ('to', 'attach', 'and'): 1,
#          ('attach', 'and', 'amuse'): 1,
#          ('and', 'amuse', 'her'): 2,
#          ('amuse', 'her', 'in'): 1,
#          ('her', 'in', 'health'): 1,
#          ('in', 'health', '--'): 1,
#          ('health', '--', 'and'): 1,
#          ('--', 'and', 'how'): 7,
#          ('and', 'how', 'nursed'): 1,
#          ('how', 'nursed', 'her'): 1,
#          ('nursed', 'her', 'through'): 1,
#          ('her', 'through', 'the'): 6,
#          ('through', 'the', 'various'): 1,
#          ('the', 'various', 'illnesses'): 1,
#          ('various', 'illnesses', 'of'): 1,
#          ('illnesses', 'of', 'childhood'): 1,
#          ('of', 'childhood', '.'): 1,
#          ('childhood', '.', '</s>'): 4,
#          ('<s>', '<s>', 'A'): 675,
#          ('<s>', 'A', 'large'): 8,
#          ('A', 'large', 'debt'): 1,
#          ('large', 'debt', 'of'): 1,
#          ('debt', 'of', 'gratitude'): 1,
#          ('of', 'gratitude', 'was'): 1,
#          ('gratitude', 'was', 'owing'): 1,
#          ('was', 'owing', 'here'): 1,
#          ('owing', 'here', ';'): 1,
#          ('here', ';', 'but'): 3,
#          (';', 'but', 'the'): 204,
#          ('but', 'the', 'intercourse'): 1,
#          ('the', 'intercourse', 'of'): 2,
#          ('intercourse', 'of', 'the'): 2,
#          ('of', 'the', 'last'): 20,
#          ('the', 'last', 'seven'): 1,
#          ('last', 'seven', 'years'): 1,
#          ('seven', 'years', ','): 6,
#          ('years', ',', 'the'): 7,
#          (',', 'the', 'equal'): 1,
#          ('the', 'equal', 'footing'): 1,
#          ('equal', 'footing', 'and'): 1,
#          ('footing', 'and', 'perfect'): 1,
#          ('and', 'perfect', 'unreserve'): 1,
#          ('perfect', 'unreserve', 'which'): 1,
#          ('unreserve', 'which', 'had'): 1,
#          ('which', 'had', 'soon'): 1,
#          ('had', 'soon', 'followed'): 1,
#          ('soon', 'followed', 'Isabella'): 1,
#          ('followed', 'Isabella', "'"): 1,
#          ('Isabella', "'", 's'): 15,
#          ('marriage', ',', 'on'): 1,
#          (',', 'on', 'their'): 4,
#          ('on', 'their', 'being'): 1,
#          ('their', 'being', 'left'): 1,
#          ('being', 'left', 'to'): 3,
#          ('left', 'to', 'each'): 1,
#          ('to', 'each', 'other'): 39,
#          ('each', 'other', ','): 55,
#          ('other', ',', 'was'): 3,
#          (',', 'was', 'yet'): 3,
#          ('was', 'yet', 'a'): 6,
#          ('yet', 'a', 'dearer'): 1,
#          ('a', 'dearer', ','): 1,
#          ('dearer', ',', 'tenderer'): 1,
#          (',', 'tenderer', 'recollection'): 1,
#          ('tenderer', 'recollection', '.'): 1,
#          ('recollection', '.', '</s>'): 4,
#          ('<s>', 'She', 'had'): 185,
#          ('She', 'had', 'been'): 19,
#          ('had', 'been', 'a'): 63,
#          ('been', 'a', 'friend'): 2,
#          ('a', 'friend', 'and'): 5,
#          ('friend', 'and', 'companion'): 1,
#          ('and', 'companion', 'such'): 1,
#          ('companion', 'such', 'as'): 1,
#          ('such', 'as', 'few'): 1,
#          ('as', 'few', 'possessed'): 1,
#          ('few', 'possessed', ':'): 1,
#          ('possessed', ':', 'intelligent'): 1,
#          (':', 'intelligent', ','): 1,
#          ('intelligent', ',', 'well'): 1,
#          (',', 'well', '-'): 27,
#          ('well', '-', 'informed'): 7,
#          ('-', 'informed', ','): 3,
#          ('informed', ',', 'useful'): 1,
#          (',', 'useful', ','): 2,
#          ('useful', ',', 'gentle'): 1,
#          (',', 'gentle', ','): 3,
#          ('gentle', ',', 'knowing'): 1,
#          (',', 'knowing', 'all'): 2,
#          ('knowing', 'all', 'the'): 1,
#          ('all', 'the', 'ways'): 5,
#          ('the', 'ways', 'of'): 37,
#          ('ways', 'of', 'the'): 14,
#          ('of', 'the', 'family'): 39,
#          ('the', 'family', ','): 17,
#          ('family', ',', 'interested'): 1,
#          (',', 'interested', 'in'): 1,
#          ('interested', 'in', 'all'): 2,
#          ('in', 'all', 'its'): 8,
#          ('all', 'its', 'concerns'): 2,
#          ('its', 'concerns', ','): 2,
#          ('concerns', ',', 'and'): 2,
#          (',', 'and', 'peculiarly'): 1,
#          ('and', 'peculiarly', 'interested'): 1,
#          ('peculiarly', 'interested', 'in'): 1,
#          ('interested', 'in', 'herself'): 1,
#          ('in', 'herself', ','): 4,
#          ('herself', ',', 'in'): 10,
#          (',', 'in', 'every'): 20,
#          ('in', 'every', 'pleasure'): 1,
#          ('every', 'pleasure', ','): 1,
#          ('pleasure', ',', 'every'): 1,
#          (',', 'every', 'scheme'): 1,
#          ('every', 'scheme', 'of'): 1,
#          ('scheme', 'of', 'hers'): 1,
#          ('of', 'hers', '--'): 1,
#          ('hers', '--', 'one'): 1,
#          ('--', 'one', 'to'): 2,
#          ('one', 'to', 'whom'): 4,
#          ('to', 'whom', 'she'): 15,
#          ('whom', 'she', 'could'): 4,
#          ('she', 'could', 'speak'): 4,
#          ('could', 'speak', 'every'): 1,
#          ('speak', 'every', 'thought'): 1,
#          ('every', 'thought', 'as'): 1,
#          ('thought', 'as', 'it'): 1,
#          ('as', 'it', 'arose'): 1,
#          ('it', 'arose', ','): 1,
#          ('arose', ',', 'and'): 76,
#          (',', 'and', 'who'): 93,
#          ('and', 'who', 'had'): 13,
#          ('who', 'had', 'such'): 3,
#          ('had', 'such', 'an'): 9,
#          ('such', 'an', 'affection'): 2,
#          ('an', 'affection', 'for'): 2,
#          ('affection', 'for', 'her'): 5,
#          ('for', 'her', 'as'): 6,
#          ('her', 'as', 'could'): 1,
#          ('as', 'could', 'never'): 1,
#          ('could', 'never', 'find'): 1,
#          ('never', 'find', 'fault'): 1,
#          ('find', 'fault', '.'): 1,
#          ('fault', '.', '</s>'): 8,
#          ('<s>', '<s>', 'How'): 368,
#          ('<s>', 'How', 'was'): 6,
#          ('How', 'was', 'she'): 1,
#          ('was', 'she', 'to'): 4,
#          ('she', 'to', 'bear'): 1,
#          ('to', 'bear', 'the'): 15,
#          ('bear', 'the', 'change'): 2,
#          ('the', 'change', '?--'): 1,
#          ('change', '?--', 'It'): 1,
#          ('?--', 'It', 'was'): 4,
#          ('It', 'was', 'true'): 4,
#          ('was', 'true', 'that'): 4,
#          ('true', 'that', 'her'): 1,
#          ('that', 'her', 'friend'): 5,
#          ('her', 'friend', 'was'): 3,
#          ('friend', 'was', 'going'): 1,
#          ('was', 'going', 'only'): 1,
#          ('going', 'only', 'half'): 1,
#          ('only', 'half', 'a'): 6,
#          ('half', 'a', 'mile'): 11,
#          ('a', 'mile', 'from'): 10,
#          ('mile', 'from', 'them'): 2,
#          ('from', 'them', ';'): 4,
#          ('them', ';', 'but'): 30,
#          (';', 'but', 'Emma'): 9,
#          ('but', 'Emma', 'was'): 2,
#          ('Emma', 'was', 'aware'): 1,
#          ('was', 'aware', 'that'): 2,
#          ('aware', 'that', 'great'): 1,
#          ('that', 'great', 'must'): 1,
#          ('great', 'must', 'be'): 1,
#          ('must', 'be', 'the'): 34,
#          ('be', 'the', 'difference'): 1,
#          ('the', 'difference', 'between'): 14,
#          ('difference', 'between', 'a'): 5,
#          ('between', 'a', 'Mrs'): 1,
#          ('a', 'Mrs', '.'): 4,
#          ('Mrs', '.', 'Weston'): 249,
#          ('.', 'Weston', ','): 104,
#          ('Weston', ',', 'only'): 1,
#          (',', 'only', 'half'): 3,
#          ('from', 'them', ','): 43,
#          ('them', ',', 'and'): 605,
#          ('and', 'a', 'Miss'): 1,
#          ('a', 'Miss', 'Taylor'): 1,
#          ('Miss', 'Taylor', 'in'): 1,
#          ('Taylor', 'in', 'the'): 1,
#          ('in', 'the', 'house'): 213,
#          ('the', 'house', ';'): 39,
#          ('house', ';', 'and'): 45,
#          (';', 'and', 'with'): 83,
#          ('and', 'with', 'all'): 50,
#          ('with', 'all', 'her'): 26,
#          ('all', 'her', 'advantages'): 1,
#          ('her', 'advantages', ','): 1,
#          ('advantages', ',', 'natural'): 1,
#          (',', 'natural', 'and'): 1,
#          ('natural', 'and', 'domestic'): 1,
#          ('and', 'domestic', ','): 1,
#          ('domestic', ',', 'she'): 1,
#          (',', 'she', 'was'): 133,
#          ('she', 'was', 'now'): 16,
#          ('was', 'now', 'in'): 8,
#          ('now', 'in', 'great'): 1,
#          ('in', 'great', 'danger'): 3,
#          ('great', 'danger', 'of'): 1,
#          ('danger', 'of', 'suffering'): 2,
#          ('of', 'suffering', 'from'): 2,
#          ('suffering', 'from', 'intellectual'): 1,
#          ('from', 'intellectual', 'solitude'): 1,
#          ('intellectual', 'solitude', '.'): 1,
#          ('solitude', '.', '</s>'): 5,
#          ('<s>', 'She', 'dearly'): 1,
#          ('She', 'dearly', 'loved'): 1,
#          ('dearly', 'loved', 'her'): 1,
#          ('loved', 'her', 'father'): 1,
#          ('her', 'father', ','): 52,
#          ('father', ',', 'but'): 6,
#          (',', 'but', 'he'): 167,
#          ('but', 'he', 'was'): 47,
#          ('he', 'was', 'no'): 6,
#          ('was', 'no', 'companion'): 1,
#          ('no', 'companion', 'for'): 1,
#          ('companion', 'for', 'her'): 2,
#          ('<s>', '<s>', 'He'): 2414,
#          ('<s>', 'He', 'could'): 48,
#          ('He', 'could', 'not'): 25,
#          ('could', 'not', 'meet'): 2,
#          ('not', 'meet', 'her'): 1,
#          ('meet', 'her', 'in'): 1,
#          ('her', 'in', 'conversation'): 2,
#          ('in', 'conversation', ','): 3,
#          ('conversation', ',', 'rational'): 1,
#          (',', 'rational', 'or'): 1,
#          ('rational', 'or', 'playful'): 1,
#          ('or', 'playful', '.'): 1,
#          ('playful', '.', '</s>'): 1,
#          ('<s>', 'The', 'evil'): 4,
#          ('The', 'evil', 'of'): 3,
#          ('evil', 'of', 'the'): 10,
#          ('of', 'the', 'actual'): 2,
#          ('the', 'actual', 'disparity'): 1,
#          ('actual', 'disparity', 'in'): 1,
#          ('disparity', 'in', 'their'): 1,
#          ('in', 'their', 'ages'): 1,
#          ('their', 'ages', '('): 1,
#          ('ages', '(', 'and'): 1,
#          ('(', 'and', 'Mr'): 2,
#          ('and', 'Mr', '.'): 109,
#          ('.', 'Woodhouse', 'had'): 8,
#          ('Woodhouse', 'had', 'not'): 1,
#          ('had', 'not', 'married'): 2,
#          ('not', 'married', 'early'): 1,
#          ('married', 'early', ')'): 1,
#          ('early', ')', 'was'): 1,
#          (')', 'was', 'much'): 1,
#          ('was', 'much', 'increased'): 2,
#          ('much', 'increased', 'by'): 4,
#          ('increased', 'by', 'his'): 1,
#          ('by', 'his', 'constitution'): 1,
#          ('his', 'constitution', 'and'): 1,
#          ('constitution', 'and', 'habits'): 1,
#          ('and', 'habits', ';'): 2,
#          ('habits', ';', 'for'): 2,
#          (';', 'for', 'having'): 2,
#          ('for', 'having', 'been'): 4,
#          ('having', 'been', 'a'): 6,
#          ('been', 'a', 'valetudinarian'): 1,
#          ('a', 'valetudinarian', 'all'): 1,
#          ('valetudinarian', 'all', 'his'): 1,
#          ('all', 'his', 'life'): 11,
#          ('his', 'life', ','): 24,
#          ('life', ',', 'without'): 2,
#          (',', 'without', 'activity'): 1,
#          ('without', 'activity', 'of'): 1,
#          ('activity', 'of', 'mind'): 1,
#          ('of', 'mind', 'or'): 3,
#          ('mind', 'or', 'body'): 1,
#          ('or', 'body', ','): 1,
#          ('body', ',', 'he'): 5,
#          (',', 'he', 'was'): 194,
#          ('he', 'was', 'a'): 85,
#          ('was', 'a', 'much'): 3,
#          ('a', 'much', 'older'): 1,
#          ('much', 'older', 'man'): 1,
#          ('older', 'man', 'in'): 1,
#          ('man', 'in', 'ways'): 1,
#          ('in', 'ways', 'than'): 1,
#          ('ways', 'than', 'in'): 1,
#          ('than', 'in', 'years'): 1,
#          ('in', 'years', ';'): 3,
#          ('years', ';', 'and'): 12,
#          (';', 'and', 'though'): 92,
#          ('and', 'though', 'everywhere'): 1,
#          ('though', 'everywhere', 'beloved'): 1,
#          ('everywhere', 'beloved', 'for'): 1,
#          ('beloved', 'for', 'the'): 2,
#          ('for', 'the', 'friendliness'): 1,
#          ('the', 'friendliness', 'of'): 1,
#          ('friendliness', 'of', 'his'): 2,
#          ('of', 'his', 'heart'): 23,
#          ('his', 'heart', 'and'): 2,
#          ('heart', 'and', 'his'): 2,
#          ('and', 'his', 'amiable'): 1,
#          ('his', 'amiable', 'temper'): 1,
#          ('amiable', 'temper', ','): 1,
#          ('temper', ',', 'his'): 1,
#          (',', 'his', 'talents'): 2,
#          ('his', 'talents', 'could'): 1,
#          ('talents', 'could', 'not'): 2,
#          ('could', 'not', 'have'): 57,
#          ('not', 'have', 'recommended'): 1,
#          ('have', 'recommended', 'him'): 1,
#          ('recommended', 'him', 'at'): 1,
#          ('him', 'at', 'any'): 2,
#          ('at', 'any', 'time'): 45,
#          ('any', 'time', '.'): 5,
#          ('time', '.', '</s>'): 210,
#          ('<s>', 'Her', 'sister'): 6,
#          ('Her', 'sister', ','): 2,
#          ('sister', ',', 'though'): 1,
#          (',', 'though', 'comparatively'): 1,
#          ('though', 'comparatively', 'but'): 1,
#          ('comparatively', 'but', 'little'): 1,
#          ('but', 'little', 'removed'): 1,
#          ('little', 'removed', 'by'): 1,
#          ('removed', 'by', 'matrimony'): 1,
#          ('by', 'matrimony', ','): 1,
#          ('matrimony', ',', 'being'): 1,
#          (',', 'being', 'settled'): 1,
#          ('being', 'settled', 'in'): 1,
#          ('settled', 'in', 'London'): 1,
#          ('in', 'London', ','): 23,
#          ('London', ',', 'only'): 1,
#          (',', 'only', 'sixteen'): 1,
#          ('only', 'sixteen', 'miles'): 1,
#          ('sixteen', 'miles', 'off'): 1,
#          ('miles', 'off', ','): 7,
#          ('off', ',', 'was'): 1,
#          (',', 'was', 'much'): 1,
#          ('was', 'much', 'beyond'): 1,
#          ('much', 'beyond', 'her'): 1,
#          ('beyond', 'her', 'daily'): 1,
#          ('her', 'daily', 'reach'): 1,
#          ('daily', 'reach', ';'): 1,
#          ('reach', ';', 'and'): 2,
#          (';', 'and', 'many'): 18,
#          ('and', 'many', 'a'): 21,
#          ('many', 'a', 'long'): 4,
#          ('a', 'long', 'October'): 1,
#          ('long', 'October', 'and'): 1,
#          ('October', 'and', 'November'): 1,
#          ('and', 'November', 'evening'): 1,
#          ('November', 'evening', 'must'): 1,
#          ('evening', 'must', 'be'): 1,
#          ('must', 'be', 'struggled'): 1,
#          ('be', 'struggled', 'through'): 1,
#          ('struggled', 'through', 'at'): 1,
#          ('through', 'at', 'Hartfield'): 1,
#          ('at', 'Hartfield', ','): 27,
#          ('Hartfield', ',', 'before'): 2,
#          (',', 'before', 'Christmas'): 1,
#          ('before', 'Christmas', 'brought'): 1,
#          ('Christmas', 'brought', 'the'): 1,
#          ('brought', 'the', 'next'): 1,
#          ('the', 'next', 'visit'): 1,
#          ('next', 'visit', 'from'): 1,
#          ('visit', 'from', 'Isabella'): 1,
#          ('from', 'Isabella', 'and'): 2,
#          ('Isabella', 'and', 'her'): 1,
#          ('and', 'her', 'husband'): 10,
#          ('her', 'husband', ','): 32,
#          ('husband', ',', 'and'): 17,
#          (',', 'and', 'their'): 289,
#          ('and', 'their', 'little'): 5,
#          ('their', 'little', 'children'): 2,
#          ('little', 'children', ','): 16,
#          ('children', ',', 'to'): 6,
#          (',', 'to', 'fill'): 6,
#          ('to', 'fill', 'the'): 6,
#          ('fill', 'the', 'house'): 1,
#          ('the', 'house', ','): 187,
#          ('house', ',', 'and'): 202,
#          (',', 'and', 'give'): 81,
#          ('and', 'give', 'her'): 1,
#          ('give', 'her', 'pleasant'): 1,
#          ('her', 'pleasant', 'society'): 1,
#          ('pleasant', 'society', 'again'): 1,
#          ('society', 'again', '.'): 1,
#          ('again', '.', '</s>'): 308,
#          ('<s>', '<s>', 'Highbury'): 2,
#          ('<s>', 'Highbury', ','): 2,
#          ('Highbury', ',', 'the'): 2,
#          (',', 'the', 'large'): 7,
#          ('the', 'large', 'and'): 2,
#          ('large', 'and', 'populous'): 1,
#          ('and', 'populous', 'village'): 1,
#          ('populous', 'village', ','): 1,
#          ('village', ',', 'almost'): 1,
#          (',', 'almost', 'amounting'): 1,
#          ('almost', 'amounting', 'to'): 1,
#          ('amounting', 'to', 'a'): 1,
#          ('to', 'a', 'town'): 1,
#          ('a', 'town', ','): 2,
#          ('town', ',', 'to'): 1,
#          (',', 'to', 'which'): 23,
#          ('to', 'which', 'Hartfield'): 1,
#          ('which', 'Hartfield', ','): 1,
#          ('Hartfield', ',', 'in'): 2,
#          (',', 'in', 'spite'): 55,
#          ('in', 'spite', 'of'): 94,
#          ('spite', 'of', 'its'): 2,
#          ('of', 'its', 'separate'): 1,
#          ('its', 'separate', 'lawn'): 1,
#          ('separate', 'lawn', ','): 1,
#          ('lawn', ',', 'and'): 3,
#          (',', 'and', 'shrubberies'): 1,
#          ('and', 'shrubberies', ','): 1,
#          ('shrubberies', ',', 'and'): 3,
#          (',', 'and', 'name'): 1,
#          ('and', 'name', ','): 2,
#          ...})

# %%
lm.highest_order
# Out:
# 3

# %%
lm.lm
# Out:
# [Counter({('1816', ']', '</s>'): -9.58744743822726,
#           (']', '</s>', '</s>'): -16.989049875687268,
#           ('<s>', '<s>', 'VOLUME'): -37.39646113320956,
#           ('<s>', 'VOLUME', 'I'): -11.695919703497736,
#           ('VOLUME', 'I', '</s>'): -16.789597499327503,
#           ('I', '</s>', '</s>'): -15.290032852708608,
#           ('<s>', '<s>', 'CHAPTER'): -30.89081331634736,
#           ('<s>', 'CHAPTER', 'I'): -15.723677090821855,
#           ('CHAPTER', 'I', '</s>'): -17.51082318178849,
#           ('<s>', '<s>', 'Emma'): -27.65961381078666,
#           ('<s>', 'Emma', 'Woodhouse'): -25.7678103823588,
#           ('Emma', 'Woodhouse', ','): -8.73027774289052,
#           ('Woodhouse', ',', 'handsome'): -28.172273395510345,
#           (',', 'handsome', ','): -7.476058939160024,
#           ('handsome', ',', 'clever'): -28.60914249746205,
#           (',', 'clever', ','): -8.77951473694336,
#           ('clever', ',', 'and'): -11.201016372200446,
#           (',', 'and', 'rich'): -30.220856031286594,
#           ('and', 'rich', ','): -10.235767519466508,
#           ('rich', ',', 'with'): -17.388982482887208,
#           (',', 'with', 'a'): -12.734106051243655,
#           ('with', 'a', 'comfortable'): -27.86062461377815,
#           ('a', 'comfortable', 'home'): -17.497311548015617,
#           ('comfortable', 'home', 'and'): -12.181419011779099,
#           ('home', 'and', 'happy'): -21.733834688471823,
#           ('and', 'happy', 'disposition'): -23.436235685773326,
#           ('happy', 'disposition', ','): -7.37999325390254,
#           ('disposition', ',', 'seemed'): -21.974270204735358,
#           (',', 'seemed', 'to'): -9.175291943636205,
#           ('seemed', 'to', 'unite'): -30.802069684292924,
#           ('to', 'unite', 'some'): -15.16121484996927,
#           ('unite', 'some', 'of'): -9.744377942874275,
#           ('some', 'of', 'the'): -11.36558017036016,
#           ('of', 'the', 'best'): -24.723151712426162,
#           ('the', 'best', 'blessings'): -25.07310619511304,
#           ('best', 'blessings', 'of'): -7.440707514979899,
#           ('blessings', 'of', 'existence'): -24.36006349725408,
#           ('of', 'existence', ';'): -9.804371717979318,
#           ('existence', ';', 'and'): -11.918208916213342,
#           (';', 'and', 'had'): -22.442787133306567,
#           ('and', 'had', 'lived'): -22.233389707887284,
#           ('had', 'lived', 'nearly'): -21.59535114058265,
#           ('lived', 'nearly', 'twenty'): -15.148006876633698,
#           ('nearly', 'twenty', '-'): -12.564503904275886,
#           ('twenty', '-', 'one'): -21.301131388086883,
#           ('-', 'one', 'years'): -19.512032273001235,
#           ('one', 'years', 'in'): -11.700917428339723,
#           ('years', 'in', 'the'): -11.61141749176354,
#           ('in', 'the', 'world'): -21.044700456239568,
#           ('the', 'world', 'with'): -18.456273095714995,
#           ('world', 'with', 'very'): -20.1778930715306,
#           ('with', 'very', 'little'): -14.904987870764982,
#           ('very', 'little', 'to'): -14.058046217448375,
#           ('little', 'to', 'distress'): -24.248716356946993,
#           ('to', 'distress', 'or'): -16.175461559548225,
#           ('distress', 'or', 'vex'): -22.636433965512605,
#           ('or', 'vex', 'her'): -11.55668991307193,
#           ('vex', 'her', '.'): -10.627990334667038,
#           ('her', '.', '</s>'): -15.342460089454443,
#           ('.', '</s>', '</s>'): -23.769293024154237,
#           ('<s>', '<s>', 'She'): -26.878819898192326,
#           ('<s>', 'She', 'was'): -13.565549621123507,
#           ('She', 'was', 'the'): -14.940583683093138,
#           ('was', 'the', 'youngest'): -27.485131810501173,
#           ('the', 'youngest', 'of'): -11.74321939823925,
#           ('youngest', 'of', 'the'): -10.231919461161027,
#           ('of', 'the', 'two'): -22.440954249495142,
#           ('the', 'two', 'daughters'): -22.0220227481708,
#           ('two', 'daughters', 'of'): -11.966564078251846,
#           ('daughters', 'of', 'a'): -15.824730223786938,
#           ('of', 'a', 'most'): -21.487501905457165,
#           ('a', 'most', 'affectionate'): -22.764008631734388,
#           ('most', 'affectionate', ','): -9.483971066913417,
#           ('affectionate', ',', 'indulgent'): -29.323362122623085,
#           (',', 'indulgent', 'father'): -15.53674066265521,
#           ('indulgent', 'father', ';'): -10.62492454038898,
#           ('father', ';', 'and'): -10.144854382833751,
#           ('and', 'had', ','): -14.45138773882007,
#           ('had', ',', 'in'): -14.187342297560296,
#           (',', 'in', 'consequence'): -26.800947039045013,
#           ('in', 'consequence', 'of'): -9.391336187439084,
#           ('consequence', 'of', 'her'): -15.595166631169297,
#           ('of', 'her', 'sister'): -19.761498426043328,
#           ('her', 'sister', "'"): -11.802172714656702,
#           ('sister', "'", 's'): -18.14367322824195,
#           ("'", 's', 'marriage'): -27.10360746229075,
#           ('s', 'marriage', ','): -7.978194619958199,
#           ('marriage', ',', 'been'): -23.1975871934307,
#           (',', 'been', 'mistress'): -22.479807386655835,
#           ('been', 'mistress', 'of'): -8.373345646417707,
#           ('mistress', 'of', 'his'): -16.163566098963344,
#           ('of', 'his', 'house'): -20.51491056977864,
#           ('his', 'house', 'from'): -21.214049751315226,
#           ('house', 'from', 'a'): -13.959910572092975,
#           ('from', 'a', 'very'): -19.238621598326645,
#           ('a', 'very', 'early'): -20.720110611705948,
#           ('very', 'early', 'period'): -19.957844721639688,
#           ('early', 'period', '.'): -11.530668452616007,
#           ('period', '.', '</s>'): -10.935740141983018,
#           ('<s>', '<s>', 'Her'): -28.214725027757904,
#           ('<s>', 'Her', 'mother'): -19.601730752108605,
#           ('Her', 'mother', 'had'): -14.456206326462716,
#           ('mother', 'had', 'died'): -19.178248991065985,
#           ('had', 'died', 'too'): -20.476341353571755,
#           ('died', 'too', 'long'): -14.43885765268581,
#           ('too', 'long', 'ago'): -19.921452352122508,
#           ('long', 'ago', 'for'): -16.281961782511285,
#           ('ago', 'for', 'her'): -14.511891977834788,
#           ('for', 'her', 'to'): -13.26400961155028,
#           ('her', 'to', 'have'): -18.303178459614706,
#           ('to', 'have', 'more'): -20.55742255897947,
#           ('have', 'more', 'than'): -11.555097643407496,
#           ('more', 'than', 'an'): -19.433300680244457,
#           ('than', 'an', 'indistinct'): -26.414358603783228,
#           ('an', 'indistinct', 'remembrance'): -15.636022132236656,
#           ('indistinct', 'remembrance', 'of'): -8.396466211747688,
#           ('remembrance', 'of', 'her'): -15.922527650282168,
#           ('of', 'her', 'caresses'): -32.391783401005874,
#           ('her', 'caresses', ';'): -10.053703177879186,
#           ('caresses', ';', 'and'): -10.30877100377924,
#           (';', 'and', 'her'): -19.72537566131208,
#           ('and', 'her', 'place'): -24.09390210346467,
#           ('her', 'place', 'had'): -18.286186295320984,
#           ('place', 'had', 'been'): -15.663326179673712,
#           ('had', 'been', 'supplied'): -27.914784990451277,
#           ('been', 'supplied', 'by'): -12.246305242718403,
#           ('supplied', 'by', 'an'): -15.590629314754448,
#           ('by', 'an', 'excellent'): -21.352113158244272,
#           ('an', 'excellent', 'woman'): -19.473019424758686,
#           ('excellent', 'woman', 'as'): -14.446130429211681,
#           ('woman', 'as', 'governess'): -24.980140675246748,
#           ('as', 'governess', ','): -7.1292062804622205,
#           ('governess', ',', 'who'): -18.084221379720162,
#           (',', 'who', 'had'): -13.654006327372635,
#           ('who', 'had', 'fallen'): -24.34911258847002,
#           ('had', 'fallen', 'little'): -20.62851198116172,
#           ('fallen', 'little', 'short'): -18.873691779615722,
#           ('little', 'short', 'of'): -9.537645554089528,
#           ('short', 'of', 'a'): -13.779197723888663,
#           ('of', 'a', 'mother'): -25.74376949888319,
#           ('a', 'mother', 'in'): -12.861277198679964,
#           ('mother', 'in', 'affection'): -28.087754160649872,
#           ('in', 'affection', '.'): -9.746175251779482,
#           ('affection', '.', '</s>'): -11.764259471744072,
#           ('<s>', '<s>', 'Sixteen'): -36.297848844541456,
#           ('<s>', 'Sixteen', 'years'): -13.109951797354492,
#           ('Sixteen', 'years', 'had'): -14.82881743403095,
#           ('years', 'had', 'Miss'): -21.86192087793338,
#           ('had', 'Miss', 'Taylor'): -18.275103964118607,
#           ('Miss', 'Taylor', 'been'): -19.529829459243693,
#           ('Taylor', 'been', 'in'): -11.56050036279157,
#           ('been', 'in', 'Mr'): -21.550668519125217,
#           ('in', 'Mr', '.'): -9.132485825375268,
#           ('Mr', '.', 'Woodhouse'): -31.493120514246094,
#           ('.', 'Woodhouse', "'"): -13.0617750884124,
#           ('Woodhouse', "'", 's'): -17.318523175877637,
#           ("'", 's', 'family'): -26.111808598166885,
#           ('s', 'family', ','): -8.038372125921466,
#           ('family', ',', 'less'): -26.28957466308168,
#           (',', 'less', 'as'): -18.41988868721742,
#           ('less', 'as', 'a'): -11.712031467799976,
#           ('as', 'a', 'governess'): -30.9585739083038,
#           ('a', 'governess', 'than'): -14.097977941456298,
#           ('governess', 'than', 'a'): -12.222763734304221,
#           ('than', 'a', 'friend'): -22.86692659191624,
#           ('a', 'friend', ','): -9.000819779712312,
#           ('friend', ',', 'very'): -23.502354625412607,
#           (',', 'very', 'fond'): -23.266122794600086,
#           ('very', 'fond', 'of'): -8.377079286198258,
#           ('fond', 'of', 'both'): -22.863123890387573,
#           ('of', 'both', 'daughters'): -24.33309633554937,
#           ('both', 'daughters', ','): -8.253056352787835,
#           ('daughters', ',', 'but'): -17.11803564398574,
#           (',', 'but', 'particularly'): -28.117463076969372,
#           ('but', 'particularly', 'of'): -14.198235197050534,
#           ('particularly', 'of', 'Emma'): -20.207180429170034,
#           ('of', 'Emma', '.'): -11.436553334986835,
#           ('Emma', '.', '</s>'): -13.05016358085899,
#           ('<s>', '<s>', 'Between'): -33.8223662777786,
#           ('<s>', 'Between', '_them_'): -21.69835059499102,
#           ('Between', '_them_', 'it'): -10.459663172755482,
#           ('_them_', 'it', 'was'): -12.502545022004039,
#           ('it', 'was', 'more'): -20.668156751527505,
#           ('was', 'more', 'the'): -17.33050500119769,
#           ('more', 'the', 'intimacy'): -27.25038049083372,
#           ('the', 'intimacy', 'of'): -13.581816801796425,
#           ('intimacy', 'of', 'sisters'): -23.77484863255024,
#           ('of', 'sisters', '.'): -10.362000460655583,
#           ('sisters', '.', '</s>'): -11.764259471744072,
#           ('<s>', '<s>', 'Even'): -29.93201175229392,
#           ('<s>', 'Even', 'before'): -20.205524951983225,
#           ('Even', 'before', 'Miss'): -18.563087217139554,
#           ('before', 'Miss', 'Taylor'): -20.06470548331118,
#           ('Miss', 'Taylor', 'had'): -14.68373566537982,
#           ('Taylor', 'had', 'ceased'): -20.609529189735362,
#           ('had', 'ceased', 'to'): -9.390051967528278,
#           ('ceased', 'to', 'hold'): -22.210450607131037,
#           ('to', 'hold', 'the'): -11.372938272774658,
#           ('hold', 'the', 'nominal'): -30.09938194160448,
#           ('the', 'nominal', 'office'): -15.268297352111338,
#           ('nominal', 'office', 'of'): -9.835920037746591,
#           ('office', 'of', 'governess'): -29.699929105532718,
#           ('of', 'governess', ','): -7.1413330834169,
#           ('governess', ',', 'the'): -14.252535909054409,
#           (',', 'the', 'mildness'): -34.54561286705335,
#           ('the', 'mildness', 'of'): -7.9505503918852005,
#           ('mildness', 'of', 'her'): -13.619491639735255,
#           ('of', 'her', 'temper'): -24.194390318617515,
#           ('her', 'temper', 'had'): -15.776112474091535,
#           ('temper', 'had', 'hardly'): -19.772811432944465,
#           ('had', 'hardly', 'allowed'): -21.687890423597317,
#           ('hardly', 'allowed', 'her'): -10.929021528610768,
#           ('allowed', 'her', 'to'): -12.23579473660621,
#           ('her', 'to', 'impose'): -30.329127683007748,
#           ('to', 'impose', 'any'): -14.652103090465532,
#           ('impose', 'any', 'restraint'): -20.53018791002393,
#           ('any', 'restraint', ';'): -10.578958582291621,
#           ('restraint', ';', 'and'): -11.407383292447351,
#           (';', 'and', 'the'): -13.312554110604886,
#           ('and', 'the', 'shadow'): -27.0325678118083,
#           ('the', 'shadow', 'of'): -9.113813024859299,
#           ('shadow', 'of', 'authority'): -26.695957548785675,
#           ('of', 'authority', 'being'): -17.818288571585818,
#           ('authority', 'being', 'now'): -14.477521112519504,
#           ('being', 'now', 'long'): -22.307822137892426,
#           ('now', 'long', 'passed'): -18.016932967555906,
#           ('long', 'passed', 'away'): -12.777245576395787,
#           ('passed', 'away', ','): -9.13313634215254,
#           ('away', ',', 'they'): -18.28714071016035,
#           (',', 'they', 'had'): -15.893580763086579,
#           ('they', 'had', 'been'): -15.875172742486725,
#           ('had', 'been', 'living'): -25.054551827438974,
#           ('been', 'living', 'together'): -16.64136715000391,
#           ('living', 'together', 'as'): -13.854500234625277,
#           ('together', 'as', 'friend'): -23.886167617242577,
#           ('as', 'friend', 'and'): -11.750962144468335,
#           ('friend', 'and', 'friend'): -22.550314540582097,
#           ('and', 'friend', 'very'): -18.41685445938826,
#           ('friend', 'very', 'mutually'): -23.177406801627562,
#           ('very', 'mutually', 'attached'): -15.774858577090871,
#           ('mutually', 'attached', ','): -10.108216870418433,
#           ('attached', ',', 'and'): -11.962169903645144,
#           (',', 'and', 'Emma'): -26.6176719310458,
#           ('and', 'Emma', 'doing'): -23.954252212456538,
#           ('Emma', 'doing', 'just'): -15.714713970396582,
#           ('doing', 'just', 'what'): -13.441827408602782,
#           ('just', 'what', 'she'): -15.944164459756934,
#           ('what', 'she', 'liked'): -22.953088190484273,
#           ('she', 'liked', ';'): -14.225433676374426,
#           ('liked', ';', 'highly'): -24.226220218405622,
#           (';', 'highly', 'esteeming'): -21.49283765809121,
#           ('highly', 'esteeming', 'Miss'): -12.151937090768731,
#           ('esteeming', 'Miss', 'Taylor'): -18.513138678775462,
#           ('Miss', 'Taylor', "'"): -12.928777211680346,
#           ('Taylor', "'", 's'): -15.961981878875342,
#           ("'", 's', 'judgment'): -26.839120151140584,
#           ('s', 'judgment', ','): -9.050920388955285,
#           ('judgment', ',', 'but'): -17.946375495423492,
#           (',', 'but', 'directed'): -31.85389474597855,
#           ('but', 'directed', 'chiefly'): -17.260647435940392,
#           ('directed', 'chiefly', 'by'): -11.489093549426338,
#           ('chiefly', 'by', 'her'): -14.155636098301889,
#           ('by', 'her', 'own'): -18.67578605784496,
#           ('her', 'own', '.'): -13.130350495220544,
#           ('own', '.', '</s>'): -13.570387969166697,
#           ('<s>', '<s>', 'The'): -23.61274914221983,
#           ('<s>', 'The', 'real'): -26.24588490452287,
#           ('The', 'real', 'evils'): -21.28400931684019,
#           ('real', 'evils', ','): -7.047817228909492,
#           ('evils', ',', 'indeed'): -20.58946312159042,
#           (',', 'indeed', ','): -9.2066527606899,
#           ('indeed', ',', 'of'): -18.130611277481744,
#           (',', 'of', 'Emma'): -26.463883158024135,
#           ('of', 'Emma', "'"): -10.328369114319623,
#           ('Emma', "'", 's'): -17.63600416298608,
#           ("'", 's', 'situation'): -26.713114680766253,
#           ('s', 'situation', 'were'): -18.192844634427125,
#           ('situation', 'were', 'the'): -11.455809584483715,
#           ('were', 'the', 'power'): -24.689310315708067,
#           ('the', 'power', 'of'): -10.472493381933136,
#           ('power', 'of', 'having'): -23.49741629582792,
#           ('of', 'having', 'rather'): -22.60458884547924,
#           ('having', 'rather', 'too'): -13.807258301599026,
#           ('rather', 'too', 'much'): -12.63677051469674,
#           ('too', 'much', 'her'): -21.089218682732547,
#           ('much', 'her', 'own'): -18.28994696589722,
#           ('her', 'own', 'way'): -18.572577263892796,
#           ('own', 'way', ','): -9.163404843077451,
#           ('way', ',', 'and'): -11.363304939276695,
#           (',', 'and', 'a'): -17.043534974329656,
#           ('and', 'a', 'disposition'): -26.368626994262314,
#           ('a', 'disposition', 'to'): -9.770968832660515,
#           ('disposition', 'to', 'think'): -20.051215762293378,
#           ('to', 'think', 'a'): -17.40756782617715,
#           ('think', 'a', 'little'): -17.729754376313473,
#           ('a', 'little', 'too'): -22.022190854857172,
#           ('little', 'too', 'well'): -16.576149889299355,
#           ('too', 'well', 'of'): -15.153685783797744,
#           ('well', 'of', 'herself'): -22.2396440553778,
#           ('of', 'herself', ';'): -12.872069992897384,
#           ('herself', ';', 'these'): -22.89116851082006,
#           (';', 'these', 'were'): -13.683648023400934,
#           ('these', 'were', 'the'): -11.312395630396734,
#           ('were', 'the', 'disadvantages'): -33.70405034990424,
#           ('the', 'disadvantages', 'which'): -10.703949160643502,
#           ('disadvantages', 'which', 'threatened'): -22.12569764533777,
#           ('which', 'threatened', 'alloy'): -18.901279763339517,
#           ('threatened', 'alloy', 'to'): -8.956930496267413,
#           ('alloy', 'to', 'her'): -14.611082190667556,
#           ('to', 'her', 'many'): -25.476349765644862,
#           ('her', 'many', 'enjoyments'): -24.198710177434613,
#           ('many', 'enjoyments', '.'): -8.573761495974525,
#           ('enjoyments', '.', '</s>'): -10.94659665104342,
#           ('<s>', 'The', 'danger'): -25.905286291789885,
#           ('The', 'danger', ','): -8.32213042856301,
#           ('danger', ',', 'however'): -22.44309782276907,
#           (',', 'however', ','): -8.565584232959393,
#           ('however', ',', 'was'): -16.702610756429202,
#           (',', 'was', 'at'): -17.278890130652012,
#           ('was', 'at', 'present'): -20.657525591087975,
#           ('at', 'present', 'so'): -19.678625885228058,
#           ('present', 'so', 'unperceived'): -24.827048359357793,
#           ('so', 'unperceived', ','): -8.618206289038527,
#           ('unperceived', ',', 'that'): -13.286746084350433,
#           (',', 'that', 'they'): -16.38789753051896,
#           ('that', 'they', 'did'): -19.645583640751035,
#           ('they', 'did', 'not'): -11.771789209029198,
#           ('did', 'not', 'by'): -20.60424168493407,
#           ('not', 'by', 'any'): -14.969863594750557,
#           ('by', 'any', 'means'): -19.9271949128534,
#           ('any', 'means', 'rank'): -22.52650760202844,
#           ('means', 'rank', 'as'): -11.679245024662615,
#           ('rank', 'as', 'misfortunes'): -26.297283535844617,
#           ('as', 'misfortunes', 'with'): -10.581959339500676,
#           ('misfortunes', 'with', 'her'): -12.8399663191267,
#           ('with', 'her', '.'): -12.846363132287573,
#           ('<s>', '<s>', 'Sorrow'): -37.661615470943076,
#           ('<s>', 'Sorrow', 'came'): -12.354884816640634,
#           ('Sorrow', 'came', '--'): -14.910317628398642,
#           ('came', '--', 'a'): -14.00086445275822,
#           ('--', 'a', 'gentle'): -26.068639431290034,
#           ('a', 'gentle', 'sorrow'): -19.891688467382483,
#           ('gentle', 'sorrow', '--'): -13.201429787463198,
#           ('sorrow', '--', 'but'): -14.197322130873351,
#           ('--', 'but', 'not'): -16.847494207726804,
#           ('but', 'not', 'at'): -15.897502283011951,
#           ('not', 'at', 'all'): -12.896246768328934,
#           ('at', 'all', 'in'): -15.602077546254787,
#           ('all', 'in', 'the'): -10.747940120362744,
#           ('in', 'the', 'shape'): -27.396122426428988,
#           ('the', 'shape', 'of'): -9.267938101746983,
#           ('shape', 'of', 'any'): -18.77019611310357,
#           ('of', 'any', 'disagreeable'): -26.978325758299466,
#           ('any', 'disagreeable', 'consciousness'): -17.882429910349032,
#           ('disagreeable', 'consciousness', '.--'): -14.773099093994665,
#           ('consciousness', '.--', 'Miss'): -16.757083262046375,
#           ('.--', 'Miss', 'Taylor'): -20.25253701192583,
#           ('Miss', 'Taylor', 'married'): -20.506551930302766,
#           ('Taylor', 'married', '.'): -9.069503361900034,
#           ('married', '.', '</s>'): -12.25320855358663,
#           ('<s>', '<s>', 'It'): -26.139086404860784,
#           ('<s>', 'It', 'was'): -12.688794867879956,
#           ('It', 'was', 'Miss'): -29.482626739398043,
#           ('was', 'Miss', 'Taylor'): -18.513138678775462,
#           ("'", 's', 'loss'): -28.321507109943465,
#           ('s', 'loss', 'which'): -16.156171344182614,
#           ('loss', 'which', 'first'): -17.42081789122403,
#           ('which', 'first', 'brought'): -18.44869152109652,
#           ('first', 'brought', 'grief'): -22.222833825615986,
#           ('brought', 'grief', '.'): -9.159766323518822,
#           ('grief', '.', '</s>'): -11.282934210777974,
#           ('It', 'was', 'on'): -18.598208488034757,
#           ('was', 'on', 'the'): -10.215538925908433,
#           ('on', 'the', 'wedding'): -31.635704296549953,
#           ('the', 'wedding', '-'): -10.311562600232895,
#           ('wedding', '-', 'day'): -16.434486657217263,
#           ('-', 'day', 'of'): -14.424088073121958,
#           ('day', 'of', 'this'): -17.76495525217235,
#           ('of', 'this', 'beloved'): -29.343752525183092,
#           ('this', 'beloved', 'friend'): -16.962647193183,
#           ('beloved', 'friend', 'that'): -13.287169463399875,
#           ('friend', 'that', 'Emma'): -20.6393396269247,
#           ('that', 'Emma', 'first'): -20.151327757994636,
#           ('Emma', 'first', 'sat'): -19.976116803413948,
#           ('first', 'sat', 'in'): -10.20803795823109,
#           ('sat', 'in', 'mournful'): -30.865597852275496,
#           ('in', 'mournful', 'thought'): -13.753284043533409,
#           ('mournful', 'thought', 'of'): -9.986876596441663,
#           ('thought', 'of', 'any'): -19.81468519367369,
#           ('of', 'any', 'continuance'): -28.88304747628433,
#           ('any', 'continuance', '.'): -9.01959560302757,
#           ('continuance', '.', '</s>'): -10.94659665104342,
#           ('<s>', 'The', 'wedding'): -27.98994128770805,
#           ('The', 'wedding', 'over'): -15.553130802635343,
#           ('wedding', 'over', ','): -10.344559075675576,
#           ('over', ',', 'and'): -11.138967161155401,
#           (',', 'and', 'the'): -13.257958556464136,
#           ('and', 'the', 'bride'): -30.20527792521378,
#           ('the', 'bride', '-'): -15.871447581720098,
#           ('bride', '-', 'people'): -19.132362669205992,
#           ('-', 'people', 'gone'): -20.477254289965046,
#           ('people', 'gone', ','): -8.999644663476468,
#           ('gone', ',', 'her'): -20.898849778017674,
#           (',', 'her', 'father'): -18.246358430159717,
#           ('her', 'father', 'and'): -11.861873576868142,
#           ('father', 'and', 'herself'): -22.13675253485247,
#           ('and', 'herself', 'were'): -20.8335272958741,
#           ('herself', 'were', 'left'): -16.477077719642025,
#           ('were', 'left', 'to'): -12.878837354547013,
#           ('left', 'to', 'dine'): -24.704718908009166,
#           ('to', 'dine', 'together'): -18.614849911013273,
#           ('dine', 'together', ','): -8.450921062564932,
#           ('together', ',', 'with'): -20.138647480562035,
#           (',', 'with', 'no'): -20.833062595242605,
#           ('with', 'no', 'prospect'): -26.20098654942165,
#           ('no', 'prospect', 'of'): -8.528343224541366,
#           ('prospect', 'of', 'a'): -13.606912356383761,
#           ('of', 'a', 'third'): -25.558953039310737,
#           ('a', 'third', 'to'): -15.651036215993312,
#           ('third', 'to', 'cheer'): -24.33481012427913,
#           ('to', 'cheer', 'a'): -14.65441747460549,
#           ('cheer', 'a', 'long'): -16.13192692635519,
#           ('a', 'long', 'evening'): -24.2885104109304,
#           ('long', 'evening', '.'): -10.172652775665219,
#           ('evening', '.', '</s>'): -13.154550680226063,
#           ('<s>', 'Her', 'father'): -17.758962056647025,
#           ('Her', 'father', 'composed'): -23.81268065468415,
#           ('father', 'composed', 'himself'): -14.031794372336103,
#           ('composed', 'himself', 'to'): -10.756538759328356,
#           ('himself', 'to', 'sleep'): -24.54922442204725,
#           ('to', 'sleep', 'after'): -20.44721176639051,
#           ('sleep', 'after', 'dinner'): -16.95991494549449,
#           ('after', 'dinner', ','): -7.787551941134361,
#           ('dinner', ',', 'as'): -14.963472121378357,
#           (',', 'as', 'usual'): -25.135408433940952,
#           ('as', 'usual', ','): -9.718901001504989,
#           ('usual', ',', 'and'): -11.451406923961898,
#           (',', 'and', 'she'): -21.58360471600175,
#           ('and', 'she', 'had'): -14.101652030283004,
#           ('she', 'had', 'then'): -22.14413646823653,
#           ('had', 'then', 'only'): -19.66218974585442,
#           ('then', 'only', 'to'): -12.419422881414876,
#           ('only', 'to', 'sit'): -23.919012040869408,
#           ('to', 'sit', 'and'): -12.858136128972289,
#           ('sit', 'and', 'think'): -22.578456689788077,
#           ('and', 'think', 'of'): -12.624925975425342,
#           ('think', 'of', 'what'): -19.3070122410783,
#           ('of', 'what', 'she'): -15.72544398314223,
#           ('what', 'she', 'had'): -12.53370426760234,
#           ('she', 'had', 'lost'): -23.433137693483506,
#           ('had', 'lost', '.'): -11.637555393402922,
#           ('lost', '.', '</s>'): -12.509344628610512,
#           ('<s>', 'The', 'event'): -27.714110266023376,
#           ('The', 'event', 'had'): -14.110920832420641,
#           ('event', 'had', 'every'): -17.700808293171,
#           ('had', 'every', 'promise'): -23.64517048555591,
#           ('every', 'promise', 'of'): -9.602884438017798,
#           ('promise', 'of', 'happiness'): -23.929118031953816,
#           ('of', 'happiness', 'for'): -16.809017946412524,
#           ('happiness', 'for', 'her'): -13.818744797274842,
#           ('for', 'her', 'friend'): -20.21449028859561,
#           ('her', 'friend', '.'): -10.940438495956233,
#           ('friend', '.', '</s>'): -13.570387969166697,
#           ('<s>', '<s>', 'Mr'): -26.2537925251121,
#           ('<s>', 'Mr', '.'): -9.89812560429713,
#           ('Mr', '.', 'Weston'): -28.243853972517403,
#           ('.', 'Weston', 'was'): -14.150119917699653,
#           ('Weston', 'was', 'a'): -13.342393106750041,
#           ('was', 'a', 'man'): -16.855486173861564,
#           ('a', 'man', 'of'): -12.716547300808047,
#           ('man', 'of', 'unexceptionable'): -33.405820360826496,
#           ('of', 'unexceptionable', 'character'): -14.513018390444387,
#           ('unexceptionable', 'character', ','): -8.179510322616418,
#           ('character', ',', 'easy'): -27.075528426018764,
#           (',', 'easy', 'fortune'): -20.995883598026378,
#           ('easy', 'fortune', ','): -7.578462154930489,
#           ('fortune', ',', 'suitable'): -30.94130954819095,
#           (',', 'suitable', 'age'): -16.202655367504214,
#           ('suitable', 'age', ','): -7.6485923839526055,
#           ('age', ',', 'and'): -10.966269356532422,
#           (',', 'and', 'pleasant'): -30.174204746294905,
#           ('and', 'pleasant', 'manners'): -20.86178681666347,
#           ('pleasant', 'manners', ';'): -11.575690843362754,
#           ('manners', ';', 'and'): -10.070736289122388,
#           (';', 'and', 'there'): -21.032064922887606,
#           ('and', 'there', 'was'): -13.241574885214293,
#           ('there', 'was', 'some'): -22.3162308546507,
#           ('was', 'some', 'satisfaction'): -23.154702338066734,
#           ('some', 'satisfaction', 'in'): -9.191949911165436,
#           ('satisfaction', 'in', 'considering'): -27.870774298936837,
#           ('in', 'considering', 'with'): -13.0770865754524,
#           ('considering', 'with', 'what'): -15.752968810717066,
#           ('with', 'what', 'self'): -25.566508094919207,
#           ('what', 'self', '-'): -9.759788971608494,
#           ('self', '-', 'denying'): -25.470035081697095,
#           ('-', 'denying', ','): -10.27403425073804,
#           ('denying', ',', 'generous'): -24.586512690516443,
#           (',', 'generous', 'friendship'): -17.9856591618599,
#           ('generous', 'friendship', 'she'): -16.110566092195096,
#           ('friendship', 'she', 'had'): -12.197485714171128,
#           ('she', 'had', 'always'): -20.429920146599354,
#           ('had', 'always', 'wished'): -22.577753023140605,
#           ('always', 'wished', 'and'): -13.36058418996276,
#           ('wished', 'and', 'promoted'): -25.011513291399755,
#           ('and', 'promoted', 'the'): -9.90937325375987,
#           ('promoted', 'the', 'match'): -22.020630118099838,
#           ('the', 'match', ';'): -13.205396156025389,
#           ('match', ';', 'but'): -13.344083500368416,
#           (';', 'but', 'it'): -16.181721734419625,
#           ('but', 'it', 'was'): -13.328701810420721,
#           ('it', 'was', 'a'): -14.474042904983412,
#           ('was', 'a', 'black'): -24.25355285005154,
#           ('a', 'black', 'morning'): -22.086568994119148,
#           ('black', 'morning', "'"): -11.797019919833499,
#           ('morning', "'", 's'): -16.15606362617256,
#           ("'", 's', 'work'): -24.68276007690072,
#           ('s', 'work', 'for'): -13.167571022754858,
#           ('work', 'for', 'her'): -16.788480925982064,
#           ('for', 'her', '.'): -12.149299799250551,
#           ('<s>', 'The', 'want'): -28.21944812529063,
#           ('The', 'want', 'of'): -8.671708452020145,
#           ('want', 'of', 'Miss'): -22.910692065810096,
#           ('of', 'Miss', 'Taylor'): -20.60829562828598,
#           ('Miss', 'Taylor', 'would'): -18.02438126033364,
#           ('Taylor', 'would', 'be'): -12.062885811861563,
#           ('would', 'be', 'felt'): -25.90349032706345,
#           ('be', 'felt', 'every'): -18.399913906323903,
#           ('felt', 'every', 'hour'): -17.237660630024358,
#           ('every', 'hour', 'of'): -9.299684214332547,
#           ('hour', 'of', 'every'): -18.804461652765298,
#           ('of', 'every', 'day'): -16.127141371446434,
#           ('every', 'day', '.'): -11.173131232891501,
#           ('day', '.', '</s>'): -15.034824687502397,
#           ('<s>', 'She', 'recalled'): -28.89481808332119,
#           ('She', 'recalled', 'her'): -12.678667979825146,
#           ('recalled', 'her', 'past'): -20.180095213547936,
#           ('her', 'past', 'kindness'): -18.266461285111404,
#           ('past', 'kindness', '--'): -14.096188976466681,
#           ('kindness', '--', 'the'): -11.795829862249647,
#           ('--', 'the', 'kindness'): -26.470615924240963,
#           ('the', 'kindness', ','): -11.447998934885817,
#           ('kindness', ',', 'the'): -14.596323733379693,
#           (',', 'the', 'affection'): -31.022854317257742,
#           ('the', 'affection', 'of'): -11.264265249117756,
#           ('affection', 'of', 'sixteen'): -27.537652142984367,
#           ('of', 'sixteen', 'years'): -13.270154617351297,
#           ('sixteen', 'years', '--'): -16.027449318033657,
#           ('years', '--', 'how'): -18.393280096756577,
#           ('--', 'how', 'she'): -15.736187362464202,
#           ('how', 'she', 'had'): -13.104484569022652,
#           ('she', 'had', 'taught'): -26.99010087468114,
#           ('had', 'taught', 'and'): -14.031448523607134,
#           ('taught', 'and', 'how'): -18.818201982058223,
#           ('and', 'how', 'she'): -15.913676546262266,
#           ('she', 'had', 'played'): -26.10662633336235,
#           ('had', 'played', 'with'): -11.085634523835123,
#           ('played', 'with', 'her'): -15.025684559607603,
#           ('with', 'her', 'from'): -19.266579118989007,
#           ('her', 'from', 'five'): -25.02428957757516,
#           ('from', 'five', 'years'): -14.30796452572993,
#           ('five', 'years', 'old'): -14.010721358210468,
#           ('years', 'old', '--'): -22.246692672449825,
#           ('old', '--', 'how'): -16.644479524093544,
#           ('she', 'had', 'devoted'): -31.260840380473386,
#           ('had', 'devoted', 'all'): -11.824958702628644,
#           ('devoted', 'all', 'her'): -14.091500219116252,
#           ('all', 'her', 'powers'): -24.063820227236153,
#           ('her', 'powers', 'to'): -12.466788775114116,
#           ('powers', 'to', 'attach'): -24.65790364376679,
#           ('to', 'attach', 'and'): -13.206054290173636,
#           ('attach', 'and', 'amuse'): -23.76135633928602,
#           ('and', 'amuse', 'her'): -9.674923155409912,
#           ('amuse', 'her', 'in'): -14.077081549318299,
#           ('her', 'in', 'health'): -26.904262074269177,
#           ('in', 'health', '--'): -14.107741198223088,
#           ('health', '--', 'and'): -12.28615166838118,
#           ('--', 'and', 'how'): -21.309157811565036,
#           ('and', 'how', 'nursed'): -28.413374051580448,
#           ('how', 'nursed', 'her'): -10.278603722345766,
#           ('nursed', 'her', 'through'): -17.548925651411775,
#           ('her', 'through', 'the'): -8.728887105456444,
#           ('through', 'the', 'various'): -28.446115382173126,
#           ('the', 'various', 'illnesses'): -23.38025053808089,
#           ('various', 'illnesses', 'of'): -8.903679001747538,
#           ('illnesses', 'of', 'childhood'): -24.288280272697857,
#           ('of', 'childhood', '.'): -9.382584355068607,
#           ('childhood', '.', '</s>'): -11.035559229164909,
#           ('<s>', '<s>', 'A'): -26.2265864142689,
#           ('<s>', 'A', 'large'): -21.560201738545793,
#           ('A', 'large', 'debt'): -22.417956199620956,
#           ('large', 'debt', 'of'): -11.409101462097455,
#           ('debt', 'of', 'gratitude'): -21.602721853219624,
#           ('of', 'gratitude', 'was'): -16.60058567976084,
#           ('gratitude', 'was', 'owing'): -22.24086781390734,
#           ('was', 'owing', 'here'): -16.174579101853258,
#           ('owing', 'here', ';'): -11.146727144574458,
#           ('here', ';', 'but'): -15.477047409434762,
#           (';', 'but', 'the'): -13.461847514294377,
#           ('but', 'the', 'intercourse'): -31.321891608653214,
#           ('the', 'intercourse', 'of'): -9.296158792702135,
#           ('intercourse', 'of', 'the'): -10.325906156873177,
#           ('of', 'the', 'last'): -24.48819083598863,
#           ('the', 'last', 'seven'): -25.18985918664732,
#           ('last', 'seven', 'years'): -13.763316544342507,
#           ('seven', 'years', ','): -10.29582006581509,
#           ('years', ',', 'the'): -14.500521893323123,
#           (',', 'the', 'equal'): -31.322794452320696,
#           ('the', 'equal', 'footing'): -20.97793078081821,
#           ('equal', 'footing', 'and'): -10.938942631952107,
#           ('footing', 'and', 'perfect'): -19.256513047116734,
#           ('and', 'perfect', 'unreserve'): -23.350505140094956,
#           ('perfect', 'unreserve', 'which'): -10.994242914177716,
#           ('unreserve', 'which', 'had'): -13.595939121946511,
#           ('which', 'had', 'soon'): -24.248700261283968,
#           ('had', 'soon', 'followed'): -18.425876351871477,
#           ('soon', 'followed', 'Isabella'): -22.00817134484183,
#           ('followed', 'Isabella', "'"): -9.807845090383202,
#           ('Isabella', "'", 's'): -16.499484571379895,
#           ('marriage', ',', 'on'): -19.235230827289545,
#           (',', 'on', 'their'): -18.687384159694144,
#           ('on', 'their', 'being'): -21.4942258520253,
#           ('their', 'being', 'left'): -19.735266202941773,
#           ('being', 'left', 'to'): -11.063172714333469,
#           ('left', 'to', 'each'): -22.008855468737842,
#           ('to', 'each', 'other'): -12.361170256077719,
#           ('each', 'other', ','): -11.138756460871672,
#           ('other', ',', 'was'): -18.553112588264007,
#           (',', 'was', 'yet'): -21.974652948692142,
#           ('was', 'yet', 'a'): -13.483075773040428,
#           ('yet', 'a', 'dearer'): -29.14779314224387,
#           ('a', 'dearer', ','): -7.83172159727224,
#           ('dearer', ',', 'tenderer'): -30.746297065798306,
#           (',', 'tenderer', 'recollection'): -14.367510806773147,
#           ('tenderer', 'recollection', '.'): -9.327056994294976,
#           ('recollection', '.', '</s>'): -11.035559229164909,
#           ('<s>', 'She', 'had'): -14.87720064378059,
#           ('She', 'had', 'been'): -15.669552430190647,
#           ('had', 'been', 'a'): -14.294115541854499,
#           ('been', 'a', 'friend'): -21.867045867156545,
#           ('a', 'friend', 'and'): -13.616698017959802,
#           ('friend', 'and', 'companion'): -25.022886994933867,
#           ('and', 'companion', 'such'): -17.351487595167242,
#           ('companion', 'such', 'as'): -11.158578797807914,
#           ('such', 'as', 'few'): -26.739479734033132,
#           ('as', 'few', 'possessed'): -20.472455347594394,
#           ('few', 'possessed', ':'): -12.798600303534014,
#           ('possessed', ':', 'intelligent'): -25.944792590748914,
#           (':', 'intelligent', ','): -8.174515584227457,
#           ('intelligent', ',', 'well'): -20.48219242427498,
#           (',', 'well', '-'): -12.307330767334447,
#           ('well', '-', 'informed'): -24.614091196921454,
#           ('-', 'informed', ','): -8.314321342345416,
#           ('informed', ',', 'useful'): -27.712191400478577,
#           (',', 'useful', ','): -7.032183336066779,
#           ('useful', ',', 'gentle'): -25.77774873540161,
#           (',', 'gentle', ','): -8.607657387471848,
#           ('gentle', ',', 'knowing'): -24.30979555952201,
#           (',', 'knowing', 'all'): -17.125892419876855,
#           ('knowing', 'all', 'the'): -10.770184662461848,
#           ('all', 'the', 'ways'): -26.45148353528918,
#           ('the', 'ways', 'of'): -9.646605980543246,
#           ('ways', 'of', 'the'): -10.408511783348217,
#           ('of', 'the', 'family'): -25.957339221639337,
#           ('the', 'family', ','): -10.21620707312358,
#           ('family', ',', 'interested'): -30.182351289473623,
#           (',', 'interested', 'in'): -9.34840768214226,
#           ('interested', 'in', 'all'): -15.508414935262016,
#           ('in', 'all', 'its'): -20.424487970790807,
#           ('all', 'its', 'concerns'): -23.628338632175385,
#           ('its', 'concerns', ','): -6.88147880792658,
#           ('concerns', ',', 'and'): -11.336848175418949,
#           (',', 'and', 'peculiarly'): -36.07631645762444,
#           ('and', 'peculiarly', 'interested'): -17.362794571596442,
#           ('peculiarly', 'interested', 'in'): -8.24979539347415,
#           ('interested', 'in', 'herself'): -21.772020281726416,
#           ('in', 'herself', ','): -8.46747380785828,
#           ('herself', ',', 'in'): -15.749668199738036,
#           (',', 'in', 'every'): -20.306882683033187,
#           ('in', 'every', 'pleasure'): -26.07407717870947,
#           ('every', 'pleasure', ','): -8.28521770479707,
#           ('pleasure', ',', 'every'): -21.735257358548914,
#           (',', 'every', 'scheme'): -27.813956644456333,
#           ('every', 'scheme', 'of'): -9.257770549849713,
#           ('scheme', 'of', 'hers'): -23.439431571983462,
#           ('of', 'hers', '--'): -15.223984655680331,
#           ('hers', '--', 'one'): -15.865141510842333,
#           ('--', 'one', 'to'): -13.653786945930726,
#           ('one', 'to', 'whom'): -21.376409829554067,
#           ('to', 'whom', 'she'): -15.035177375138856,
#           ('whom', 'she', 'could'): -15.932072983927355,
#           ('she', 'could', 'speak'): -21.96685692761728,
#           ('could', 'speak', 'every'): -18.76913908093924,
#           ('speak', 'every', 'thought'): -17.332609096825138,
#           ('every', 'thought', 'as'): -15.822849138972675,
#           ('thought', 'as', 'it'): -14.767773630482775,
#           ('as', 'it', 'arose'): -28.53280694976214,
#           ('it', 'arose', ','): -8.558747466510566,
#           ('arose', ',', 'and'): -11.124389343970607,
#           (',', 'and', 'who'): -23.863514118481834,
#           ('and', 'who', 'had'): -13.621410582232013,
#           ('who', 'had', 'such'): -20.704202147726356,
#           ('had', 'such', 'an'): -12.953603193731293,
#           ('such', 'an', 'affection'): -21.980599615942957,
#           ('an', 'affection', 'for'): -10.85280809802493,
#           ('affection', 'for', 'her'): -14.031565017877009,
#           ('for', 'her', 'as'): -17.148237999154784,
#           ('her', 'as', 'could'): -20.863659863192765,
#           ('as', 'could', 'never'): -19.238469651247975,
#           ('could', 'never', 'find'): -22.0292610043115,
#           ('never', 'find', 'fault'): -19.830601888806413,
#           ('find', 'fault', '.'): -10.610189546132164,
#           ('fault', '.', '</s>'): -11.50005196821627,
#           ('<s>', '<s>', 'How'): -27.684125422341534,
#           ('<s>', 'How', 'was'): -16.401709142021737,
#           ('How', 'was', 'she'): -19.260809507875166,
#           ('was', 'she', 'to'): -14.502351040976446,
#           ('she', 'to', 'bear'): -23.023946492911044,
#           ('to', 'bear', 'the'): -10.582623325921768,
#           ('bear', 'the', 'change'): -23.061211422389082,
#           ('the', 'change', '?--'): -20.918187381117235,
#           ('change', '?--', 'It'): -15.812029290193157,
#           ('?--', 'It', 'was'): -11.101995312725906,
#           ('It', 'was', 'true'): -24.151082578993595,
#           ('was', 'true', 'that'): -11.931421645102692,
#           ('true', 'that', 'her'): -17.863213902814127,
#           ('that', 'her', 'friend'): -18.682774461821094,
#           ('her', 'friend', 'was'): -16.52358372071649,
#           ('friend', 'was', 'going'): -19.05845123940667,
#           ('was', 'going', 'only'): -22.392643615455267,
#           ('going', 'only', 'half'): -16.4159701612447,
#           ('only', 'half', 'a'): -10.577525701480797,
#           ('half', 'a', 'mile'): -22.386368784487782,
#           ('a', 'mile', 'from'): -13.428699454459636,
#           ('mile', 'from', 'them'): -14.8852443650433,
#           ('from', 'them', ';'): -14.52170350340945,
#           ('them', ';', 'but'): -15.722352541464955,
#           (';', 'but', 'Emma'): -23.359202730126743,
#           ('but', 'Emma', 'was'): -13.662032409329498,
#           ('Emma', 'was', 'aware'): -25.235902776653035,
#           ('was', 'aware', 'that'): -11.029930316720883,
#           ('aware', 'that', 'great'): -20.238409979487685,
#           ('that', 'great', 'must'): -22.485230897215033,
#           ('great', 'must', 'be'): -11.56016385644577,
#           ('must', 'be', 'the'): -14.010290386125726,
#           ('be', 'the', 'difference'): -27.095412048389083,
#           ('the', 'difference', 'between'): -12.575879302124958,
#           ('difference', 'between', 'a'): -14.17787168338078,
#           ('between', 'a', 'Mrs'): -22.308978640862648,
#           ('a', 'Mrs', '.'): -8.832779801022582,
#           ('Mrs', '.', 'Weston'): -28.02620222377006,
#           ('.', 'Weston', ','): -10.274794852418028,
#           ('Weston', ',', 'only'): -23.397427187813634,
#           (',', 'only', 'half'): -18.441574479233726,
#           ('from', 'them', ','): -9.56854544016725,
#           ('them', ',', 'and'): -11.95467962125794,
#           ('and', 'a', 'Miss'): -27.2390964711865,
#           ('a', 'Miss', 'Taylor'): -20.12257659120956,
#           ('Miss', 'Taylor', 'in'): -15.868327546077058,
#           ('Taylor', 'in', 'the'): -10.159151370582366,
#           ('in', 'the', 'house'): -20.787596067030183,
#           ('the', 'house', ';'): -15.424468321522742,
#           ('house', ';', 'and'): -10.381795432347781,
#           (';', 'and', 'with'): -18.392916384275896,
#           ('and', 'with', 'all'): -15.262702975770518,
#           ('with', 'all', 'her'): -16.177536996837066,
#           ('all', 'her', 'advantages'): -28.890369051566093,
#           ('her', 'advantages', ','): -7.95451749328417,
#           ('advantages', ',', 'natural'): -24.26414834767788,
#           (',', 'natural', 'and'): -12.245828700801054,
#           ('natural', 'and', 'domestic'): -24.126806910242337,
#           ('and', 'domestic', ','): -11.296502186698566,
#           ('domestic', ',', 'she'): -16.5593239895229,
#           (',', 'she', 'was'): -13.418199773367803,
#           ('she', 'was', 'now'): -17.900801016383845,
#           ('was', 'now', 'in'): -13.87083326291237,
#           ('now', 'in', 'great'): -21.711197500307986,
#           ('in', 'great', 'danger'): -22.94608492482648,
#           ('great', 'danger', 'of'): -10.294270161889957,
#           ('danger', 'of', 'suffering'): -24.50862349346427,
#           ('of', 'suffering', 'from'): -12.416105714382747,
#           ('suffering', 'from', 'intellectual'): -24.784748997032125,
#           ('from', 'intellectual', 'solitude'): -17.158809554856465,
#           ('intellectual', 'solitude', '.'): -8.899272584662146,
#           ('solitude', '.', '</s>'): -11.160883885097402,
#           ('<s>', 'She', 'dearly'): -29.0199812262752,
#           ('She', 'dearly', 'loved'): -13.903761235322579,
#           ('dearly', 'loved', 'her'): -12.409842812603708,
#           ('loved', 'her', 'father'): -19.971403204023233,
#           ('her', 'father', ','): -10.160109270665206,
#           ('father', ',', 'but'): -18.54838103360752,
#           (',', 'but', 'he'): -16.597730802294063,
#           ('but', 'he', 'was'): -13.859558882514593,
#           ('he', 'was', 'no'): -20.780024964824605,
#           ('was', 'no', 'companion'): -25.308284934479968,
#           ('no', 'companion', 'for'): -12.976157810090045,
#           ('companion', 'for', 'her'): -13.460756803820791,
#           ('<s>', '<s>', 'He'): -25.11366689640115,
#           ('<s>', 'He', 'could'): -18.716431201422857,
#           ('He', 'could', 'not'): -11.399622752992167,
#           ('could', 'not', 'meet'): -25.72787982120624,
#           ('not', 'meet', 'her'): -16.476776612006134,
#           ('meet', 'her', 'in'): -14.609824906551204,
#           ('her', 'in', 'conversation'): -24.730152181234747,
#           ('in', 'conversation', ','): -8.23886623744685,
#           ('conversation', ',', 'rational'): -28.390358173731304,
#           (',', 'rational', 'or'): -14.943661862290277,
#           ('rational', 'or', 'playful'): -23.617263218524332,
#           ('or', 'playful', '.'): -9.720970915349291,
#           ('playful', '.', '</s>'): -11.45376782989229,
#           ('<s>', 'The', 'evil'): -23.85405727319286,
#           ('The', 'evil', 'of'): -11.254218664569535,
#           ('evil', 'of', 'the'): -10.648103871281407,
#           ('of', 'the', 'actual'): -32.83221425889324,
#           ('the', 'actual', 'disparity'): -20.499326235401586,
#           ('actual', 'disparity', 'in'): -10.435389799607162,
#           ('disparity', 'in', 'their'): -13.765727766738864,
#           ('in', 'their', 'ages'): -28.311574364706168,
#           ('their', 'ages', '('): -15.770926756571615,
#           ('ages', '(', 'and'): -11.07169331379706,
#           ('(', 'and', 'Mr'): -19.029731725938557,
#           ('and', 'Mr', '.'): -10.09269255225443,
#           ('.', 'Woodhouse', 'had'): -15.164507826025833,
#           ('Woodhouse', 'had', 'not'): -15.663939067920795,
#           ('had', 'not', 'married'): -26.831437640323063,
#           ('not', 'married', 'early'): -18.76281404678248,
#           ('married', 'early', ')'): -16.71529455232851,
#           ('early', ')', 'was'): -12.227481735979675,
#           (')', 'was', 'much'): -18.893870364236307,
#           ('was', 'much', 'increased'): -20.710539818790636,
#           ('much', 'increased', 'by'): -10.924194367008065,
#           ('increased', 'by', 'his'): -14.84109830597474,
#           ('by', 'his', 'constitution'): -28.65559033550456,
#           ('his', 'constitution', 'and'): -12.072485575753666,
#           ('constitution', 'and', 'habits'): -22.058769665425313,
#           ('and', 'habits', ';'): -10.752673837117975,
#           ('habits', ';', 'for'): -12.931315506311986,
#           (';', 'for', 'having'): -25.326871543016438,
#           ('for', 'having', 'been'): -14.979040127623891,
#           ('having', 'been', 'a'): -13.177585846132065,
#           ('been', 'a', 'valetudinarian'): -33.281474349207876,
#           ('a', 'valetudinarian', 'all'): -9.465946607731254,
#           ('valetudinarian', 'all', 'his'): -12.377830444205108,
#           ('all', 'his', 'life'): -19.39042874581166,
#           ('his', 'life', ','): -9.616563795866838,
# ...
#   ('talked',): -8.852087528756623,
#   ('night',): -8.111312299207423,
#   ('may',): -7.0342483467455175,
#   ('because',): -7.769869049864191,
#   ('housemaid',): -11.872512414900987,
#   ('doubt',): -9.06915203399445,
#   ('whether',): -8.422524869069399,
#   ('take',): -7.996116587115991,
#   ('anywhere',): -9.288514862468755,
#   ('else',): -8.715511993750873,
#   ('That',): -7.921268696319559,
#   ('got',): -8.549276574708543,
#   ('Hannah',): -10.619749446405619,
#   ('Nobody',): -11.061582198684658,
#   ('mentioned',): -9.269822729456603,
#   ('glad',): -8.996126898979561,
#   ('lucky',): -9.857609394358722,
#   ('slighted',): -10.95622168302683,
#   ('upon',): -6.090226878756842,
#   ('account',): -8.792898657366294,
#   ('make',): -7.911699245303408,
#   ('servant',): -9.269822729456603,
#   ('pretty',): -8.747947269504026,
#   ('spoken',): -9.03929907084477,
#   ('girl',): -8.996126898979561,
#   ('opinion',): -9.288514862468755,
#   ('Whenever',): -11.872512414900987,
#   ('curtseys',): -13.258806776020878,
#   ('asks',): -11.061582198684658,
#   ('me',): -5.963071703271595,
#   ('do',): -7.3133861674143015,
#   ('manner',): -8.368457647799124,
#   ('needlework',): -11.872512414900987,
#   ('observe',): -9.621220616294492,
#   ('turns',): -9.307563057439449,
#   ('lock',): -10.214284338297453,
#   ('door',): -8.726207282867621,
#   ('right',): -7.9309306072312955,
#   ('bangs',): -13.258806776020878,
#   ('comfort',): -8.816155519530561,
#   ('somebody',): -9.387605765112985,
#   ('about',): -6.482299783648694,
#   ('goes',): -8.747947269504026,
#   ('hearing',): -9.147932911847565,
#   ('tell',): -8.430493038718575,
#   ('spared',): -10.368435018124712,
#   ('exertions',): -10.550756574918667,
#   ('maintain',): -10.860911503222507,
#   ('flow',): -9.545234709316569,
#   ('ideas',): -9.647888863376652,
#   ('hoped',): -9.891510946034403,
#   ('help',): -8.684095797517495,
#   ('backgammon',): -12.160194487352767,
#   ('tolerably',): -9.891510946034403,
#   ('attacked',): -10.860911503222507,
#   ('regrets',): -10.619749446405619,
#   ('table',): -9.024700271423617,
#   ('placed',): -9.115672049629344,
#   ('visitor',): -10.773900126232876,
#   ('immediately',): -8.288993476444876,
#   ('afterwards',): -8.653636590032786,
#   ('walked',): -8.737018198971837,
#   ('unnecessary',): -10.000710237999394,
#   ('Knightley',): -10.42559343196466,
#   ('sensible',): -9.703458714531463,
#   ('eight',): -9.054114156629911,
#   ('thirty',): -8.954741682816707,
#   ('intimate',): -10.08075294567293,
#   ('connected',): -9.521137157737508,
#   ('elder',): -10.314367796854436,
#   ('brother',): -9.024700271423617,
#   ('frequent',): -9.926602265845673,
#   ('welcome',): -9.147932911847565,
#   ('directly',): -8.576675548896658,
#   ('mutual',): -10.167764322662562,
#   ('connexions',): -10.486218053781096,
#   ('returned',): -8.234926255174601,
#   ('late',): -9.024700271423617,
#   ('days',): -8.288993476444876,
#   ('absence',): -9.891510946034403,
#   ('Brunswick',): -12.160194487352767,
#   ('Square',): -11.061582198684658,
#   ('circumstance',): -9.56992732190694,
#   ('animated',): -10.263074502466885,
#   ('inquiries',): -10.039930951152677,
#   ('answered',): -7.878909422480417,
#   ('satisfactorily',): -12.160194487352767,
#   ('When',): -8.83996616822428,
#   ('gratefully',): -10.619749446405619,
#   ('observed',): -9.115672049629344,
#   ('come',): -7.305563441733093,
#   ('out',): -6.047250042707075,
#   ('call',): -8.202560970672568,
#   ('afraid',): -9.099923692661205,
#   ('shocking',): -10.314367796854436,
#   ('Not',): -9.06915203399445,
#   ('sir',): -9.762299214554396,
#   ('beautiful',): -8.902097949331285,
#   ('moonlight',): -10.167764322662562,
#   ('mild',): -9.474617142102616,
#   ('draw',): -9.181269332115157,
#   ('back',): -7.450664286040433,
#   ('fire',): -8.146818987664334,
#   ('found',): -7.90694864254481,
#   ('damp',): -10.167764322662562,
#   ('dirty',): -10.123312560091728,
#   ('catch',): -9.647888863376652,
#   ('cold',): -8.471315033238831,
#   ('Dirty',): -13.258806776020878,
#   ('Look',): -10.039930951152677,
#   ('shoes',): -9.621220616294492,
#   ('speck',): -12.565659595460932,
#   ('Well',): -10.000710237999394,
#   ('quite',): -7.7494184393929,
#   ('surprising',): -10.69385741855934,
#   ('vast',): -9.181269332115157,
#   ('rain',): -8.982140657004821,
#   ('rained',): -11.179365234341041,
#   ('dreadfully',): -10.368435018124712,
#   ('hard',): -8.302979718419616,
#   ('breakfast',): -9.288514862468755,
#   ('wanted',): -8.902097949331285,
#   ('By',): -8.324332842890184,
#   ('bye',): -11.649368863586776,
#   ('joy',): -8.55832641022846,
#   ('Being',): -10.486218053781096,
#   ('sort',): -8.430493038718575,
#   ('feeling',): -8.633833962736606,
#   ('hurry',): -9.82481957153573,
#   ('congratulations',): -11.179365234341041,
#   ('hope',): -8.317164353411572,
#   ('went',): -7.091290285132536,
#   ('behave',): -10.486218053781096,
#   ('Who',): -9.054114156629911,
#   ('cried',): -8.758997105690613,
#   ('Ah',): -10.314367796854436,
#   ('Tis',): -11.312896626965564,
#   ('business',): -8.549276574708543,
#   ('please',): -9.452144286250558,
#   ('possibly',): -10.039930951152677,
#   ('`',): -9.56992732190694,
#   (".'",): -7.72147250900234,
#   ('regard',): -8.996126898979561,
#   ('comes',): -8.430493038718575,
#   ('question',): -8.982140657004821,
#   ('dependence',): -10.263074502466885,
#   ('independence',): -10.263074502466885,
#   ('At',): -9.08441950612524,
#   ('rate',): -10.039930951152677,
#   ('better',): -7.935796796882469,
#   ('Especially',): -12.565659595460932,
#   ('_one_',): -11.467047306792821,
#   ('those',): -7.484255230476469,
#   ('fanciful',): -10.860911503222507,
#   ('troublesome',): -10.368435018124712,
#   ('creature',): -8.827989977177563,
#   ('playfully',): -11.467047306792821,
#   ('head',): -7.9604894094728404,
#   ('certainly',): -8.770170406288736,
#   ('believe',): -8.889358923553855,
#   (',"',): -5.901888533664856,
#   ('sometimes',): -8.576675548896658,
#   ('dearest',): -10.214284338297453,
#   ('mean',): -8.915001354167194,
#   ('_you_',): -10.69385741855934,
#   ('horrible',): -9.675287837564767,
#   ('idea',): -8.902097949331285,
#   ('Oh',): -9.647888863376652,
#   ('meant',): -8.982140657004821,
#   ('myself',): -7.358909422438385,
#   ('loves',): -9.732446251404715,
#   ('joke',): -10.368435018124712,
#   ('another',): -7.686652743843112,
#   ('fact',): -9.545234709316569,
#   ('faults',): -10.314367796854436,
#   ('told',): -8.165056575214114,
#   ('agreeable',): -9.497606660327314,
#   ('knew',): -8.22836885462844,
#   ('suspect',): -10.214284338297453,
#   ('knows',): -9.215755508186326,
#   ('flatter',): -10.69385741855934,
#   ('reflection',): -9.703458714531463,
#   ('has',): -7.087106178609962,
#   ('persons',): -8.982140657004821,
#   ('chances',): -10.619749446405619,
#   ('gainer',): -12.565659595460932,
#   ('willing',): -9.732446251404715,
#   ('let',): -8.049320623179456,
#   ('pass',): -8.471315033238831,
#   ('--"',): -7.4446762441958105,
#   ('hear',): -8.549276574708543,
#   ('behaved',): -10.167764322662562,
#   ('charmingly',): -11.872512414900987,
#   ('Every',): -9.762299214554396,
#   ('punctual',): -11.312896626965564,
#   ('looks',): -8.726207282867621,
#   ('tear',): -10.167764322662562,
#   ('face',): -7.774009842530222,
#   ('seen',): -8.549276574708543,
#   ('apart',): -9.497606660327314,
#   ('Dear',): -11.312896626965564,
#   ('bears',): -10.263074502466885,
#   ('sorry',): -9.474617142102616,
#   ('lose',): -9.56992732190694,
#   ('_will_',): -12.160194487352767,
#   ('miss',): -10.214284338297453,
#   ('thinks',): -9.497606660327314,
#   ('turned',): -7.950539078619673,
#   ('divided',): -9.307563057439449,
#   ('tears',): -9.115672049629344,
#   ('smiles',): -9.621220616294492,
#   ('should',): -7.074657885083393,
#   ('acceptable',): -10.263074502466885,
#   ('important',): -9.387605765112985,
#   ('secure',): -9.326981143296551,
#   ('provision',): -10.314367796854436,
#   ('therefore',): -7.812069404354567,
#   ('allow',): -9.962969910016549,
#   ('pain',): -8.852087528756623,
#   ('happily',): -9.926602265845673,
#   ('forgotten',): -9.387605765112985,
#   ('matter',): -8.928073435734547,
#   ('considerable',): -9.647888863376652,
#   ('four',): -8.288993476444876,
#   ('proved',): -9.288514862468755,
#   ('marry',): -9.647888863376652,
#   ('shook',): -9.181269332115157,
#   ('fondly',): -10.69385741855934,
#   ('replied',): -8.968347334872487,
#   ('matches',): -11.312896626965564,
#   ('foretell',): -11.872512414900987,
#   ('whatever',): -8.996126898979561,
#   ('Pray',): -10.69385741855934,
#   ('none',): -8.07702322572879,
#   ('greatest',): -10.167764322662562,
#   ('amusement',): -9.891510946034403,
#   ('success',): -9.621220616294492,
#   ('widower',): -12.160194487352767,
#   ('perfectly',): -8.715511993750873,
#   ('constantly',): -9.891510946034403,
#   ('occupied',): -9.56992732190694,
#   ('either',): -8.18363296078705,
#   ('friends',): -8.45478573128762,
#   ('wherever',): -9.82481957153573,
#   ('need',): -8.928073435734547,
#   ('spend',): -9.962969910016549,
#   ('single',): -9.474617142102616,
#   ('year',): -8.83996616822428,
#   ('alone',): -7.820727467097681,
#   ('Some',): -9.891510946034403,
#   ('deathbed',): -13.258806776020878,
#   ('others',): -8.673839297350305,
#   ('son',): -8.673839297350305,
#   ('uncle',): -10.039930951152677,
#   ('letting',): -10.486218053781096,
#   ('solemn',): -9.56992732190694,
#   ('nonsense',): -9.703458714531463,
#   ('subject',): -9.36698647791025,
#   ('believed',): -8.968347334872487,
#   ('Ever',): -11.061582198684658,
#   ('since',): -8.261594502256761,
#   ('met',): -8.694458584553042,
#   ('Broadway',): -11.179365234341041,
#   ('Lane',): -11.179365234341041,
#   ('began',): -7.72147250900234,
#   ('drizzle',): -13.258806776020878,
#   ('darted',): -9.647888863376652,
#   ('gallantry',): -10.619749446405619,
#   ('borrowed',): -10.486218053781096,
#   ('umbrellas',): -11.872512414900987,
#   ('Farmer',): -9.099923692661205,
#   ('Mitchell',): -13.258806776020878,
#   ('planned',): -10.95622168302683,
#   ('blessed',): -9.054114156629911,
#   ('instance',): -10.08075294567293,
#   ('leave',): -8.55832641022846,
#   ('making',): -8.673839297350305,
#   ('understand',): -8.889358923553855,
#   (',\'"',): -11.649368863586776,
#   ('Success',): -13.258806776020878,
#   ('supposes',): -11.649368863586776,
#   ('endeavour',): -10.486218053781096,
#   ('Your',): -9.36698647791025,
#   ('properly',): -9.59524512989123,
#   ('delicately',): -11.312896626965564,
#   ('endeavouring',): -11.061582198684658,
#   ('bring',): -8.576675548896658,
#   ('worthy',): -9.024700271423617,
#   ('employment',): -9.891510946034403,
#   ('young',): -7.883528368336712,
#   ('lady',): -9.198363765474458,
#   ('imagine',): -9.621220616294492,
#   ('planning',): -11.179365234341041,
#   ('saying',): -8.694458584553042,
#   ('yourself',): -8.24817148192462,
#   ('idle',): -9.474617142102616,
#   (",'",): -7.4967553932407,
#   ('why',): -8.941318662484566,
#   ('talk',): -8.704929884420336,
#   ('Where',): -9.36698647791025,
#   ('merit',): -9.732446251404715,
#   ('proud',): -9.115672049629344,
#   ('guess',): -9.79307087322115,
#   ('_that_',): -10.860911503222507,
#   ('can',): -7.462749025255505,
#   ('known',): -8.360966976069966,
#   ('triumph',): -9.545234709316569,
#   ('cleverer',): -11.649368863586776,
#   ('depend',): -10.167764322662562,
#   ('merely',): -8.852087528756623,
#   ('luck',): -9.857609394358722,
#   ('There',): -9.164462213798776,
#   ('talent',): -10.550756574918667,
#   ('word',): -8.513874647657627,
#   ('quarrel',): -9.962969910016549,
#   ('claim',): -9.732446251404715,
#   ('drawn',): -9.08441950612524,
#   ('pictures',): -9.857609394358722,
#   ('something',): -7.72147250900234,
#   ('nothing',): -7.561713289515472,
#   ('If',): -8.852087528756623,
#   ('visits',): -10.000710237999394,
#   ('given',): -8.488122151555212,
#   ('encouragements',): -12.565659595460932,
#   ('smoothed',): -11.649368863586776,
#   ('matters',): -9.181269332115157,
#   ('enough',): -7.400873621537418,
#   ('comprehend',): -10.08075294567293,
#   ('straightforward',): -11.872512414900987,
#   ('open',): -8.158940348196678,
#   ('hearted',): -11.467047306792821,
#   ('unaffected',): -11.312896626965564,
#   ('safely',): -9.36698647791025,
#   ('manage',): -10.619749446405619,
#   ('likely',): -9.59524512989123,
#   ('harm',): -9.762299214554396,
#   ('interference',): -10.486218053781096,
#   ('rejoined',): -11.872512414900987,
#   ('understanding',): -8.954741682816707,
#   ('pray',): -9.56992732190694,
#   ('silly',): -9.647888863376652,
#   ('break',): -8.968347334872487,
#   ('circle',): -9.430165379531783,
#   ('grievously',): -11.179365234341041,
#   ('Only',): -9.79307087322115,
#   ('Elton',): -11.467047306792821,
#   (',--',): -7.7136293315413145,
#   ('look',): -7.7616385507276755,
#   ('whole',): -9.054114156629911,
#   ('fitted',): -9.82481957153573,
#   ('comfortably',): -10.314367796854436,
#   ('shame',): -8.982140657004821,
#   ('longer',): -8.941318662484566,
#   ('joining',): -10.95622168302683,
#   ('hands',): -8.19621174299391,
#   ('same',): -10.619749446405619,
#   ('service',): -9.198363765474458,
#   ('shew',): -9.010311533971517,
#   ('attention',): -8.694458584553042,
#   ('ask',): -8.889358923553855,
#   ('dare',): -9.762299214554396,
#   ('With',): -7.786536102349403,
#   ('laughing',): -9.474617142102616,
#   ('Invite',): -13.258806776020878,
#   ('fish',): -8.770170406288736,
#   ('chicken',): -11.312896626965564,
#   ('chuse',): -10.486218053781096,
#   ('Depend',): -12.565659595460932,
#   ('six',): -8.715511993750873,
#   ('care',): -8.902097949331285,
#   ('II',): -10.860911503222507,
#   ('native',): -10.08075294567293,
#   ('born',): -9.03929907084477,
#   ('respectable',): -9.926602265845673,
#   ('generations',): -10.123312560091728,
#   ('rising',): -8.827989977177563,
#   ('gentility',): -11.649368863586776,
#   ('property',): -9.762299214554396,
#   ('received',): -8.576675548896658,
#   ('education',): -9.647888863376652,
#   ('succeeding',): -10.69385741855934,
#   ('small',): -8.496632841223121,
#   ('become',): -8.889358923553855,
#   ('indisposed',): -11.467047306792821,
#   ('homely',): -11.467047306792821,
#   ('pursuits',): -10.860911503222507,
#   ('brothers',): -9.926602265845673,
#   ('engaged',): -9.08441950612524,
#   ('satisfied',): -9.288514862468755,
#   ('active',): -9.891510946034403,
#   ('social',): -10.000710237999394,
#   ('entering',): -9.79307087322115,
#   ('militia',): -12.565659595460932,
#   ('county',): -10.860911503222507,
#   ('embodied',): -11.649368863586776,
#   ('Captain',): -8.317164353411572,
#   ('general',): -9.452144286250558,
#   ('favourite',): -9.762299214554396,
#   ('military',): -10.214284338297453,
#   ('introduced',): -10.214284338297453,
#   ('Churchill',): -11.061582198684658,
#   ('Yorkshire',): -11.467047306792821,
#   ('fell',): -7.911699245303408,
#   ('love',): -7.851635004560758,
#   ('surprized',): -10.263074502466885,
#   ('except',): -8.954741682816707,
#   ('full',): -7.926087982755508,
#   ('pride',): -9.010311533971517,
#   ('importance',): -9.59524512989123,
#   ('connexion',): -10.08075294567293,
#   ('offend',): -10.000710237999394,
#   ('command',): -8.852087528756623,
#   ('bore',): -9.497606660327314,
#   ('proportion',): -10.314367796854436,
#   ('estate',): -9.732446251404715,
#   ('dissuaded',): -13.258806776020878,
#   ('took',): -7.602814965201024,
#   ('infinite',): -9.545234709316569,
#   ('mortification',): -10.619749446405619,
#   ('threw',): -9.215755508186326,
#   ('due',): -9.099923692661205,
#   ('decorum',): -11.312896626965564,
#   ('unsuitable',): -12.160194487352767,
#   ('produce',): -10.000710237999394,
#   ('ought',): -8.488122151555212,
#   ('whose',): -8.353531997582447,
#   ('warm',): -9.147932911847565,
#   ('sweet',): -8.324332842890184,
#   ('return',): -8.391272325565295,
#   ('goodness',): -9.521137157737508,
#   ('spirit',): -8.522608327626381,
#   ('resolution',): -9.452144286250558,
#   ('pursue',): -10.314367796854436,
#   ('refrain',): -10.95622168302683,
#   ('unreasonable',): -10.42559343196466,
#   ('anger',): -9.251473590788406,
#   ('missing',): -10.123312560091728,
#   ('luxuries',): -12.160194487352767,
#   ('former',): -9.79307087322115,
#   ('income',): -10.123312560091728,
#   ('still',): -7.383876045168846,
#   ('comparison',): -10.263074502466885,
#   ('Enscombe',): -10.486218053781096,
#   ('cease',): -9.621220616294492,
#   ('once',): -7.753475240088514,
#   ('considered',): -9.326981143296551,
#   ('especially',): -9.82481957153573,
#   ('Churchills',): -12.160194487352767,
#   ('amazing',): -10.95622168302683,
#   ...}]
